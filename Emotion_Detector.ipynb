# %%
from __future__ import division
import nltk 
import re
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import *
from textblob.classifiers import NaiveBayesClassifier
from sklearn.cross_validation import KFold
from nltk.classify.naivebayes import NaiveBayesClassifier
from gensim import corpora, models, similarities
from nltk.corpus import wordnet as wn
import urllib
import urllib3
# Uncomment if using AlchemyAPI
# from alchemyapi import AlchemyAPI
# alchemyapi = AlchemyAPI()

# %%
# !pip install urllib3
# Out:
# Requirement already satisfied: urllib3 in d:\appdata\local\continuum\anaconda3\lib\site-packages (1.23)

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/01/6e/8a8ff9ec36a34dd753c6504cde998c4e0a4e37dcd91e1c9ca4b71960a4f5/gensim-3.6.0.tar.gz (23.1MB)
# Requirement already satisfied: numpy>=1.11.3 in d:\appdata\local\continuum\anaconda3\lib\site-packages (from gensim) (1.15.1)
# Requirement already satisfied: scipy>=0.18.1 in d:\appdata\local\continuum\anaconda3\lib\site-packages (from gensim) (1.1.0)
# Requirement already satisfied: six>=1.5.0 in d:\appdata\local\continuum\anaconda3\lib\site-packages (from gensim) (1.11.0)
# Collecting smart_open>=1.2.1 (from gensim)
#   Downloading https://files.pythonhosted.org/packages/4b/1f/6f27e3682124de63ac97a0a5876da6186de6c19410feab66c1543afab055/smart_open-1.7.1.tar.gz
# Requirement already satisfied: boto>=2.32 in d:\appdata\local\continuum\anaconda3\lib\site-packages (from smart_open>=1.2.1->gensim) (2.49.0)
# Collecting bz2file (from smart_open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/61/39/122222b5e85cd41c391b68a99ee296584b2a2d1d233e7ee32b4532384f2d/bz2file-0.98.tar.gz
# Requirement already satisfied: requests in d:\appdata\local\continuum\anaconda3\lib\site-packages (from smart_open>=1.2.1->gensim) (2.19.1)
# Collecting boto3 (from smart_open>=1.2.1->gensim)
#   Using cached https://files.pythonhosted.org/packages/ab/ba/34037d2a97f6b1bc7dd6de4aefcf1633225993571dcb7372d4777c05716e/boto3-1.9.49-py2.py3-none-any.whl
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in d:\appdata\local\continuum\anaconda3\lib\site-packages (from requests->smart_open>=1.2.1->gensim) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in d:\appdata\local\continuum\anaconda3\lib\site-packages (from requests->smart_open>=1.2.1->gensim) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\appdata\local\continuum\anaconda3\lib\site-packages (from requests->smart_open>=1.2.1->gensim) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\appdata\local\continuum\anaconda3\lib\site-packages (from requests->smart_open>=1.2.1->gensim) (2018.8.24)
# Collecting s3transfer<0.2.0,>=0.1.10 (from boto3->smart_open>=1.2.1->gensim)
#   Using cached https://files.pythonhosted.org/packages/d7/14/2a0004d487464d120c9fb85313a75cd3d71a7506955be458eebfe19a6b1d/s3transfer-0.1.13-py2.py3-none-any.whl
# Collecting botocore<1.13.0,>=1.12.49 (from boto3->smart_open>=1.2.1->gensim)
#   Using cached https://files.pythonhosted.org/packages/9f/92/ef02dcb2ba6bf95e96b68884a94d3e66e81093aac3b358d95898f07fda20/botocore-1.12.49-py2.py3-none-any.whl
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3->smart_open>=1.2.1->gensim)
#   Using cached https://files.pythonhosted.org/packages/b7/31/05c8d001f7f87f0f07289a5fc0fc3832e9a57f2dbd4d3b0fee70e0d51365/jmespath-0.9.3-py2.py3-none-any.whl
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in d:\appdata\local\continuum\anaconda3\lib\site-packages (from botocore<1.13.0,>=1.12.49->boto3->smart_open>=1.2.1->gensim) (2.6.1)
# Requirement already satisfied: docutils>=0.10 in d:\appdata\local\continuum\anaconda3\lib\site-packages (from botocore<1.13.0,>=1.12.49->boto3->smart_open>=1.2.1->gensim) (0.14)
# Building wheels for collected packages: gensim, smart-open, bz2file
#   Running setup.py bdist_wheel for gensim: started
#   Running setup.py bdist_wheel for gensim: finished with status 'done'
#   Stored in directory: C:\Users\chilukuri\AppData\Local\pip\Cache\wheels\97\37\bd\2b80cbc3be93cdf9dd3348dc8b5e659e059f5b51fcecc706be
#   Running setup.py bdist_wheel for smart-open: started
#   Running setup.py bdist_wheel for smart-open: finished with status 'done'
#   Stored in directory: C:\Users\chilukuri\AppData\Local\pip\Cache\wheels\23\00\44\e5b939f7a80c04e32297dbd6d96fa3065af89ecf57e2b5f89f
#   Running setup.py bdist_wheel for bz2file: started
#   Running setup.py bdist_wheel for bz2file: finished with status 'done'
#   Stored in directory: C:\Users\chilukuri\AppData\Local\pip\Cache\wheels\81\75\d6\e1317bf09bf1af5a30befc2a007869fa6e1f516b8f7c591cb9
# Successfully built gensim smart-open bz2file
# Installing collected packages: bz2file, jmespath, botocore, s3transfer, boto3, smart-open, gensim
# Successfully installed boto3-1.9.49 botocore-1.12.49 bz2file-0.98 gensim-3.6.0 jmespath-0.9.3 s3transfer-0.1.13 smart-open-1.7.1

# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading https://files.pythonhosted.org/packages/11/18/7f55c8be6d68ddc4036ffda5382ca51e23a1075987f708b9123712091af1/textblob-0.15.1-py2.py3-none-any.whl (631kB)
# Requirement already satisfied: nltk>=3.1 in d:\appdata\local\continuum\anaconda3\lib\site-packages (from textblob) (3.3)
# Requirement already satisfied: six in d:\appdata\local\continuum\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.11.0)
# Installing collected packages: textblob
# Successfully installed textblob-0.15.1

# %%
excell = pd.read_csv('ISEAR.csv')

# %%
excell.head()
# Out:
#        joy  \
# 0     fear
# 1    anger
# 2  sadness
# 3  disgust
# 4    shame
#
#   On days when I feel close to my partner and other friends.   \nWhen I feel at peace with myself and also experience a close  \ncontact with people whom I regard greatly.  \
# 0  Every time I imagine that someone I love or I ...
# 1  When I had been obviously unjustly treated and...
# 2  When I think about the short time that we live...
# 3  At a gathering I found myself involuntarily si...
# 4  When I realized that I was directing the feeli...
#
#   Unnamed: 2
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
'''
Reading the Dataset (ISEAR Dataset)
'''
Data = pd.read_csv('ISEAR.csv',header=None)
'''
36 - Class Label
40 - Sentence
'''
# Out:
# '\n36 - Class Label\n40 - Sentence\n'

# %%
Data
# Out:
#             0                                                  1    2
# 0         joy  On days when I feel close to my partner and ot...  NaN
# 1        fear  Every time I imagine that someone I love or I ...  NaN
# 2       anger  When I had been obviously unjustly treated and...  NaN
# 3     sadness  When I think about the short time that we live...  NaN
# 4     disgust  At a gathering I found myself involuntarily si...  NaN
# 5       shame  When I realized that I was directing the feeli...  NaN
# 6       guilt  I feel guilty when when I realize that I consi...  NaN
# 7         joy  After my girlfriend had taken her exam we went...  NaN
# 8        fear  When, for the first time I realized the meanin...  NaN
# 9       anger  When a car is overtaking another and I am forc...  NaN
# 10    sadness  When I recently thought about the hard work it...  NaN
# 11    disgust    When I found a bristle in the liver paste tube.  NaN
# 12      shame  When I was tired and unmotivated, I shouted at...  NaN
# 13      guilt  When I think that I do not study enough.  Afte...  NaN
# 14        joy  When I pass an examination which I did not thi...  NaN
# 15       fear  When one has arranged to meet someone and that...  NaN
# 16      anger  When one is unjustly accused of something one ...  NaN
# 17    sadness  When one's studies seem hopelessly difficult a...  NaN
# 18    disgust  When one finds out that someone you know is no...  NaN
# 19      shame  When one has been unjust, stupid towards someo...  NaN
# 20      guilt  When one has neglected or been unjust to a goo...  NaN
# 21        joy          Passing an exam I did not expect to pass.  NaN
# 22       fear  When I climbed up a tree to pick apples.  The ...  NaN
# 23      guilt  When excuses are necessary and I get out of do...  NaN
# 24        joy                            When I had my children.  NaN
# 25       fear  When my 2 year old son climbed up and sat on t...  NaN
# 26      anger  When my partner was attacked and lost three te...  NaN
# 27    sadness  When I see children on T.V from areas devastat...  NaN
# 28    disgust  When I nearly walked on a blindworm and then s...  NaN
# 29      shame  When I saw my 18 year old son grab an oxygen m...  NaN
# ...       ...                                                ...  ...
# 7486    shame  I forgot to zip up my trousers, this was not n...  NaN
# 7487    guilt                                           Peeping.  NaN
# 7488      joy  I had a picnic with old classmates, we chatted...  NaN
# 7489     fear  At night when I was alone at home (all the fam...  NaN
# 7490    anger  When I saw that my bed at the hostel was a mes...  NaN
# 7491  sadness  During the Physics experiment session I did no...  NaN
# 7492  disgust  A man sexually aggressed a small girl in the b...  NaN
# 7493    shame         Being unable to stop urinating on the bus.  NaN
# 7494    guilt  There were old people in a crowded bus and I d...  NaN
# 7495      joy  It was the first time that I gave a birthday p...  NaN
# 7496     fear  It was a week before the higher level results ...  NaN
# 7497    anger  The surname of my brother was different from o...  NaN
# 7498  sadness  When I was in primary 6, my father died.  I wa...  NaN
# 7499     guit  At hostel, my roommate was a very selfish pers...  NaN
# 7500    shame  My friend had many female friends and I though...  NaN
# 7501    guilt  In the past I used to think that my mother was...  NaN
# 7502      joy  In August,1983, the long awaited "big envelope...  NaN
# 7503     fear  On Christmas eve,1984, I had just finished the...  NaN
# 7504    anger  In September 1984, I was forced to live with s...  NaN
# 7505     fear  This issue worried me rather than saddening me...  NaN
# 7506    anger  My roommate liked to listen to some meaningles...  NaN
# 7507    shame  Last Summer I went camping with some C.U stude...  NaN
# 7508    shame                  I lied to one of my best friends.  NaN
# 7509      joy         I received a letter from a distant friend.  NaN
# 7510     fear  My parents were out and I was the eldest at ho...  NaN
# 7511    shame  Two years back someone invited me to be the tu...  NaN
# 7512    shame  I had taken the responsibility to do something...  NaN
# 7513     fear  I was at home and I heard a loud sound of spit...  NaN
# 7514    guilt  I did not do the homework that the teacher had...  NaN
# 7515     fear  I had shouted at my younger brother and he was...  NaN
#
# [7516 rows x 3 columns]

# %%
'''
Emotion Labels
'''
emotion_labels = ['joy', 'fear', 'anger', 'sadness', 'disgust', 'shame', 'guilt']
# emotion_labels = ['joy', 'fear', 'anger', 'sadness', 'disgust']

# %%
'''
Negation words
'''
negation_words = ['not', 'neither', 'nor', 'but', 'however', 'although', 'nonetheless', 'despite', 'except', 'even though', 'yet']

# %%
'''
Returns a list of all corresponding class labels
'''
def class_labels(emotions):
    labels = []
    labelset = []
    exclude = []
    for i in range(len(emotions)):
#         labels.append(e)
#         labelset.append([e])
        if emotions[i] not in ['shame','guilt']:
            labels.append(e)
            labelset.append([e])
        else:
            exclude.append(i)
    return labels, labelset, exclude

# %%
'''
Removes unnecessary characters from sentences
'''
def removal(sentences):
    sentence_list = []
    count = 0
#     for sen in sentences:
#         count += 1
#         print count
#         print sen
#         print type(sen)
    s = nltk.word_tokenize(sentences)
    characters = ["á", "\xc3", "\xa1", "\n", ",", ".", "[", "]", ""]
    l = []
    for t in s:
        if t not in characters:
            l.append(t)
    return l
#     new = ' '.join([i for i in s if not [e for e in characters if e in i]])
#     print new
#     sentence_list.append(new)
#     return sentence_list

# %%
'''
POS-TAGGER, returns NAVA words
'''
def pos_tag(sentences):
    tags = [] #have the pos tag included
    nava_sen = []
    pt = nltk.pos_tag(sentences)
#     for s in sentences:
#     s_token = nltk.word_tokenize(sentences)
#     pt = nltk.pos_tag(s_token)
    nava = []
    nava_words = []
    for t in pt:
        if t[1].startswith('NN') or t[1].startswith('JJ') or t[1].startswith('VB') or t[1].startswith('RB'):
            nava.append(t)
            nava_words.append(t[0])
    return nava, nava_words
#     tags.append(nava)
#     nava_sen.append(nava_words)
#     return tags, nava_sen

# %%
'''
Performs stemming
'''
def stemming(sentences):
    sentence_list = []
    sen_string = []
    sen_token = []
    stemmer = PorterStemmer()
    i = 0
#     for sen in sentences:
#         print i,
    i += 1
    st = ""
    for word in sentences:
        word_l = word.lower()
        if len(word_l) >= 3:
            st += stemmer.stem(word_l) + " "
    sen_string.append(st)
    w_set = nltk.word_tokenize(st)
    sen_token.append(w_set)
    w_text = nltk.Text(w_set)
    sentence_list.append(w_text)
    return w_text, st, w_set
#     return sentence_list, sen_string, sen_token

# %%
'''
Write to file
'''
def write_to_file(filename, text):
    o = open(filename,'w')
    o.write(str(text))
    o.close()

# %%
'''
Creating the dataframe
'''
def create_frame(Data):
    labels = []
#     sentences = []
#     sen_string = []
#     sen_token =[]
    sen = []
    sen_s = []
    sen_t = []
    labelset = []
    for i in range(len(Data)):
        if i >= 0:
#             print i,
            emotion = Data[0][i]
            sit = Data[1][i]
#             if emotion not in ['shame', 'guilt']:
            labels.append(emotion)
            labelset.append([emotion])
            sent = removal(sit)
            nava, sent_pt = pos_tag(sent)
            sentences, sen_string, sen_token = stemming(sent_pt)
            sen.append(sentences)
            sen_s.append(sen_string)
            sen_t.append(sen_token)
#     labels, labelset, exclude = class_labels(emotions[1:])
#     sent = removal(sit[1:], exclude)
#     nava, sent_pt = pos_tag(sent)
#     sentences, sen_string, sen_token = stemming(sent_pt)
    frame = pd.DataFrame({0 : labels,
                          1 : sen,
                          2 : sen_s,
                          3 : sen_t,
                          4 : labelset})
    return frame, sen_t, labels, sen_s

# %%
c, st, labels, senten = create_frame(Data)

# %%
c
# Out:
#             0                                                  1  \
# 0         joy  (day, feel, close, partner, other, friend, fee...
# 1        fear  (time, imagin, someon, love, contact, seriou, ...
# 2       anger  (had, been, obvious, unjustli, treat, had, pos...
# 3     sadness  (think, short, time, live, relat, period, life...
# 4     disgust  (gather, found, involuntarili, sit, next, peop...
# 5       shame  (realiz, wa, direct, feel, discont, partner, w...
# 6       guilt  (feel, guilti, realiz, consid, materi, thing, ...
# 7         joy  (girlfriend, had, taken, exam, went, parent, p...
# 8        fear                 (first, time, realiz, mean, death)
# 9       anger                  (car, overtak, forc, drive, road)
# 10    sadness  (recent, thought, hard, work, take, studi, wan...
# 11    disgust                 (found, bristl, liver, past, tube)
# 12      shame  (wa, tire, unmotiv, shout, girlfriend, brought...
# 13      guilt  (think, not, studi, enough, weekend, think, ha...
# 14        joy         (pass, examin, did, not, think, did, well)
# 15       fear  (one, ha, arrang, meet, someon, person, arriv,...
# 16      anger           (unjustli, accus, someth, ha, not, done)
# 17    sadness  (one, studi, seem, hopelessli, difficult, unin...
# 18    disgust  (find, someon, know, not, had, thought, instan...
# 19      shame  (one, ha, been, unjust, stupid, toward, someon...
# 20      guilt     (one, ha, neglect, been, unjust, good, friend)
# 21        joy               (pass, exam, did, not, expect, pass)
# 22       fear  (climb, tree, pick, appl, angl, ladder, wa, di...
# 23      guilt                   (excus, are, necessari, get, do)
# 24        joy                                    (had, children)
# 25       fear  (year, old, son, climb, sat, 7th, floor, balco...
# 26      anger                 (partner, wa, attack, lost, teeth)
# 27    sadness   (see, children, t.v, area, devast, drought, war)
# 28    disgust  (nearli, walk, blindworm, then, saw, crawl, away)
# 29      shame  (saw, year, old, son, grab, oxygen, mask, had,...
# ...       ...                                                ...
# 7486    shame      (forgot, zip, trouser, wa, not, notic, anyon)
# 7487    guilt                                             (peep)
# 7488      joy     (had, picnic, old, classmat, chat, play, game)
# 7489     fear  (night, wa, alon, home, famili, member, usual,...
# 7490    anger  (saw, bed, hostel, wa, mess, guess, someon, el...
# 7491  sadness  (physic, experi, session, did, not, understand...
# 7492  disgust  (man, sexual, aggress, small, girl, bu, girl, ...
# 7493    shame                        (be, unabl, stop, urin, bu)
# 7494    guilt  (were, old, peopl, crowd, bu, did, not, have, ...
# 7495      joy  (wa, first, time, gave, birthday, present, fri...
# 7496     fear  (wa, week, higher, level, result, were, announ...
# 7497    anger  (surnam, brother, wa, differ, often, grin, hom...
# 7498  sadness  (wa, primari, father, die, wa, veri, young, th...
# 7499     guit  (hostel, roommat, wa, veri, selfish, person, a...
# 7500    shame  (friend, had, mani, femal, friend, thought, we...
# 7501    guilt  (past, use, think, mother, wa, veri, nag, pers...
# 7502      joy  (august,1983, long, await, big, envelop, docum...
# 7503     fear  (christma, eve,1984, had, just, finish, exam, ...
# 7504    anger  (septemb, wa, forc, live, someon, did, not, fi...
# 7505     fear  (issu, worri, rather, sadden, mid, septemb, we...
# 7506    anger  (roommat, like, listen, meaningless, song, had...
# 7507    shame  (last, summer, went, camp, c.u, student, wa, w...
# 7508    shame                                (lie, best, friend)
# 7509      joy                  (receiv, letter, distant, friend)
# 7510     fear  (parent, were, wa, eldest, home, midnight, mal...
# 7511    shame  (year, back, someon, invit, tutor, grand-daugh...
# 7512    shame  (had, taken, respons, someth, had, prepar, how...
# 7513     fear  (wa, home, heard, loud, sound, spit, door, tho...
# 7514    guilt  (did, not, homework, teacher, had, ask, wa, sc...
# 7515     fear  (had, shout, younger, brother, wa, alway, afra...
#
#                                                       2  \
# 0     day feel close partner other friend feel peac ...
# 1     time imagin someon love contact seriou ill eve...
# 2     had been obvious unjustli treat had possibl el...
# 3     think short time live relat period life think ...
# 4     gather found involuntarili sit next peopl expr...
# 5     realiz wa direct feel discont partner way wa t...
# 6     feel guilti realiz consid materi thing more im...
# 7          girlfriend had taken exam went parent place
# 8                         first time realiz mean death
# 9                          car overtak forc drive road
# 10    recent thought hard work take studi want tri s...
# 11                        found bristl liver past tube
# 12    wa tire unmotiv shout girlfriend brought neg s...
# 13    think not studi enough weekend think have been...
# 14                  pass examin did not think did well
# 15    one ha arrang meet someon person arriv late me...
# 16                   unjustli accus someth ha not done
# 17      one studi seem hopelessli difficult uninterest
# 18    find someon know not had thought instanc frien...
# 19         one ha been unjust stupid toward someon els
# 20              one ha neglect been unjust good friend
# 21                       pass exam did not expect pass
# 22    climb tree pick appl angl ladder wa did not en...
# 23                          excus are necessari get do
# 24                                        had children
# 25    year old son climb sat 7th floor balconi leg h...
# 26                        partner wa attack lost teeth
# 27            see children t.v area devast drought war
# 28           nearli walk blindworm then saw crawl away
# 29    saw year old son grab oxygen mask had breath d...
# ...                                                 ...
# 7486             forgot zip trouser wa not notic anyon
# 7487                                              peep
# 7488            had picnic old classmat chat play game
# 7489  night wa alon home famili member usual get tog...
# 7490  saw bed hostel wa mess guess someon els had us...
# 7491  physic experi session did not understand conte...
# 7492  man sexual aggress small girl bu girl did not ...
# 7493                             be unabl stop urin bu
# 7494  were old peopl crowd bu did not have courag gi...
# 7495  wa first time gave birthday present friend wro...
# 7496  wa week higher level result were announc had t...
# 7497  surnam brother wa differ often grin home provo...
# 7498  wa primari father die wa veri young then did n...
# 7499  hostel roommat wa veri selfish person avoid do...
# 7500  friend had mani femal friend thought were love...
# 7501  past use think mother wa veri nag person start...
# 7502  august,1983 long await big envelop document c....
# 7503  christma eve,1984 had just finish exam wa afra...
# 7504  septemb wa forc live someon did not first week...
# 7505  issu worri rather sadden mid septemb went guan...
# 7506  roommat like listen meaningless song had melod...
# 7507  last summer went camp c.u student wa work then...
# 7508                                   lie best friend
# 7509                      receiv letter distant friend
# 7510  parent were wa eldest home midnight male stran...
# 7511  year back someon invit tutor grand-daught gran...
# 7512  had taken respons someth had prepar howev fail...
# 7513  wa home heard loud sound spit door thought fam...
# 7514  did not homework teacher had ask wa scold immedi
# 7515  had shout younger brother wa alway afraid call...
#
#                                                       3          4
# 0     [day, feel, close, partner, other, friend, fee...      [joy]
# 1     [time, imagin, someon, love, contact, seriou, ...     [fear]
# 2     [had, been, obvious, unjustli, treat, had, pos...    [anger]
# 3     [think, short, time, live, relat, period, life...  [sadness]
# 4     [gather, found, involuntarili, sit, next, peop...  [disgust]
# 5     [realiz, wa, direct, feel, discont, partner, w...    [shame]
# 6     [feel, guilti, realiz, consid, materi, thing, ...    [guilt]
# 7     [girlfriend, had, taken, exam, went, parent, p...      [joy]
# 8                    [first, time, realiz, mean, death]     [fear]
# 9                     [car, overtak, forc, drive, road]    [anger]
# 10    [recent, thought, hard, work, take, studi, wan...  [sadness]
# 11                   [found, bristl, liver, past, tube]  [disgust]
# 12    [wa, tire, unmotiv, shout, girlfriend, brought...    [shame]
# 13    [think, not, studi, enough, weekend, think, ha...    [guilt]
# 14           [pass, examin, did, not, think, did, well]      [joy]
# 15    [one, ha, arrang, meet, someon, person, arriv,...     [fear]
# 16             [unjustli, accus, someth, ha, not, done]    [anger]
# 17    [one, studi, seem, hopelessli, difficult, unin...  [sadness]
# 18    [find, someon, know, not, had, thought, instan...  [disgust]
# 19    [one, ha, been, unjust, stupid, toward, someon...    [shame]
# 20       [one, ha, neglect, been, unjust, good, friend]    [guilt]
# 21                 [pass, exam, did, not, expect, pass]      [joy]
# 22    [climb, tree, pick, appl, angl, ladder, wa, di...     [fear]
# 23                     [excus, are, necessari, get, do]    [guilt]
# 24                                      [had, children]      [joy]
# 25    [year, old, son, climb, sat, 7th, floor, balco...     [fear]
# 26                   [partner, wa, attack, lost, teeth]    [anger]
# 27     [see, children, t.v, area, devast, drought, war]  [sadness]
# 28    [nearli, walk, blindworm, then, saw, crawl, away]  [disgust]
# 29    [saw, year, old, son, grab, oxygen, mask, had,...    [shame]
# ...                                                 ...        ...
# 7486      [forgot, zip, trouser, wa, not, notic, anyon]    [shame]
# 7487                                             [peep]    [guilt]
# 7488     [had, picnic, old, classmat, chat, play, game]      [joy]
# 7489  [night, wa, alon, home, famili, member, usual,...     [fear]
# 7490  [saw, bed, hostel, wa, mess, guess, someon, el...    [anger]
# 7491  [physic, experi, session, did, not, understand...  [sadness]
# 7492  [man, sexual, aggress, small, girl, bu, girl, ...  [disgust]
# 7493                        [be, unabl, stop, urin, bu]    [shame]
# 7494  [were, old, peopl, crowd, bu, did, not, have, ...    [guilt]
# 7495  [wa, first, time, gave, birthday, present, fri...      [joy]
# 7496  [wa, week, higher, level, result, were, announ...     [fear]
# 7497  [surnam, brother, wa, differ, often, grin, hom...    [anger]
# 7498  [wa, primari, father, die, wa, veri, young, th...  [sadness]
# 7499  [hostel, roommat, wa, veri, selfish, person, a...     [guit]
# 7500  [friend, had, mani, femal, friend, thought, we...    [shame]
# 7501  [past, use, think, mother, wa, veri, nag, pers...    [guilt]
# 7502  [august,1983, long, await, big, envelop, docum...      [joy]
# 7503  [christma, eve,1984, had, just, finish, exam, ...     [fear]
# 7504  [septemb, wa, forc, live, someon, did, not, fi...    [anger]
# 7505  [issu, worri, rather, sadden, mid, septemb, we...     [fear]
# 7506  [roommat, like, listen, meaningless, song, had...    [anger]
# 7507  [last, summer, went, camp, c.u, student, wa, w...    [shame]
# 7508                                [lie, best, friend]    [shame]
# 7509                  [receiv, letter, distant, friend]      [joy]
# 7510  [parent, were, wa, eldest, home, midnight, mal...     [fear]
# 7511  [year, back, someon, invit, tutor, grand-daugh...    [shame]
# 7512  [had, taken, respons, someth, had, prepar, how...    [shame]
# 7513  [wa, home, heard, loud, sound, spit, door, tho...     [fear]
# 7514  [did, not, homework, teacher, had, ask, wa, sc...    [guilt]
# 7515  [had, shout, younger, brother, wa, alway, afra...     [fear]
#
# [7516 rows x 5 columns]

# %%
'''
Reads the emotion representative words file
'''
def readfile(filename):
    f = open(filename,'r')
    representative_words = []
    for line in f.readlines():
        characters = ["\n", " ", "\r", "\t"]
        new = ''.join([i for i in line if not [e for e in characters if e in i]])
        representative_words.append(new)
    return representative_words

# %%
'''
Makes a list of all words semantically related to an emotion and Stemming
'''
def affect_wordlist(words):
    affect_words = []
    stemmer = PorterStemmer()
    for w in words:
        w_l = w.lower()
        word_stem = stemmer.stem(w_l)
        if word_stem not in affect_words:
            affect_words.append(word_stem)
    return affect_words

# %%
'''
Creating an emotion wordnet
'''
def emotion_word_set(emotions):
    word_set = {}
    for e in emotions:
        representative_words = readfile(e)
        wordlist = affect_wordlist(representative_words)
        word_set[e] = wordlist
    return word_set

# %%
'''
Lexicon based approach - Check for lexicons
'''
def lexicon_based(sentences, word_set):
    text_vector = []
    for sen in sentences:
        s_vector = []
        for word in sen:
            w_vector = {}
            for emo in word_set:
                if word in word_set[emo]:
#                     print word
                    try:
                        if emo not in w_vector[word]:
                            w_vector[word].append(emo)
                    except KeyError:
                        w_vector[word] = [emo]
            if w_vector:
                s_vector.append(w_vector)
        if not s_vector:
            text_vector.append(s_vector)
        else:
            text_vector.append(s_vector)
    return text_vector

# %%
'''
Lexicon based approach - Classify based on lexicons
'''
def classify_lexicon(text_vector, labels, emotion_labels):
    count = 0
    total = 0
    for j in range(len(text_vector)):
        sen = text_vector[j]
        sen_emo = np.empty(len(emotion_labels))
        sen_emo.fill(0)
        if sen:
            total += 1
            w_emo = []
            for word in sen:
                emotions =  list(word.values())[0][0]
#                 print emotions, type(emotions), j
                w_emo.append(emotions)
                i = emotion_labels.index(emotions)
                sen_emo[i] += 1
#             print sen_emo
            winner = np.argwhere(sen_emo == np.amax(sen_emo))
            indices = winner.flatten().tolist()
            for i in indices:
                if emotion_labels[i] == labels[j]:
                    count += 1
                    break
#                 else:
#                     print j, text_vector[j]
    accuracy = count/len(text_vector)
    tot_accuracy = count/total
    return accuracy, tot_accuracy

# %%
e = emotion_word_set(emotion_labels)
l = lexicon_based(c[1],e) 
a, b = classify_lexicon(l, c[0], emotion_labels)
print (a, b)
# Out:
# 0.2273815859499734 0.5397978521794062

# %%
'''
Calculate pmi
'''
def pmi(x, y, sentences):
    count_x = 1
    count_y = 1
    count_xy = 1
    for sen in sentences:
        if x and y in sentences:
            count_xy += 1
            count_x += 1
            count_y += 1
        if x in sentences:
            count_x += 1
        if y in sentences:
            count_y += 1
        result = count_xy/(count_x * count_y)
    return result

# %%
print (a*100, '%')
print (b*100, "%")
# Out:
# 22.73815859499734 %
# 53.97978521794062 %

# %%
'''
Emotion Detector
'''
# c = create_frame(Data)
# emo_word_net = emotion_word_set(emotion_set)
# Out:
# '\nEmotion Detector\n'

# %%
'''
Getting synonyms from wordnet synsets
'''
def get_synonyms():
    syn = {}
    for e in emotion_labels:
        jw = wn.synsets(e)
        for s in jw:
            v = s.name()
            try:
                syn[e].append(wn.synset(v).lemma_names())
            except KeyError:
                syn[e] = wn.synset(v).lemma_names()

# %%
'''
Creating training/testing set for Naive Bayes classifier TextBlob -- Not used
'''
def create_dataset_textblob(sentences, emotions):
    train = []
    sen = []
    emo = []
    for s in sentences:
        sen.append(s)
    for e in emotions:
        emo.append(e)
    for i in range(len(sen)):
        s = sen[i]
        e = emo[i]
        train.append((str(s), e))
    return train

# %%
'''
Testing for Naive Bayes Classifier
'''
def testing(cl, test):
    for s, e in test:
        r = cl.classify(s)
        print (s, e, r)
        if r == e:
            print ("*")

# %%
'''
Create dataset for nltk Naive Bayes
'''
def create_data(sentence, emotion):
    data = []
    for i in range(len(sentence)):
        sen = []
        for s in sentence[i]:
            sen.append(str(s))
        emo = emotion[i]
        data.append((sen, emo))
    return data

# %%
'''
Get all words in dataset
'''
def get_words_in_dataset(dataset):
    all_words = []
    for (words, sentiment) in dataset:
        all_words.extend(words)
    return all_words

# %%
'''
Getting frequency dist of words
'''
def get_word_features(wordlist):
    wordlist = nltk.FreqDist(wordlist)
    word_features = wordlist.keys()
    return word_features

# %%
'''
Extacting features
'''
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
'''
Create test data
'''
def create_test(sentence, emotion):
    data = []
    sen = []
    emo = []
    for s in sentence:
        sen.append(str(s))
    for e in emotion:
        emo.append(e)
    for i in range(len(sen)):
        temp = []
        temp.append(sen[i])
        temp.append(emo[i])
        data.append(temp)
    return data

# %%
'''
Classifier
'''
def classify_dataset(data):
    return \
        classifier.classify(extract_features(nltk.word_tokenize(data)))

# %%
'''
Get accuracy
'''
def get_accuracy(test_data, classifier):
    total = accuracy = float(len(test_data))
    for data in test_data:
        if classify_dataset(data[0]) != data[1]:
#             print data, classify_dataset(data[0]), data[1]
            accuracy -= 1
    print('Total accuracy: %f%% (%d/20).' % (accuracy / total * 100, accuracy))
    final = accuracy / total * 100
    return final

# %%
# Create training and testing data
sen = c[3]
emo = c[0]
l = len(c[3])
limit = (9*l)//10
sente = c[2]
Data = create_data(sen, emo)
test_data = create_test(sente[limit:], emo[limit:])

# %%
# extract the word features out from the training data
word_features = get_word_features(\
                    get_words_in_dataset(Data))

# %%
word_features
# Out:
# dict_keys(['day', 'feel', 'close', 'partner', 'other', 'friend', 'peac', 'also', 'experi', 'contact', 'peopl', 'regard', 'greatli', 'time', 'imagin', 'someon', 'love', 'seriou', 'ill', 'even', 'death', 'had', 'been', 'obvious', 'unjustli', 'treat', 'possibl', 'elucid', 'think', 'short', 'live', 'relat', 'period', 'life', 'did', 'not', 'use', 'gather', 'found', 'involuntarili', 'sit', 'next', 'express', 'opinion', 'consid', 'veri', 'low', 'discrimin', 'realiz', 'wa', 'direct', 'discont', 'way', 'tri', 'put', 'blame', 'instead', 'sort', 'own', 'feeli', 'guilti', 'materi', 'thing', 'more', 'import', 'care', 'rel', 'self-cent', 'girlfriend', 'taken', 'exam', 'went', 'parent', 'place', 'first', 'mean', 'car', 'overtak', 'forc', 'drive', 'road', 'recent', 'thought', 'hard', 'work', 'take', 'studi', 'want', 'someth', 'els', 'read', 'theoret', 'book', 'english', 'understand', 'bristl', 'liver', 'past', 'tube', 'tire', 'unmotiv', 'shout', 'brought', 'neg', 'side', 'charact', 'are', 'actual', 'enough', 'weekend', 'have', 'abl', 'accomplish', 'pass', 'examin', 'well', 'one', 'ha', 'arrang', 'meet', 'person', 'arriv', 'late', 'meantim', 'start', 'gone', 'wrong', 'e.g', 'traffic', 'accid', 'accus', 'done', 'seem', 'hopelessli', 'difficult', 'uninterest', 'find', 'know', 'instanc', 'steal', 'quit', 'unwarr', 'unjust', 'stupid', 'toward', 'neglect', 'good', 'expect', 'climb', 'tree', 'pick', 'appl', 'angl', 'ladder', 'enabl', 'get', 'high', 'impli', 'stabl', 'excus', 'necessari', 'do', 'children', 'year', 'old', 'son', 'sat', '7th', 'floor', 'balconi', 'leg', 'hang', 'hold', 'tightli', 'upper', 'rail', 'easili', 'lost', 'balanc', 'attack', 'teeth', 'see', 't.v', 'area', 'devast', 'drought', 'war', 'nearli', 'walk', 'blindworm', 'then', 'saw', 'crawl', 'away', 'grab', 'oxygen', 'mask', 'breath', 'difficulti', 'bad', 'conscienc', 'stop', 'smoke', 'medic', 'dilat', 'caus', 'sens', 'guilt', 'middl', 'verbal', 'write', 'child', 'born', 'spring', 'ice', 'melt', 'far', 'jetti', 'poke', 'long', 'branch', 'break', 'fell', 'water', 'head', 'act', 'fail', 'drunkard', 'bleed', 'wet', 'disgust', 'turn', 'sadness-unpleas', 'adult', 'caught', 'lie', 'behav', 'badli', 'environ', 'much', 'wors', 'privileg', 'seen', 'knock', 'heard', 'radio', 'footbal', 'match', 'belgium', 'end', 'catastroph', 'sever', 'die', 'normal', 'such', 'lone', 'perhap', 'lot', 'shut', 'appart', 'noth', 'happen', 'particular', 'anyth', 'learn', 'mass', 'media', 'kill', 'go', 'world', 'precis', 'cancel', 'let', 'accept', 'cours', 'financ', 'account', 'bu', 'drove', 'right', 'event', 'frighten', 'wait', 'emerg', 'ward', 'hour', 'began', 'swell', 'summer', 'job', 'nobodi', 'look', 'student', 'just', 'move', 'new', 'ventil', 'kitchen', 'clean', 'drum', 'full', 'mud', 'slime', 'felt', 'elder', 'brother', 'alway', 'relationship', 'asham', 'call', 'talk', 'nowaday', 'caretak', 'employ', 'age', 'prefer', 'lunch', 'personnel', 'rather', 'point', 'cottag', 'larg', 'forest', 'alon', 'while', 'dark', 'railway', 'station', 'good-by', 'crippl', 'rag', 'small', 'itali', 'probabl', 'impost', 'told', 'parti', 'enjoy', 'came', 'along', 'understood', 'fit', 'reason', 'break-up', 'finish', 'absolut', 'certain', 'back', 'denmark', 'yatch', 'storm', 'blown', 'overboard', 'scare', 'till', 'manag', 'onboard', 'lock', 'miss', 'last', 'tram', 'home', 'pour', 'rain', 'worm', 'food', 'eaten', 'intox', 'polic', 'took', 'later', 'hapen', 'overhear', 'meant', 'hear', 'won', 'trip', 'greec', 'competit', 'suspici', 'come', 'elderli', 'man', 'complain', 'unjustifi', 'distrust', 'lectur', 'alcohol', 'stood', 'dribbl', 'counter', 'were', 'discuss', 'guy', 'listen', 'colleagu', 'believ', 'like', 'birthday', 'closest', 'pleasant', 'say', 'happi', 'friday', 'night', 'heavi', 'acquaplan', 'surfac', 'few', 'second', 'mad', 'dad', 'case', 'unrequit', 'smell', 'cucumb', 'masturb', 'help', 'pool', 'flew', 'athen', 'copenhagen', 'holiday', 'plane', 'shake', 'thouhght', 'crash', 'stole', 'bike', 'list', 'acccout', 'god', 'ever', ' ...

# %%
training_set = nltk.classify.util.apply_features(extract_features, Data)

# %%
Data
# Out:
# [(['day',
#    'feel',
#    'close',
#    'partner',
#    'other',
#    'friend',
#    'feel',
#    'peac',
#    'also',
#    'experi',
#    'close',
#    'contact',
#    'peopl',
#    'regard',
#    'greatli'],
#   'joy'),
#  (['time',
#    'imagin',
#    'someon',
#    'love',
#    'contact',
#    'seriou',
#    'ill',
#    'even',
#    'death'],
#   'fear'),
#  (['had', 'been', 'obvious', 'unjustli', 'treat', 'had', 'possibl', 'elucid'],
#   'anger'),
#  (['think',
#    'short',
#    'time',
#    'live',
#    'relat',
#    'period',
#    'life',
#    'think',
#    'did',
#    'not',
#    'use',
#    'short',
#    'time'],
#   'sadness'),
#  (['gather',
#    'found',
#    'involuntarili',
#    'sit',
#    'next',
#    'peopl',
#    'express',
#    'opinion',
#    'consid',
#    'veri',
#    'low',
#    'discrimin'],
#   'disgust'),
#  (['realiz',
#    'wa',
#    'direct',
#    'feel',
#    'discont',
#    'partner',
#    'way',
#    'wa',
#    'tri',
#    'put',
#    'blame',
#    'instead',
#    'sort',
#    'own',
#    'feeli'],
#   'shame'),
#  (['feel',
#    'guilti',
#    'realiz',
#    'consid',
#    'materi',
#    'thing',
#    'more',
#    'import',
#    'care',
#    'rel',
#    'feel',
#    'veri',
#    'self-cent'],
#   'guilt'),
#  (['girlfriend', 'had', 'taken', 'exam', 'went', 'parent', 'place'], 'joy'),
#  (['first', 'time', 'realiz', 'mean', 'death'], 'fear'),
#  (['car', 'overtak', 'forc', 'drive', 'road'], 'anger'),
#  (['recent',
#    'thought',
#    'hard',
#    'work',
#    'take',
#    'studi',
#    'want',
#    'tri',
#    'someth',
#    'els',
#    'read',
#    'theoret',
#    'book',
#    'english',
#    'did',
#    'not',
#    'understand'],
#   'sadness'),
#  (['found', 'bristl', 'liver', 'past', 'tube'], 'disgust'),
#  (['wa',
#    'tire',
#    'unmotiv',
#    'shout',
#    'girlfriend',
#    'brought',
#    'neg',
#    'side',
#    'charact',
#    'are',
#    'actual',
#    'not',
#    'import'],
#   'shame'),
#  (['think',
#    'not',
#    'studi',
#    'enough',
#    'weekend',
#    'think',
#    'have',
#    'been',
#    'abl',
#    'have',
#    'accomplish',
#    'someth',
#    'time'],
#   'guilt'),
#  (['pass', 'examin', 'did', 'not', 'think', 'did', 'well'], 'joy'),
#  (['one',
#    'ha',
#    'arrang',
#    'meet',
#    'someon',
#    'person',
#    'arriv',
#    'late',
#    'meantim',
#    'start',
#    'think',
#    'have',
#    'gone',
#    'wrong',
#    'e.g',
#    'traffic',
#    'accid'],
#   'fear'),
#  (['unjustli', 'accus', 'someth', 'ha', 'not', 'done'], 'anger'),
#  (['one', 'studi', 'seem', 'hopelessli', 'difficult', 'uninterest'],
#   'sadness'),
#  (['find',
#    'someon',
#    'know',
#    'not',
#    'had',
#    'thought',
#    'instanc',
#    'friend',
#    'steal',
#    'thing',
#    'quit',
#    'unwarr'],
#   'disgust'),
#  (['one', 'ha', 'been', 'unjust', 'stupid', 'toward', 'someon', 'els'],
#   'shame'),
#  (['one', 'ha', 'neglect', 'been', 'unjust', 'good', 'friend'], 'guilt'),
#  (['pass', 'exam', 'did', 'not', 'expect', 'pass'], 'joy'),
#  (['climb',
#    'tree',
#    'pick',
#    'appl',
#    'angl',
#    'ladder',
#    'wa',
#    'did',
#    'not',
#    'enabl',
#    'get',
#    'high',
#    'enough',
#    'impli',
#    'ladder',
#    'wa',
#    'not',
#    'veri',
#    'stabl'],
#   'fear'),
#  (['excus', 'are', 'necessari', 'get', 'do'], 'guilt'),
#  (['had', 'children'], 'joy'),
#  (['year',
#    'old',
#    'son',
#    'climb',
#    'sat',
#    '7th',
#    'floor',
#    'balconi',
#    'leg',
#    'hang',
#    'wa',
#    'hold',
#    'tightli',
#    'upper',
#    'rail',
#    'balconi',
#    'have',
#    'easili',
#    'lost',
#    'balanc',
#    'sat'],
#   'fear'),
#  (['partner', 'wa', 'attack', 'lost', 'teeth'], 'anger'),
#  (['see', 'children', 't.v', 'area', 'devast', 'drought', 'war'], 'sadness'),
#  (['nearli', 'walk', 'blindworm', 'then', 'saw', 'crawl', 'away'], 'disgust'),
#  (['saw',
#    'year',
#    'old',
#    'son',
#    'grab',
#    'oxygen',
#    'mask',
#    'had',
#    'breath',
#    'difficulti',
#    'had',
#    'bad',
#    'conscienc',
#    'had',
#    'not',
#    'stop',
#    'smoke',
#    'medic',
#    'dilat',
#    'breath',
#    'tube',
#    'also',
#    'caus',
#    'sens',
#    'guilt'],
#   'shame'),
#  (['experi',
#    'sens',
#    'guilt',
#    'middl',
#    'son',
#    'not',
#    'express',
#    'other',
#    'children',
#    'verbal',
#    'write'],
#   'guilt'),
#  (['child', 'wa', 'born'], 'joy'),
#  (['wa',
#    'spring',
#    'ice',
#    'wa',
#    'melt',
#    'wa',
#    'far',
#    'jetti',
#    'poke',
#    'ice',
#    'long',
#    'branch',
#    'tri',
#    'break',
#    'branch',
#    'went',
#    'ice',
#    'fell',
#    'water',
#    'close',
#    'head'],
#   'fear'),
#  (['unjust', 'accus', 'direct', 'way', 'act', 'someon', 'close'], 'anger'),
#  (['fail', 'examin'], 'sadness'),
#  (['drunkard',
#    'fell',
#    'start',
#    'bleed',
#    'wet',
#    'disgust',
#    'turn',
#    'sadness-unpleas'],
#   'disgust'),
#  (['adult', 'have', 'been', 'caught', 'lie', 'behav', 'badli'], 'shame'),
#  (['environ', 'person', 'much', 'wors', 'realiz', 'privileg'], 'guilt'),
#  (['saw', 'person', 'had', 'not', 'seen', 'long', 'time'], 'joy'),
#  (['child', 'wa', 'nearli', 'knock', 'car'], 'fear'),
#  (['heard',
#    'radio',
#    'footbal',
#    'match',
#    'belgium',
#    'had',
#    'end',
#    'catastroph',
#    'sever',
#    'peopl',
#    'had',
#    'die',
#    'not',
#    'understand',
#    'normal',
#    'peopl',
#    'behav',
#    'such',
#    'way'],
#   'anger'),
#  (['feel',
#    'lone',
#    'perhap',
#    'have',
#    'studi',
#    'lot',
#    'shut',
#    'appart',
#    'noth',
#    'happen',
#    'particular',
#    'time',
#    'anyth',
#    'els'],
#   'sadness'),
#  (['one', 'learn', 'mass', 'media', 'war', 'kill', 'go', 'world'], 'disgust'),
#  (['lie', 'precis', 'cancel', 'meet', 'good', 'friend'], 'shame'),
#  (['let', 'friend'], 'guilt'),
#  (['wa', 'accept', 'cours', 'financ', 'account'], 'joy'),
#  (['bu',
#    'drove',
#    'right',
#    'leg',
#    'event',
#    'wa',
#    'not',
#    'veri',
#    'frighten',
#    'had',
#    'wait',
#    'emerg',
#    'ward',
#    'hour',
#    'then',
#    'leg',
#    'began',
#    'swell',
#    'wa',
#    'frighten'],
#   'fear'),
#  (['summer', 'job', 'nobodi', 'look', 'particular', 'had', 'learn', 'own'],
#   'anger'),
#  (['wa', 'not', 'accept', 'student', 'financ', 'account'], 'sadness'),
#  (['had',
#    'just',
#    'move',
#    'new',
#    'appart',
#    'found',
#    'ventil',
#    'kitchen',
#    'wa',
#    'go',
#    'clean',
#    'found',
#    'drum',
#    'wa',
#    'full',
#    'mud',
#    'slime',
#    'felt',
#    'disgust'],
#   'disgust'),
#  (['elder',
#    'brother',
#    'have',
#    'not',
#    'alway',
#    'had',
#    'good',
#    'relationship',
#    'feel',
#    'asham',
#    'not',
#    'call',
#    'talk',
#    'nowaday'],
#   'shame'),
#  (['summer',
#    'job',
#    'new',
#    'caretak',
#    'had',
#    'been',
#    'employ',
#    'wa',
#    'age',
#    'prefer',
#    'go',
#    'lunch',
#    'account',
#    'personnel',
#    'rather'],
#   'guilt'),
#  (['pass', 'exam', 'point'], 'joy'),
#  (['cottag', 'larg', 'forest', 'wa', 'alon', 'while', 'dark'], 'fear'),
#  (['railway', 'station', 'good-by'], 'sadness'),
#  (['saw',
#    'crippl',
#    'rag',
#    'small',
#    'children',
#    'itali',
#    'wa',
#    'probabl',
#    'impost'],
#   'disgust'),
#  (['told',
#    'friend',
#    'wa',
#    'go',
#    'parti',
#    'not',
#    'enjoy',
#    'came',
#    'along',
#    'understood',
#    'not',
#    'have',
#    'fit',
#    'wa',
#    'someth'],
#   'shame'),
#  (['wa',
#    'reason',
#    'break-up',
#    'friend',
#    'relationship',
#    'girlfriend',
#    'finish'],
#   'guilt'),
#  (['pass', 'exam', 'wa', 'absolut', 'certain', 'had', 'fail'], 'joy'),
#  (['way',
#    'back',
#    'denmark',
#    'friend',
#    'small',
#    'yatch',
#    'wa',
#    'storm',
#    'friend',
#    'wa',
#    'blown',
#    'overboard',
#    'wa',
#    'veri',
#    'scare',
#    'till',
#    'manag',
#    'get',
#    'back',
#    'onboard'],
#   'fear'),
#  (['lock'], 'anger'),
#  (['miss', 'last', 'tram', 'home', 'had', 'walk', 'pour', 'rain'], 'sadness'),
#  (['found', 'worm', 'food', 'had', 'obvious', 'eaten'], 'disgust'),
#  (['friend',
#    'wa',
#    'intox',
#    'polic',
#    'came',
#    'took',
#    'away',
#    'later',
#    'contact',
#    'parent'],
#   'shame'),
#  (['hapen', 'overhear', 'someth', 'wa', 'not', 'meant', 'hear'], 'guilt'),
#  (['won', 'trip', 'greec', 'competit'], 'joy'),
#  (['dark', 'suspici', 'look', 'charact', 'come', 'toward'], 'fear'),
#  (['work', 'elderli', 'man', 'complain', 'unjustifi', 'distrust'], 'anger'),
#  (['had', 'not', 'understood', 'anyth', 'lectur'], 'sadness'),
#  (['alcohol', 'stood', 'dribbl', 'food', 'counter'], 'disgust'),
#  (['friend',
#    'were',
#    'discuss',
#    'good',
#    'look',
#    'guy',
#    'realiz',
#    'had',
#    'been',
#    'listen'],
#   'shame'),
#  (['complain',
#    'colleagu',
#    'manag',
#    'told',
#    'someon',
#    'had',
#    'complain',
#    'colleagu',
#    'came',
#    'believ',
#    'like'],
#   'guilt'),
#  (['friend',
#    'birthday',
#    'parti',
#    'closest',
#    'friend',
#    'wa',
#    'veri',
#    'pleasant',
#    'say',
#    'wa',
#    'happi',
#    'have',
#    'such',
#    'good',
#    'friend'],
#   'joy'),
#  (['way',
#    'home',
#    'friday',
#    'night',
#    'heavi',
#    'rain',
#    'car',
#    'acquaplan',
#    'lost',
#    'contact',
#    'road',
#    'surfac',
#    'few',
#    'second'],
#   'fear'),
#  (['mad', 'dad'], 'anger'),
#  (['case', 'unrequit', 'love'], 'sadness'),
#  (['bad', 'smell', 'cucumb'], 'disgust'),
#  (['nearli', 'caught', 'masturb'], 'shame'),
#  (['not', 'help', 'enough', 'home'], 'guilt'),
#  (['felt', 'veri', 'happi', 'won', 'footbal', 'pool'], 'joy'),
#  (['flew',
#    'athen',
#    'copenhagen',
#    'holiday',
#    'plane',
#    'wa',
#    'caught',
#    'storm',
#    'began',
#    'shake',
#    'thouhght',
#    'were',
#    'go',
#    'crash'],
#   'fear'),
#  (['someon', 'stole', 'bike'], 'anger'),
#  (['saw',
#    'list',
#    'book',
#    'read',
#    'acccout',
#    'cours',
#    'thought',
#    'god',
#    'ever',
#    'manaag'],
#   'sadness'),
#  (['wa',
#    'read',
#    'newspap',
#    'articl',
#    'futur',
#    'foresaw',
#    'eat',
#    'frog-burg',
#    'year',
#    'illustr',
#    'show',
#    'frog',
#    'piec',
#    'bread'],
#   'disgust'),
#  (['drop', 'bottl', 'state', 'liquor', 'store', 'everybobi', 'start', 'laugh'],
#   'shame'),
#  (['wa',
#    'young',
#    'pinch',
#    'store',
#    'wa',
#    'caught',
#    'store',
#    'then',
#    'contact',
#    'parent'],
#   'guilt'),
#  (['whole',
#    'famili',
#    'get',
#    'togeth',
#    'week',
#    'holiday',
#    'everybodi',
#    'feel',
#    'free',
#    'trip',
#    'well',
#    'plan',
#    'work',
#    'well',
#    'enjoy'],
#   'joy'),
#  (['not',
#    'find',
#    'year',
#    'old',
#    'daughter',
#    'ran',
#    'look',
#    'everywher',
#    'not',
#    'find',
#    'final',
#    'found',
#    'had',
#    'gone',
#    'bed',
#    'sleep'],
#   'fear'),
#  (['friend', 'tri', 'put', 'hurt'], 'anger'),
#  (['marriag', 'crise', 'boredom'], 'sadness'),
#  (['someon', 'make', 'advanc', 'doe', 'not', 'want'], 'disgust'),
#  (['discoveri', 'ha', 'onli', 'thought', 'oneself'], 'shame'),
#  (['spank', 'child', 'anger', 'later', 'regret', 'terribl'], 'guilt'),
#  (['pass', 'first', 'examin', 'had', 'repeat'], 'joy'),
#  (['drove',
#    'stockholm',
#    'first',
#    'time',
#    'drove',
#    'stora',
#    'hissingen',
#    'road',
#    'wrong',
#    'exit'],
#   'fear'),
#  (['boyfriend', 'went', 'away', 'month', 'long', 'holiday'], 'anger'),
#  (['last',
#    'year',
#    'work',
#    'summer',
#    'holiday',
#    'studi',
#    'same',
#    'time',
#    'examin',
#    'had',
#    'repeat',
#    'boyfriend',
#    'went',
#    'greec',
#    'holiday',
#    'month'],
#   'sadness'),
#  (['dog', 'left', 'whine', 'shop'], 'disgust'),
#  (['promis', 'help', 'friend', 'weekend', 'did', 'not', 'keep', 'promis'],
#   'shame'),
#  (['realiz', 'had', 'more', 'examin', 'take'], 'guilt'),
#  (['day', 'wa', 'told', 'had', 'been', 'accept', 'student', 'econom'], 'joy'),
#  (['take',
#    'short',
#    'cut',
#    'vasa',
#    'park',
#    'wa',
#    'surround',
#    'peopl',
#    'tri',
#    'steal',
#    'money',
#    'wa',
#    'scare',
#    'wa',
#    'save',
#    'onli',
#    'appear',
#    'other',
#    'peopl'],
#   'fear'),
#  (['restaur',
#    'observ',
#    'gypsi',
#    'tri',
#    'get',
#    'money',
#    'cheat',
#    'foreign',
#    'i.e',
#    'non',
#    'swedish',
#    'speak',
#    'anger',
#    'had',
#    'noth',
#    'hatr',
#    'foreign',
#    'wa',
#    'express',
#    'anger',
#    'feel',
#    'see',
#    'peopl',
#    'be',
#    'use'],
#   'anger'),
#  (['begin',
#    'new',
#    'cours',
#    'afraid',
#    'encount',
#    'problem',
#    'not',
#    'manag',
#    'thought',
#    'revolv',
#    'fail',
#    'subject',
#    'consequ',
#    'have',
#    'futur'],
#   'sadness'),
#  (['walk',
#    'town',
#    'notic',
#    'polic',
#    'harrass',
#    'man',
#    'wa',
#    'influenc',
#    'alcohol',
#    'terrifi',
#    'thought',
#    'arrest',
#    'drive',
#    'close',
#    'pedestrian',
#    'street',
#    'disgust',
#    'wa',
#    'direct',
#    'gestur',
#    'facial',
#    'express',
#    'policemen',
#    'seem',
#    'enjoy'],
#   'disgust'),
#  (['boyfriend',
#    'reveal',
#    'knew',
#    'had',
#    'discov',
#    'thing',
#    'import',
#    'natur',
#    'felt',
#    'asham',
#    'had',
#    'not',
#    'mention',
#    'earlier'],
#   'shame'),
#  (['dishonest',
#    'friend',
#    'veri',
#    'close',
#    'feel',
#    'guilti',
#    'know',
#    'give',
#    'differ',
#    'version',
#    'truth',
#    'have',
#    'not',
#    'correct',
#    'mistak',
#    'awar',
#    'know',
#    'are',
#    'wrong'],
#   'guilt'),
#  (['found', 'had', 'pass', 'last', 'exam', 'margin', 'mark'], 'joy'),
#  (['father', 'wa', 'ill', 'wa', 'wait', 'result', 'test'], 'fear'),
#  (['got',
#    'caught',
#    'pour',
#    'rain',
#    'last',
#    'thursday',
#    'did',
#    'not',
#    'have',
#    'raincoat'],
#   'anger'),
#  (['fail', 'exam'], 'sadness'),
#  (['had',
#    'not',
#    'prepar',
#    'contribut',
#    'group',
#    'thoroughli',
#    'other',
#    'member',
#    'result',
#    'overal',
#    'result',
#    'wa',
#    'poor'],
#   'shame'),
#  (['father',
#    'work',
#    'hous',
#    'just',
#    'had',
#    'recov',
#    'ill',
#    'wa',
#    'rather',
#    'lazi',
#    'meant',
#    'had',
#    'work',
#    'hard',
#    'wa',
#    'not',
#    'veri',
#    'well',
#    'later'],
#   'guilt'),
#  (['gave',
#    'birth',
#    'son',
#    'saw',
#    'wa',
#    'aliv',
#    'had',
#    'manag',
#    'well',
#    'wa',
#    'born',
#    'month',
#    'too',
#    'earli',
#    'malfunct',
#    'lung',
#    'happen',
#    'year',
#    'ago'],
#   'joy'),
#  (['found',
#    'father',
#    'had',
#    'lung',
#    'cancer',
#    'did',
#    'not',
#    'know',
#    'long',
#    'live'],
#   'fear'),
#  (['colleagu', 'ask', 'help', 'work', 'fact', 'had', 'more', 'time', 'had'],
#   'anger'),
#  (['did',
#    'not',
#    'get',
#    'salari',
#    'increas',
#    'had',
#    'been',
#    'expect',
#    'understood',
#    'littl',
#    'work',
#    'wa',
#    'appreci'],
#   'sadness'),
#  (['wa', 'weed', 'garden', 'found', 'lizard', 'hand'], 'disgust'),
#  (['met',
#    'friend',
#    'had',
#    'not',
#    'seen',
#    'long',
#    'time',
#    'heard',
#    'troubl',
#    'thought',
#    'have',
#    'got',
#    'touch',
#    'earlier'],
#   'shame'),
#  (['got',
#    'angri',
#    'mother',
#    'someth',
#    'trivial',
#    'were',
#    'bad',
#    'mood',
#    'father',
#    'wa',
#    'veri',
#    'ill',
#    'knew',
#    'mother',
#    'realli',
#    'need',
#    'support',
#    'had',
#    'react',
#    'wrongli'],
#   'guilt'),
#  (['new',
#    'year',
#    'eve',
#    'met',
#    'girlfriend',
#    'stood',
#    'step',
#    'parent',
#    'home',
#    'kiss',
#    'first',
#    'time'],
#   'joy'),
#  (['wa',
#    'stop',
#    'plain',
#    'cloth',
#    'policemen',
#    'car',
#    'wa',
#    'drive',
#    'had',
#    'overturn',
#    'avenu',
#    'had',
#    'been',
#    'drive',
#    'too',
#    'fast',
#    'wa',
#    'afraid',
#    'wa',
#    'stop',
#    'question',
#    'then',
#    'toild',
#    'situat',
#    'end',
#    'happili',
#    'were',
#    'consequ'],
#   'fear'),
#  (['editor',
#    'chang',
#    'head',
#    'articl',
#    'had',
#    'written',
#    'consid',
#    'head',
#    'derogatori',
#    'person',
#    'had',
#    'written'],
#   'anger'),
#  (['close',
#    'acquaint',
#    'famili',
#    'die',
#    'lung',
#    'cancer',
#    'wa',
#    'expect',
#    'still',
#    'felt',
#    'depress'],
#   'sadness'),
#  (['saw',
#    'pictur',
#    'gothenburg',
#    'post',
#    'total',
#    'demolish',
#    'car',
#    'fatal',
#    'injur',
#    'passeng',
#    'car',
#    'wa',
#    'badli',
#    'damag',
#    "n't",
#    'get',
#    'bodi',
#    'scene',
#    'accid'],
#   'disgust'),
#  (['night',
#    'had',
#    'sexual',
#    'intercours',
#    'man',
#    'sexual',
#    'desir',
#    'curios',
#    'had',
#    'made',
#    'jump',
#    'bed',
#    'asham',
#    'now'],
#   'shame'),
#  (['due',
#    'lazi',
#    'fail',
#    'term',
#    'studi',
#    'complet',
#    'univers',
#    'also',
#    'want',
#    'extent',
#    'protest',
#    'parent',
#    'expect'],
#   'guilt'),
#  (['got', 'loan', 'studi'], 'joy'),
#  (['met',
#    'intox',
#    'peopl',
#    'dubiou',
#    'intent',
#    'back',
#    'alley',
#    'wednesday',
#    'night'],
#   'fear'),
#  (['t.v',
#    'saw',
#    'news',
#    'featur',
#    'south',
#    'africa',
#    'policeman',
#    'attack',
#    'group',
#    'black',
#    'peopl',
#    'whip'],
#   'anger'),
#  (['thought', 'have', 'read', 'bore', 'book', 'page', 'english'], 'sadness'),
#  (['grovel', 'peopl'], 'disgust'),
#  (['inabl', 'assert', 'posit', 'group'], 'shame'),
#  (['experi', 'feel', 'guilt', 'not', 'studi', 'enough'], 'guilt'),
#  (['observ',
#    'someon',
#    'cafeteria',
#    'noisili',
#    'gulp',
#    'food',
#    'have',
#    'extrem',
#    'bad',
#    'manner'],
#   'disgust'),
#  (['guess',
#    'have',
#    'often',
#    'been',
#    'asham',
#    'have',
#    'talk',
#    'badli',
#    'other',
#    'peopl'],
#   'shame'),
#  (['have', 'been', 'angri', 'unpleas', 'toward', 'parent'], 'guilt'),
#  (['sister',
#    'histori',
#    'abort',
#    'stillbirth',
#    'gave',
#    'birth',
#    'perfectli',
#    'healti',
#    'boy'],
#   'joy'),
#  (['sister',
#    'had',
#    'still',
#    'born',
#    'child',
#    'wa',
#    'emot',
#    'veri',
#    'deep',
#    'down',
#    'took',
#    'long',
#    'time',
#    'recov'],
#   'fear'),
#  (['were',
#    'start',
#    'student',
#    'project',
#    'teacher',
#    'talk',
#    'wa',
#    'veri',
#    'neg',
#    'not',
#    'veri',
#    'help'],
#   'anger'),
#  (['boyfriend', 'openli', 'let', 'prefer', 'girl'], 'sadness'),
#  (['felt', 'disgust', 'boyfriend', 'time', 'had', 'left'], 'disgust'),
#  (["n't", 'think'], 'shame'),
#  (['accid',
#    'aunt',
#    'offer',
#    'front',
#    'seat',
#    'car',
#    'next',
#    'driver',
#    'declin',
#    'took',
#    'seat',
#    'wa',
#    'kill',
#    'there',
#    'car',
#    'crash'],
#   'guilt'),
#  (['unexpect', 'visit', 'close', 'friend', 'had', "n't", 'seen', 'year'],
#   'joy'),
#  (['wander', 'mistak', 'safeti', 'zone', 'shoot', 'rang', 'wa', 'shot'],
#   'fear'),
#  (['be', 'treat', 'unfairli'], 'anger'),
#  (['break', 'girl'], 'sadness'),
#  (['noth'], 'disgust'),
#  (['none'], 'shame'),
#  (['littl', 'contact', 'father', 'die'], 'guilt'),
#  (['wa', 'accept', 'student', 'colleg', 'not', 'have', 'thought', 'possibl'],
#   'joy'),
#  (['wa',
#    'first',
#    'arriv',
#    'scene',
#    'accid',
#    'found',
#    'close',
#    'school',
#    'friend',
#    'had',
#    'been',
#    'kill'],
#   'fear'),
#  (['wa',
#    'accus',
#    'have',
#    'done',
#    'someth',
#    'had',
#    "n't",
#    'got',
#    'veri',
#    'angri'],
#   'anger'),
#  (['grandmoth', 'die'], 'sadness'),
#  (['not', 'applic'], 'disgust'),
#  (['coupl',
#    'year',
#    'ago',
#    'summer',
#    'holiday',
#    'wa',
#    'fish',
#    'lake',
#    'husband',
#    'suddenli',
#    'start',
#    'rain',
#    'sun',
#    'wa',
#    'still',
#    'shine',
#    'experienc',
#    'feel',
#    'joy',
#    'happi',
#    'fulfil',
#    'whole',
#    'natur',
#    'wa',
#    'full',
#    'music'],
#   'joy'),
#  (['wa',
#    'alon',
#    'home',
#    'bed',
#    'read',
#    'women',
#    'magazin',
#    'were',
#    'storie',
#    'paranorm',
#    'experi',
#    'leg',
#    'wa',
#    'itch',
#    'stretch',
#    'hand',
#    'scratch',
#    'felt',
#    'strang',
#    'hand',
#    'later',
#    'realiz',
#    'wa',
#    'corner',
#    'blanket'],
#   'fear'),
#  (['went',
#    'lectur',
#    'onc',
#    'again',
#    'had',
#    'been',
#    'cancel',
#    'wa',
#    'second',
#    'time',
#    'had',
#    'neg',
#    'attitud',
#    'lectur'],
#   'anger'),
#  (['heard',
#    'former',
#    'superior',
#    'mine',
#    'had',
#    'die',
#    'wa',
#    'later',
#    'home',
#    'home',
#    'read',
#    'newspap',
#    'thought',
#    'interact',
#    'wa',
#    'longer',
#    'possibl',
#    'limit',
#    'scope',
#    'human',
#    'life',
#    'sad'],
#   'sadness'),
#  (['tram',
#    'wa',
#    'fat',
#    'sickli',
#    'look',
#    'woman',
#    'front',
#    'wa',
#    'ask',
#    'direct',
#    'thick',
#    'voic',
#    'got',
#    'disgust',
#    'smell',
#    'urin',
#    'came',
#    'felt',
#    'choke'],
#   'disgust'),
#  (['were',
#    'home',
#    'husband',
#    'made',
#    'remark',
#    'someth',
#    'had',
#    'done',
#    'perfectli',
#    'friendli',
#    'manner',
#    'deed',
#    'had',
#    'been',
#    'unjust',
#    'knew',
#    'husband',
#    'wa',
#    'right',
#    'therefor',
#    'sens',
#    'shame'],
#   'shame'),
#  (['made',
#    'remark',
#    'sister',
#    'concern',
#    'attitud',
#    'men',
#    'way',
#    'talk',
#    'compar',
#    'acquaint',
#    'mine',
#    'later',
#    'same',
#    'even',
#    'sister',
#    'look',
#    'sad',
#    'felt',
#    'guilti',
#    'sad'],
#   'guilt'),
#  (['had', 'summer', 'job', 'sweden', 'boyfriend', 'came', 'meet', 'birthday'],
#   'joy'),
#  (['went', 'practic', 'sweden', 'summer', 'wa', 'afraid', 'not', 'well'],
#   'fear'),
#  (['holiday',
#    'cottag',
#    'associ',
#    'pal',
#    'came',
#    'wake',
#    'earli',
#    'morn',
#    'bring',
#    'radio',
#    'play',
#    'highest',
#    'volum',
#    'room',
#    'wa',
#    'morn',
#    'servic',
#    'loudest'],
#   'anger'),
#  (['grandmoth', 'die', 'suddenli', 'last', 'summer'], 'sadness'),
#  (['superior',
#    'summer',
#    'job',
#    'swindl',
#    'custom',
#    'much',
#    'onc',
#    'put',
#    'difficult',
#    'situat',
#    'not',
#    'detest'],
#   'disgust'),
#  (['onc',
#    'arriv',
#    'hour',
#    'late',
#    'work',
#    'place',
#    'bank',
#    'wa',
#    'still',
#    'feel',
#    'feebl',
#    'tire'],
#   'shame'),
#  (['associ',
#    'had',
#    'polish',
#    'visitor',
#    'were',
#    'go',
#    'back',
#    'boat',
#    'did',
#    'not',
#    'see',
#    'chairman',
#    'associ'],
#   'guilt'),
#  (['wa',
#    'told',
#    'quit',
#    'unexpectedli',
#    'want',
#    'becom',
#    'vice-chairman',
#    'student',
#    'organis',
#    'wa',
#    'realli',
#    'surpris',
#    'joy',
#    'wa',
#    'first',
#    'emot',
#    'felt',
#    'wa',
#    'succeed'],
#   'joy'),
#  (['tutori',
#    'group',
#    'wa',
#    'soon',
#    'divid',
#    'got',
#    'list',
#    'name',
#    'freshmen',
#    'were',
#    'group',
#    'read',
#    'name',
#    'then',
#    'group',
#    'went',
#    'own',
#    'way',
#    'seminar',
#    'room',
#    'wonder',
#    'cope',
#    'new',
#    'situat',
#    'succeed',
#    'group',
#    'leader'],
#   'fear'),
#  (['were',
#    'disco',
#    'even',
#    'wa',
#    'not',
#    'pleasant',
#    'not',
#    'know',
#    'wa',
#    'angri',
#    'companion',
#    'let',
#    'feel',
#    'bad',
#    'humour',
#    'not',
#    'hide',
#    'feel'],
#   'anger'),
#  (['grandmoth',
#    'die',
#    'mother',
#    'call',
#    'sunday',
#    'morn',
#    'autumn',
#    'way',
#    'mother',
#    'told',
#    'hate',
#    'moment',
#    'sound',
#    'had',
#    'been',
#    'wait',
#    'death',
#    'grandmoth',
#    'had',
#    'lost',
#    'person',
#    'close',
#    'felt',
#    'guilti',
#    'too',
#    'had',
#    'been',
#    'bad',
#    'grandmoth',
#    'late',
#    'had',
#    'not',
#    'remain',
#    'calm',
#    'longer',
#    'understood',
#    'everyth',
#    'well'],
#   'sadness'),
#  (['underground',
#    'station',
#    'drunkard',
#    'came',
#    'speak',
#    'tri',
#    'ask',
#    'someth',
#    'did',
#    'not',
#    'answer',
#    'began',
#    'speak',
#    'companion',
#    'detest',
#    'dirti',
#    'growl',
#    'man'],
#   'disgust'),
#  (['wa',
#    'worri',
#    'task',
#    'relat',
#    'studi',
#    'had',
#    'done',
#    'group',
#    'wa',
#    'talk',
#    'friend',
#    'said',
#    'someth',
#    'neg',
#    'too',
#    'abrupt',
#    'manner',
#    'concern',
#    'work',
#    'partner',
#    'did',
#    'not',
#    'quit',
#    'mean',
#    'said',
#    'felt',
#    'asham',
#    'have',
#    'been',
#    'mean',
#    'enough',
#    'critic',
#    'also',
#    'friend',
#    'mine'],
#   'shame'),
#  (['had',
#    'told',
#    'boyfriend',
#    'did',
#    'not',
#    'want',
#    'relationship',
#    'knew',
#    'wa',
#    'import',
#    'want',
#    'free',
#    'saw',
#    'wa',
#    'difficult',
#    'remain',
#    'firm',
#    'did',
#    'not',
#    'chang',
#    'mind'],
#   'guilt'),
#  (['last',
#    'night',
#    'had',
#    'chat',
#    'fellow',
#    'student',
#    'had',
#    'known',
#    'year',
#    'first',
#    'time',
#    'were',
#    'speak',
#    'same',
#    'languag',
#    'mean',
#    'inspir',
#    'discuss',
#    'encount'],
#   'joy'),
#  (['sometim',
#    'quarrel',
#    'mother',
#    'blame',
#    'have',
#    'not',
#    'way',
#    'been',
#    'connect',
#    'event'],
#   'anger'),
#  (['hear',
#    'death',
#    'grandfath',
#    'first',
#    'not',
#    'believ',
#    'later',
#    'wept',
#    'felt',
#    'situat',
#    'wa',
#    'hopeless',
#    'felt',
#    'lone',
#    'want',
#    'consol'],
#   'sadness'),
#  (['even',
#    'wa',
#    'watch',
#    'littl',
#    'brother',
#    'came',
#    'start',
#    'eat',
#    'food',
#    'had',
#    'brought',
#    'kitchen',
#    'wa',
#    'tri',
#    'concentr',
#    'program'],
#   'disgust'),
#  (['littl',
#    'brother',
#    'wa',
#    'arrest',
#    'polic',
#    'railway',
#    'station',
#    'had',
#    'beer'],
#   'shame'),
#  (['temporari',
#    'job',
#    'have',
#    'restrict',
#    'other',
#    'action',
#    'make',
#    'obey',
#    'veri',
#    'often',
#    'give',
#    'feel',
#    'guilt',
#    'wish',
#    'other',
#    'way',
#    'act'],
#   'guilt'),
#  (['met',
#    'dear',
#    'friend',
#    'mine',
#    'long',
#    'time',
#    'express',
#    'feel',
#    'own',
#    'usual',
#    'way',
#    'mutual',
#    'scold',
#    'abus',
#    'complet',
#    'understand',
#    'touch',
#    'pat',
#    'take',
#    'hand',
#    'other',
#    'person',
#    'etc'],
#   'joy'),
#  (['felt',
#    'fear',
#    'purest',
#    'kind',
#    'car',
#    'accid',
#    'incid',
#    'imag',
#    'horror',
#    'kept',
#    'come',
#    'back',
#    'mind',
#    'wonder',
#    'have',
#    'happen',
#    'sister',
#    'friend',
#    'noth',
#    'veri',
#    'seriou',
#    'actual',
#    'happen'],
#   'fear'),
#  (['boy',
#    'know',
#    'were',
#    'tell',
#    'indec',
#    'manner',
#    'had',
#    'teas',
#    'young',
#    'shi',
#    'girl',
#    'know',
#    'had',
#    'despis',
#    'convict',
#    'scorn',
#    'touch',
#    'got',
#    'veri',
#    'angri',
#    'did',
#    'not',
#    'tri',
#    'conceal',
#    'gave',
#    'back'],
#   'anger'),
#  (['sweetheart',
#    'left',
#    'rather',
#    'decid',
#    'break',
#    'mutual',
#    'consent',
#    'consequ',
#    'were',
#    'unrestrain',
#    'weep',
#    'feel',
#    'loneli',
#    'hopeless',
#    'disconsol',
#    'felt',
#    'find',
#    'friend',
#    'talk',
#    'joy',
#    'forget'],
#   'sadness'),
#  (['sheer',
#    'curios',
#    'went',
#    'see',
#    'pornograph',
#    'movi',
#    'copenhagen',
#    'room',
#    'wa',
#    'full',
#    'men',
#    'pant',
#    'masturb',
#    'veri',
#    'disgust'],
#   'disgust'),
#  (['have',
#    'quarel',
#    'unnecessarili',
#    'reason',
#    'have',
#    'been',
#    'stupidli',
#    'cross',
#    'way'],
#   'shame'),
#  (['forc', 'fill', 'questionnair'], 'guilt'),
#  (['won', 'tenni', 'match'], 'joy'),
#  (['dog', 'ran', 'thin', 'ice', 'last', 'spring'], 'fear'),
#  (['tenni', 'match', 'wa', 'interrupt', 'kid', 'cycl', 'right', 'court'],
#   'anger'),
#  (['celebr',
#    'graduat',
#    'day',
#    'orchestra',
#    'play',
#    'garden',
#    'part',
#    'orchestra'],
#   'joy'),
#  (['risk', 'be', 'involv', 'fight', 'parti'], 'fear'),
#  (['had',
#    'veri',
#    'heavi',
#    'work',
#    'load',
#    'colleagu',
#    'have',
#    'noth',
#    'disturb',
#    'terror',
#    'ring',
#    'i.e',
#    'contin',
#    'interrupt',
#    'telephon'],
#   'anger'),
#  (['exam', 'fail'], 'sadness'),
#  (['overtook',
#    'car',
#    'mainroad',
#    'misjudg',
#    'distanc',
#    'oncom',
#    'car',
#    'result',
#    'toot',
#    'flash',
#    'other',
#    'driver',
#    'have',
#    'collid',
#    'had',
#    'acquaint',
#    'car'],
#   'shame'),
#  (['saw',
#    'neighbour',
#    'same',
#    'appart',
#    'block',
#    'lie',
#    'road',
#    'have',
#    'been',
#    'injur',
#    'ill',
#    'kept',
#    'metr',
#    'away',
#    'did',
#    'not',
#    'help'],
#   'guilt'),
#  (['met', 'old', 'schhol', 'friend', 'school', 'love'], 'joy'),
#  (['wa',
#    'cycl',
#    'school',
#    'nearli',
#    'got',
#    'knock',
#    'car',
#    'too',
#    'close',
#    'did',
#    'not',
#    'give',
#    'swerv',
#    'space'],
#   'fear'),
#  (['wa',
#    'deputi',
#    'manag',
#    'summer',
#    'certain',
#    'deputi',
#    'took',
#    'liberti',
#    'more',
#    'wa',
#    'normal'],
#   'anger'),
#  (['realiz', 'girlfriend', 'like', 'were', 'go', 'separ'], 'sadness'),
#  (['dog', 'dirt', 'thaw', 'spring'], 'disgust'),
#  (['forgot', 'mother', 'birthday'], 'shame'),
#  (['not', 'think', 'anyth', 'just', 'now'], 'guilt'),
#  (['pass', 'last', 'exam'], 'joy'),
#  (['wa', 'nearli', 'knock', 'car'], 'fear'),
#  (['reach', 'bu', 'stop', 'realiz', 'had', 'forgotten', 'bu', 'pass'],
#   'anger'),
#  (['current',
#    'work',
#    'load',
#    'too',
#    'much',
#    'feel',
#    'come',
#    'back',
#    'time',
#    'time'],
#   'sadness'),
#  (['year', 'old', 'son', 'give', 'spontan', 'kiss'], 'joy'),
#  (['someon', 'close', 'travel', 'car', 'delay'], 'fear'),
#  (['someon', 'doe', 'someth', 'wrong', 'affect', 'neg'], 'anger'),
#  (['think', 'parent', 'get', 'old'], 'sadness'),
#  (['not',
#    'have',
#    'time',
#    'other',
#    'peopl',
#    'problem',
#    'mother-in-law',
#    'sometim',
#    'depress',
#    'not',
#    'have',
#    'time',
#    'desir',
#    'strength',
#    'help'],
#   'guilt'),
#  (['ex-colleagu',
#    'ask',
#    'wa',
#    'interest',
#    'work',
#    'account',
#    'need',
#    'clever',
#    'peopl',
#    'had',
#    'immedi',
#    'thought'],
#   'joy'),
#  (['wa',
#    'drive',
#    'deer',
#    'suddenli',
#    'appear',
#    'front',
#    'car',
#    'wa',
#    'lot',
#    'traffic'],
#   'fear'),
#  (['saw', 'report', 't.v', 'news', 'apartheid', 'south', 'africa'], 'anger'),
#  (['girlfriend', 'becam', 'pregnant'], 'joy'),
#  (['nearli', 'collid', 'car'], 'fear'),
#  (['time', 'someon', 'let', 'air', 'tyre', 'cycl'], 'anger'),
#  (['read', 'lot', 'did', 'not', 'rememb', 'anyth'], 'sadness'),
#  (['time', 'had', 'put', 'dog', 'sleep'], 'guilt'),
#  (['long', 'ill'], 'sadness'),
#  (['pass', 'exam'], 'joy'),
#  (['wa',
#    'travel',
#    'tram',
#    'trip',
#    'fell',
#    'door',
#    'thought',
#    'wa',
#    'go',
#    'fall'],
#   'fear'),
#  (['miss', 'tram', 'have', 'run'], 'anger'),
#  (['inabl', 'read', 'book', 'colleg'], 'sadness'),
#  (['guy', 'not', 'interest', 'make', 'advanc'], 'disgust'),
#  (['drink', 'wine', 'too', 'often'], 'shame'),
#  (['not', 'studi', 'enough', 'not', 'understand', 'properli'], 'guilt'),
#  (['work', 'lawyer', 'offic', 'summer', 'got', 'veri', 'good', 'refer'],
#   'joy'),
#  (['had',
#    'been',
#    'watch',
#    'triller',
#    'dark',
#    'night',
#    'countri',
#    'had',
#    'outsid',
#    'toilet',
#    'own'],
#   'fear'),
#  (['accus', 'someth', 'have', 'not', 'done', 'get', 'unbeliev', 'angri'],
#   'anger'),
#  (['began',
#    'read',
#    'thick',
#    'book',
#    'had',
#    'limit',
#    'time',
#    'read',
#    'also',
#    'have',
#    'lot',
#    'work',
#    'not',
#    'keep'],
#   'sadness'),
#  (['someon', 'vomit', 'street'], 'disgust'),
#  (['not',
#    'think',
#    'incid',
#    'have',
#    'felt',
#    'veri',
#    'asham',
#    'are',
#    'small',
#    'incid',
#    'asham',
#    'instanc',
#    'not',
#    'send',
#    'money',
#    'children',
#    'ethiopia'],
#   'shame'),
#  (['had',
#    'lunch',
#    'ex-boyfriend',
#    'did',
#    'not',
#    'mention',
#    'fiance',
#    'felt',
#    'guilti',
#    'fact',
#    'felt',
#    'noth',
#    'ex-boyfriend'],
#   'guilt'),
#  (['wa', 'final', 'qualifi', 'profess'], 'joy'),
#  (['someon', 'attack', 'knife'], 'fear'),
#  (['someon', 'drove', 'car', 'then', 'deni', 'had', 'happen'], 'anger'),
#  (['wa', 'told', 'friend', 'wife', 'had', 'cancer'], 'sadness'),
#  (['saw', 'dog', 'had', 'been', 'knock', 'car'], 'disgust'),
#  (['box', 'child', 'ear'], 'shame'),
#  (['wa', 'fine', 'speed'], 'guilt'),
#  (['stop', 'work', 'had', 'bore', 'job'], 'joy'),
#  (['wa',
#    'go',
#    'home',
#    'car',
#    'late',
#    'one',
#    'night',
#    'wa',
#    'cold',
#    'dark',
#    'windi',
#    'becam',
#    'rather',
#    'panicki',
#    'way',
#    'hous'],
#   'fear'),
#  (['quarrel', 'famili'], 'anger'),
#  (['alon', 'room', 'contact', 'anyon', 'loneli', 'drain'], 'sadness'),
#  (['wa', 'holiday', 'someon', 'vomit', 'front'], 'disgust'),
#  (['empti', 'bucket', 'water', 'hospit'], 'shame'),
#  (['feign', 'sick', 'leav', 'work'], 'guilt'),
#  (['get', 'hug', 'someon', 'love'], 'joy'),
#  (['wa',
#    'drive',
#    'veri',
#    'fast',
#    'small',
#    'road',
#    'met',
#    'oncom',
#    'car',
#    'right',
#    'hand',
#    'bend',
#    'other',
#    'driver',
#    'wa',
#    'own',
#    'side',
#    'road',
#    'had',
#    'skid',
#    'avoid',
#    'collis',
#    'wa',
#    'dark'],
#   'fear'),
#  (['car',
#    'had',
#    'been',
#    'tow',
#    'away',
#    'traffic',
#    'polic',
#    'had',
#    'been',
#    'wrongli',
#    'park',
#    'howev',
#    'sign',
#    'had',
#    'been',
#    'put',
#    'onli',
#    'had',
#    'alreadi',
#    'park'],
#   'anger'),
#  (['oper', 'had', 'stay', 'bed', 'long', 'time'], 'sadness'),
#  (['wa', 'forc', 'stay', 'canteen', 'eat', 'food', 'had', 'not', 'ask', 'got'],
#   'disgust'),
#  (['did', 'not', 'buy', 'had', 'promis'], 'shame'),
#  (['mistak', 'took', 'book', 'librari', 'wa', 'not', 'suppos', 'loan'],
#   'guilt'),
#  (['won', 'unexpect', 'sum', 'money'], 'joy'),
#  (['year',
#    'old',
#    'daughter',
#    'disappear',
#    'moment',
#    'inattent',
#    'wa',
#    'respons'],
#   'fear'),
#  (['colleagu',
#    'ask',
#    'advic',
#    'did',
#    'not',
#    'have',
#    'enough',
#    'confid',
#    'ask',
#    'third',
#    'person'],
#   'anger'),
#  (['want', 'pregnant', 'did', 'not', 'succeed', 'wa', 'depress', 'menstruat'],
#   'sadness'),
#  (['warm', 'bu', 'full', 'peopl', 'someon', 'vomit', 'whole', 'bu', 'stank'],
#   'disgust'),
#  (['complain',
#    'colleagu',
#    'behaviour',
#    'goe',
#    'back',
#    'word',
#    'often',
#    'absent',
#    'irrespons',
#    'found',
#    'wa',
#    'alcohol',
#    'wa',
#    'tri',
#    'fight',
#    'againt',
#    'addict'],
#   'shame'),
#  (['spoke',
#    'mother',
#    'phone',
#    'had',
#    'skin',
#    'cancer',
#    'wa',
#    'wait',
#    'oper',
#    'forgot',
#    'ask',
#    'date',
#    'oper',
#    'just',
#    'finish',
#    'convers',
#    'gave',
#    'date',
#    'pass'],
#   'guilt'),
#  (['wa',
#    'parti',
#    'met',
#    'old',
#    'friend',
#    'adult',
#    'educ',
#    'cours',
#    'had',
#    'not',
#    'met',
#    'year',
#    'had',
#    'thought',
#    'lot',
#    'other',
#    'wonder',
#    'experi'],
#   'joy'),
#  (['wa',
#    'cycl',
#    'park',
#    'late',
#    'night',
#    'peopl',
#    'jump',
#    'wood',
#    'tri',
#    'stop',
#    'were',
#    'shout',
#    'someth',
#    'same',
#    'time'],
#   'fear'),
#  (['close', 'rel', 'tri', 'dissuad', 'studi', 'psycholog', 'low', 'statu'],
#   'anger'),
#  (['had',
#    'long',
#    'discuss',
#    'polit',
#    'acquaint',
#    'wa',
#    'more',
#    'knowledg',
#    'fail',
#    'explain',
#    'point',
#    'view',
#    'wa',
#    'misunderstood',
#    'felt',
#    'depress',
#    'left'],
#   'sadness'),
#  (['read',
#    'newspap',
#    'articl',
#    'young',
#    'girl',
#    'had',
#    'been',
#    'rape',
#    'assault',
#    'night',
#    'sever',
#    'men',
#    'wa',
#    'unconsci'],
#   'disgust'),
#  (['mother',
#    'reveal',
#    'person',
#    'detail',
#    'neg',
#    'aspect',
#    'charact',
#    'other',
#    'peopl',
#    'wa',
#    'present',
#    'unabl',
#    'defend'],
#   'shame'),
#  (['wa',
#    'unfaith',
#    'partner',
#    'onc',
#    'wa',
#    'work',
#    'abroad',
#    'long',
#    'period'],
#   'guilt'),
#  (['recent', 'got', 'appart', 'central', 'gottenburg'], 'joy'),
#  (['saw', 'larg', 'spider', 'crawl', 'wall'], 'fear'),
#  (['employ',
#    'took',
#    'too',
#    'mani',
#    'aspirin',
#    'bad',
#    'back',
#    'also',
#    'drank',
#    'enorm',
#    'amount',
#    'spirit',
#    'wa',
#    'danger',
#    'did',
#    'not',
#    'understand',
#    'had',
#    'done',
#    'anyth',
#    'wrong'],
#   'anger'),
#  (['left', 'new', 'york', 'famili', 'friend'], 'sadness'),
#  (['slept',
#    'guy',
#    'best',
#    'friend',
#    'want',
#    'had',
#    'never',
#    'had',
#    'intercours',
#    'anyon',
#    'had',
#    'terribl',
#    'complex'],
#   'disgust'),
#  (['date',
#    'close',
#    'girlfriend',
#    'boyfriend',
#    'few',
#    'time',
#    'told',
#    'wa',
#    'over',
#    'accept',
#    'found',
#    'finish',
#    'friendship'],
#   'shame'),
#  (['broke',
#    'boyfriend',
#    'year',
#    'wa',
#    'quit',
#    'unexpect',
#    'wa',
#    'particular',
#    'reason',
#    'break',
#    'such',
#    'someon',
#    'els'],
#   'guilt'),
#  (['son', 'return', 'mountain', 'healthi', 'bodi', 'soul'], 'joy'),
#  (['meet', 'new', 'peopl', 'forc', 'collabor'], 'fear'),
#  (['sport',
#    'fishermen',
#    'catch',
#    'gull',
#    'instead',
#    'fish',
#    'hook',
#    'often',
#    'mistak',
#    'make',
#    'angri'],
#   'anger'),
#  (['feel', 'sad', 'event', 'not', 'influenc'], 'sadness'),
#  (['member', 'famili', 'complain', 'food', 'serv', 'disgust'], 'disgust'),
#  (['have',
#    'chosen',
#    'put',
#    'son',
#    'privat',
#    'school',
#    'were',
#    'examin',
#    'mark',
#    'are',
#    'low',
#    'everi',
#    'time',
#    'give',
#    'term',
#    'result',
#    'left',
#    'sens',
#    'guilt'],
#   'guilt'),
#  (['wa', 'inform', 'had', 'been', 'accept', 'student', 'psycholog'], 'joy'),
#  (['wa', 'littl', 'fish', 'boat', 'ran', 'hard', 'weather', 'open', 'sea'],
#   'fear'),
#  (['found',
#    'guy',
#    'wa',
#    'date',
#    'particular',
#    'time',
#    'had',
#    'steadi',
#    'relationship',
#    'go',
#    'someon',
#    'els',
#    'long',
#    'time'],
#   'anger'),
#  (['felt', 'sad', 'depress', 'heard', 'cat', 'had', 'die'], 'sadness'),
#  (['wa',
#    'work',
#    'nurs',
#    'mental',
#    'hospit',
#    'patient',
#    'ate',
#    'content',
#    'patient',
#    'spitoon'],
#   'disgust'),
#  (['primari', 'school', 'vomit', 'front', 'other', 'middl', 'lesson'],
#   'shame'),
#  (['arriv', 'hour', 'late', 'import', 'meet', 'had', 'misunderstood', 'time'],
#   'guilt'),
#  (['wa', 'accept', 'student', 'psycholog'], 'joy'),
#  (['son', 'ha', 'pain', 'leg', 'appar', 'reason'], 'fear'),
#  (['week',
#    'school',
#    'teacher',
#    'sent',
#    'note',
#    'home',
#    'say',
#    'son',
#    'wa',
#    'inattent',
#    'unabl',
#    'lesson'],
#   'anger'),
#  (['thought',
#    'wa',
#    'go',
#    'imposs',
#    'start',
#    'studi',
#    'due',
#    'wrong',
#    'inform',
#    'student',
#    'advisor'],
#   'sadness'),
#  (['certain', 'person', 'lack', 'cleanli', 'home', 'person'], 'disgust'),
#  (['made',
#    'same',
#    'mistak',
#    'had',
#    'accus',
#    'someon',
#    'els',
#    'wa',
#    'obviou',
#    'third',
#    'pereson'],
#   'shame'),
#  (['lost', 'someth', 'wa', 'valuabl', 'sister'], 'guilt'),
#  (['son', 'wa', 'born'], 'joy'),
#  (['nearli',
#    'drown',
#    'ici',
#    'water',
#    'wear',
#    'ice',
#    'skate',
#    'wa',
#    'difficult',
#    'get'],
#   'fear'),
#  (['wa',
#    'point',
#    'problem',
#    'child',
#    'primari',
#    'school',
#    'mother',
#    'took',
#    'teacher',
#    'point',
#    'view'],
#   'anger'),
#  (['wa', 'accus', 'neglect', 'work', 'wrong', 'reason'], 'sadness'),
#  (['parent',
#    'attitud',
#    'toward',
#    'other',
#    'becom',
#    'reconcil',
#    'father',
#    'long-tim',
#    'addict'],
#   'disgust'),
#  (['wa', 'caught', 'steal', 'money', 'father'], 'shame'),
#  (['stole',
#    'coconut',
#    'cake',
#    'recept',
#    'tabl',
#    'put',
#    'mouth',
#    'realiz',
#    'host',
#    'wa',
#    'watch'],
#   'guilt'),
#  (['month',
#    'nation',
#    'servic',
#    'wa',
#    'downgrad',
#    'did',
#    'not',
#    'have',
#    'remain',
#    'month'],
#   'joy'),
#  (['wa', 'reprimand', 'manag', 'hotel', 'work', 'autumn'], 'fear'),
#  (['parent',
#    'drove',
#    'nearbi',
#    'place',
#    'went',
#    'home',
#    'immedi',
#    'instead',
#    'wait',
#    'few',
#    'hour',
#    'have',
#    'easili',
#    'wait'],
#   'anger'),
#  (['ex-girlfriend', 'discov', 'wa', 'certain', 'risk', 'be', 'pregnant'],
#   'sadness'),
#  (['wa',
#    'about',
#    'clean',
#    'drain',
#    'board',
#    'saw',
#    'look',
#    'sink',
#    'live',
#    'student',
#    'hostel'],
#   'disgust'),
#  (['mother', 'caught', 'masturb'], 'shame'),
#  (['onli',
#    'person',
#    'famili',
#    'academ',
#    'have',
#    'look',
#    'younger',
#    'onli',
#    'sister',
#    'better',
#    'respect',
#    'educ',
#    'life',
#    'experi'],
#   'guilt'),
#  (['older',
#    'sister',
#    'told',
#    'wa',
#    'think',
#    'join',
#    'rest',
#    'famili',
#    'winter',
#    'sport',
#    'holiday'],
#   'joy'),
#  (['slept',
#    'chapel',
#    'middl',
#    'night',
#    'realiz',
#    'wa',
#    'someeon',
#    'els',
#    'chapel',
#    'never',
#    'discov',
#    'wa',
#    'wa',
#    'there'],
#   'fear'),
#  (['were',
#    'high',
#    'school',
#    'few',
#    'guy',
#    'sometim',
#    'provok',
#    'friend',
#    'mine',
#    'call',
#    'pig',
#    'then',
#    'grunt',
#    'irrit',
#    'most',
#    'girl',
#    'onc',
#    'girl',
#    'got',
#    'angri',
#    'friend',
#    'said',
#    'someth',
#    'nasti',
#    'made',
#    'terribl',
#    'angri'],
#   'anger'),
#  (['talk',
#    'boyfriend',
#    'phone',
#    'wa',
#    'high',
#    'spirit',
#    'had',
#    'lot',
#    'tell',
#    'had',
#    'been',
#    'look',
#    'forward',
#    'convers',
#    'did',
#    'not',
#    'listen',
#    'extent',
#    'had',
#    'anticip'],
#   'sadness'),
#  (['mother', 'shout', 'child', 'noth'], 'disgust'),
#  (['complain',
#    'mother',
#    'untidi',
#    'kitchen',
#    'loook',
#    'box',
#    'ear',
#    'had',
#    'never',
#    'happen'],
#   'shame'),
#  (['not',
#    'home',
#    'midnight',
#    'call',
#    'home',
#    'ask',
#    'leav',
#    'door',
#    'open',
#    'get',
#    'actual',
#    'woke',
#    'whole',
#    'famili',
#    'call',
#    'late',
#    'mother',
#    'not',
#    'back',
#    'sleep',
#    'had',
#    'confer',
#    'next',
#    'day',
#    'realli',
#    'need',
#    'sleep'],
#   'guilt'),
#  (['got', 'first', 'day', 'here', 'depart'], 'joy'),
#  (['wa',
#    'cycl',
#    'park',
#    'car',
#    'someon',
#    'open',
#    'door',
#    'nearli',
#    'push',
#    'bike',
#    'traffic'],
#   'fear'),
#  (['boyfriend', 'sat', 'night', 'play', 'comput', 'game', 'friend'], 'anger'),
#  (['had', 'leav', 'mother', 'sister', 'week', 'visit'], 'sadness'),
#  (['saw', 'big', 'spider', 'veri', 'close'], 'disgust'),
#  (['ask',
#    'friend',
#    'return',
#    'money',
#    'had',
#    'loan',
#    'then',
#    'rememb',
#    'had',
#    'repay',
#    'sever',
#    'way'],
#   'shame'),
#  (['parent', 'insinu', 'someth', 'other', 'are', 'divorc'], 'guilt'),
#  (['wa', 'ask', 'child', 'godmoth'], 'joy'),
#  (['way', 'ski', 'slope', 'wa', 'difficult', 'steep'], 'fear'),
#  (['mother', 'interf', 'life'], 'anger'),
#  (['wa', 'left', 'alon', 'week-end', 'be', 'prepar'], 'sadness'),
#  (['first',
#    'time',
#    'saw',
#    'surgeon',
#    'cut',
#    'leg',
#    'put',
#    'black',
#    'rubbish',
#    'bag'],
#   'disgust'),
#  (['forgot', 'meet', 'work'], 'shame'),
#  (['demand', 'too', 'much', 'friend'], 'guilt'),
#  (['husband',
#    'suddenli',
#    'came',
#    'see',
#    'new',
#    'job',
#    'brought',
#    'flower',
#    'cake'],
#   'joy'),
#  (['wa', 'nearli', 'attackad', 'man', 'had', 'been', 'chase'], 'fear'),
#  (['father',
#    'ask',
#    'wa',
#    'communist',
#    'same',
#    'time',
#    'made',
#    'clear',
#    'longer',
#    'see',
#    'daughter'],
#   'anger'),
#  (['appli',
#    'job',
#    'thought',
#    'had',
#    'good',
#    'chanc',
#    'get',
#    'wa',
#    'not',
#    'even',
#    'grant',
#    'interview',
#    'did',
#    'not',
#    'get',
#    'job'],
#   'sadness'),
#  (['t.v', 'featur', 'show', 'violat', 'defenceless', 'peopl'], 'disgust'),
#  (['child', 'wa', 'play', 'doctor', 'neighbour', 'boy', 'mother', 'caught'],
#   'shame'),
#  (['husband',
#    'talk',
#    'restrict',
#    'have',
#    'accept',
#    'life',
#    'make',
#    'marriag',
#    'work',
#    'felt',
#    'wa',
#    'direct',
#    'wa',
#    'had',
#    'demand',
#    'chang',
#    'were',
#    'marriag',
#    'counsellor',
#    'then'],
#   'guilt'),
#  (['were',
#    'abl',
#    'afford',
#    'new',
#    'sofa',
#    'leather',
#    'cost',
#    'sek',
#    'had',
#    'wait',
#    'year'],
#   'joy'),
#  (['vertigo', 'stand', 'ladder', 'paint', 'hous'], 'fear'),
#  (['boss',
#    'enrol',
#    'cours',
#    'satisfi',
#    'own',
#    'end',
#    'trampl',
#    'associ',
#    'have',
#    'misfortun',
#    'have',
#    'superior',
#    'cours'],
#   'anger'),
#  (['argu', 'mother', 'way', 'treat', 'children', 'differ'], 'sadness'),
#  (['spit', 'vomit'], 'disgust'),
#  (['spot', 'seat', 'cover', 'husband', 'car'], 'shame'),
#  (['not',
#    'speak',
#    'sister-in-law',
#    'due',
#    'lack',
#    'interest',
#    'relationship',
#    'side'],
#   'guilt'),
#  (['recent',
#    'manag',
#    'get',
#    'first',
#    'consult',
#    'assign',
#    'i.e',
#    'own',
#    'initi'],
#   'joy'),
#  (['wa',
#    'hair',
#    'breadth',
#    'knock',
#    'drunkard',
#    'suddenli',
#    'ran',
#    'street',
#    'fear',
#    'came',
#    'later',
#    'realiz',
#    'have',
#    'happen'],
#   'fear'),
#  (['friend', 'usual', 'forgot', 'ticket', 'home', 'perform', 'miss'], 'anger'),
#  (['elect',
#    'thought',
#    'social',
#    'democrat',
#    'communist',
#    'major',
#    'achiev',
#    'especi',
#    'worker',
#    'share',
#    'fund',
#    'extens'],
#   'sadness'),
#  (['studi',
#    'visit',
#    'chicken',
#    'factori',
#    'butcheri',
#    'smell',
#    'environ',
#    'nois'],
#   'disgust'),
#  (['confess', 'parent', 'involv', 'mope', 'theft'], 'shame'),
#  (['answer',
#    'see',
#    'veri',
#    'littl',
#    'differ',
#    'shame',
#    'guilt',
#    'therefor',
#    'see',
#    'answer',
#    'shame'],
#   'guilt'),
#  (['wa',
#    'appoint',
#    'posit',
#    'trust',
#    'group',
#    'set',
#    'chang',
#    'work',
#    'environ'],
#   'joy'),
#  (['wa',
#    'alon',
#    'cottag',
#    'often',
#    'stay',
#    'wa',
#    'woken',
#    'rustl',
#    'sound',
#    'middl',
#    'night'],
#   'fear'),
#  (['tri',
#    'explain',
#    'plumber',
#    'face',
#    'face',
#    'toilet',
#    'wa',
#    'broken',
#    'did',
#    'not',
#    'believ',
#    'had',
#    'been',
#    'mend',
#    'ten',
#    'time'],
#   'anger'),
#  (['result',
#    'project',
#    'work',
#    'wa',
#    'treat',
#    'nonchalantli',
#    'intead',
#    'be',
#    'critic',
#    'teacher'],
#   'sadness'),
#  (['programm', 'violenc', 'pornographi', 'are', 'shown', 't.v'], 'disgust'),
#  (['talk',
#    'malici',
#    'colleagu',
#    'work',
#    'someon',
#    'els',
#    'immedi',
#    'afterward',
#    'felt',
#    'asham'],
#   'shame'),
#  (['decid', 'take', 'week', 'holiday', 'consult', 'famili', 'first'], 'guilt'),
#  (['girl',
#    'talk',
#    'thing',
#    'relationship',
#    'chang',
#    'becam',
#    'posit',
#    'diificult',
#    'time',
#    'turn',
#    'pleasant'],
#   'joy'),
#  (['not',
#    'land',
#    'plane',
#    'knew',
#    'fuel',
#    'wa',
#    'run',
#    'bad',
#    'weather',
#    'had',
#    'alreadi',
#    'frighten'],
#   'fear'),
#  (['read',
#    'reagan',
#    'tactic',
#    'decis',
#    'concern',
#    'south',
#    'african',
#    'boycott'],
#   'anger'),
#  (['half', 'brother', 'becam', 'serious', 'ill', 'cancer', 'die', 'later'],
#   'sadness'),
#  (['film',
#    'were',
#    'woman',
#    'wa',
#    'attack',
#    'rape',
#    'did',
#    'not',
#    'see',
#    'worst',
#    'had',
#    'desir',
#    'effect',
#    'veri',
#    'strong'],
#   'disgust'),
#  (['made',
#    'comment',
#    'wa',
#    'interpret',
#    'complet',
#    'differ',
#    'had',
#    'meant',
#    'said',
#    'realiz',
#    'mother',
#    'had',
#    'understood'],
#   'shame'),
#  (['had',
#    'promis',
#    'visit',
#    'girlfriend',
#    'differ',
#    'reason',
#    'not',
#    'make',
#    'rang',
#    'later',
#    'tell',
#    'not',
#    'come'],
#   'guilt'),
#  (['wa', 'offer', 'high', 'posit', 'trust', 'later', 'accept'], 'joy'),
#  (['had',
#    'window',
#    'open',
#    'door',
#    'wa',
#    'shut',
#    'kitten',
#    'not',
#    'partner',
#    'came',
#    'start',
#    'talk',
#    'someth',
#    'forgot',
#    'window',
#    'suddenli',
#    'saw',
#    'kitten',
#    'hang',
#    'window',
#    'frame',
#    'wa',
#    'rigid',
#    'fright',
#    'till',
#    'got',
#    'hold'],
#   'fear'),
#  (['noisi',
#    'guest',
#    'arriv',
#    'hotel',
#    'had',
#    'been',
#    'slightli',
#    'irrit',
#    'earlier',
#    'night',
#    'wa',
#    'tri',
#    'sleep',
#    'were',
#    'have',
#    'parti',
#    'went',
#    'yell',
#    'want',
#    'sleep',
#    'had',
#    'get',
#    'earli',
#    'next',
#    'day'],
#   'anger'),
#  (['wa',
#    'told',
#    'had',
#    'not',
#    'been',
#    'success',
#    'get',
#    'job',
#    'had',
#    'been',
#    'expect',
#    'wa',
#    'sure',
#    'wa',
#    'suffici',
#    'qualifi'],
#   'sadness'),
#  (['cat',
#    'vomit',
#    'worm',
#    'came',
#    'wa',
#    'still',
#    'aliv',
#    'wa',
#    'forc',
#    'wipe'],
#   'disgust'),
#  (['wa',
#    'child',
#    'wa',
#    'found',
#    'had',
#    'taken',
#    'cloth',
#    'outdoor',
#    'wa',
#    'summer',
#    'friend',
#    'were',
#    'out',
#    'wood',
#    'had',
#    'felt',
#    'excit',
#    'time',
#    'parent',
#    'discov',
#    'trouser',
#    'were',
#    'back',
#    'front',
#    'felt',
#    'asham'],
#   'shame'),
#  (['stole',
#    'money',
#    'mother',
#    'ask',
#    'later',
#    'wa',
#    'respons',
#    'never',
#    'admit'],
#   'guilt'),
#  (['cycl',
#    'spring',
#    'sunshin',
#    'give',
#    'such',
#    'delight',
#    'happi',
#    'healthi',
#    'wonder',
#    'financ',
#    'simpli',
#    'be',
#    'here',
#    'earth'],
#   'joy'),
#  (['relationship',
#    'famili',
#    'veri',
#    'poor',
#    'often',
#    'fear',
#    'be',
#    'exclud',
#    'group',
#    'fear',
#    'stronger',
#    'situat',
#    'argument',
#    'hand'],
#   'fear'),
#  (['recent',
#    'sister',
#    'year',
#    'younger',
#    'veri',
#    'spoil',
#    'shout',
#    'mother',
#    'appar',
#    'reason',
#    'heart-broken',
#    'express',
#    'mother',
#    'face',
#    'made',
#    'feel',
#    'veri',
#    'angri'],
#   'anger'),
#  (['watch',
#    't.v',
#    'programm',
#    'call',
#    'live',
#    'planet',
#    'saw',
#    'far',
#    'reach',
#    'environment',
#    'destruct',
#    'caus',
#    'man'],
#   'sadness'),
#  (['disgust',
#    'feel',
#    'have',
#    'never',
#    'experienc',
#    'peopli',
#    'other',
#    'hand',
#    'ha',
#    'been',
#    'repuls',
#    'anim',
#    'snake',
#    't.v'],
#   'disgust'),
#  (['rel', 'have', 'act', 'strang', 'unfriendli', 'toward'], 'shame'),
#  (['due',
#    'hunger',
#    'tired',
#    'becam',
#    'gener',
#    'irrit',
#    'fiance',
#    'made',
#    'cut',
#    'remark',
#    'realli',
#    'hurt',
#    'later',
#    'realiz',
#    'unfound',
#    'irrit',
#    'had',
# ...
#    'etiquett',
#    'act',
#    'tactlessli',
#    'ignor'],
#   'shame'),
#  (['reberbahn',
#    'wa',
#    'restaur',
#    'drink',
#    'were',
#    'overpr',
#    'did',
#    'not',
#    'ask',
#    'price',
#    'beforehand',
#    'bill',
#    'came',
#    'not',
#    'pay',
#    'bill'],
#   'guilt'),
#  (['girlfriend',
#    'gave',
#    'feed-back',
#    'understood',
#    'meant',
#    'relationship',
#    'wa',
#    'turn',
#    'even',
#    'closer'],
#   'joy'),
#  (['dentist', 'wait', 'turn', 'come'], 'fear'),
#  (['armi',
#    'wa',
#    'treat',
#    'unfairli',
#    'superior',
#    'wa',
#    'held',
#    'respons',
#    'deed',
#    'wa',
#    'innoc'],
#   'anger'),
#  (['came', 'know', 'grandmoth', 'had', 'die', 'wa', 'veri', 'close'],
#   'sadness'),
#  (['armi',
#    'acquaint',
#    'mine',
#    'tend',
#    'use',
#    'posit',
#    'advanc',
#    'own',
#    'interest'],
#   'disgust'),
#  (['lie',
#    'girlfriend',
#    'tell',
#    'had',
#    'pass',
#    'exam',
#    'actual',
#    'did',
#    'not',
#    'even',
#    'take'],
#   'shame'),
#  (['spoke', 'ill', 'fellow', 'worker', 'absenc', 'person'], 'guilt'),
#  (['look', 'peopl', 'know', 'peopl', 'are', 'stupid', 'look', 'stupid'],
#   'joy'),
#  (['saw', 'russian', 'roulett', 'obvious', 'movi', 'deer', 'hunter'], 'fear'),
#  (['stupid', 'peopl', 'rush', 'time', 'citi'], 'anger'),
#  (['lazi', 'make', 'sad'], 'sadness'),
#  (['saw', 'hundr', 'snake', 'twist', 'movi'], 'disgust'),
#  (['saw',
#    'skid-row',
#    'chronic',
#    'alcohol',
#    'wa',
#    'asham',
#    'peopl',
#    'high',
#    'standard',
#    'live'],
#   'shame'),
#  (['shot', 'bird', 'head', 'shotgun'], 'guilt'),
#  (['be', 'close', 'person'], 'joy'),
#  (['uncertainti', 'own', 'abil', 'exam'], 'fear'),
#  (['unfair', 'punish'], 'anger'),
#  (['loneli', 'be', 'uncertain', 'autumn'], 'sadness'),
#  (['rich', 'man', 'express', 'disgust', 'toward', 'alcohol'], 'disgust'),
#  (['went',
#    'doctor',
#    'complaint',
#    'doctor',
#    'told',
#    'wa',
#    'complet',
#    'healthi'],
#   'joy'),
#  (['father',
#    'wa',
#    'away',
#    'home',
#    'did',
#    'not',
#    'come',
#    'back',
#    'wa',
#    'expect',
#    'came',
#    'back',
#    'sever',
#    'hour',
#    'later',
#    'expect'],
#   'fear'),
#  (['had',
#    'implicit',
#    'agreement',
#    'sister',
#    'meet',
#    'howev',
#    'had',
#    'not',
#    'understood',
#    'situat',
#    'same',
#    'way',
#    'did',
#    'not',
#    'turn'],
#   'anger'),
#  (['realiz', 'girl', 'love', 'had', 'leav'], 'sadness'),
#  (['bu',
#    'wa',
#    'sit',
#    'next',
#    'colleag',
#    'wa',
#    'drunk',
#    'behav',
#    'keep',
#    'state'],
#   'disgust'),
#  (['had', 'promis', 'help', 'domest', 'chore', 'forgot'], 'shame'),
#  (['had', 'promis', 'call', 'girl', 'did', 'not'], 'guilt'),
#  (['unexpectedli', 'receiv', 'birthday', 'greet', 'person', 'like'], 'joy'),
#  (['return',
#    'home',
#    'late',
#    'parti',
#    'last',
#    'night',
#    'felt',
#    'afraid',
#    'tri',
#    'anticip',
#    'reaction',
#    'father'],
#   'fear'),
#  (['learn', 'brother', 'had', 'spoilt', 'mine'], 'anger'),
#  (['came', 'know', 'girl', 'wa', 'fond', 'alreadi', 'had', 'boyfriend'],
#   'sadness'),
#  (['too', 'eager', 'approach', 'dirti', 'drunken', 'person', 'bu'], 'disgust'),
#  (['made',
#    'major',
#    'mistak',
#    'learn',
#    'use',
#    'comput',
#    'programm',
#    'teacher',
#    'critic'],
#   'shame'),
#  (['reproach',
#    'mother',
#    'cook',
#    'criticis',
#    'person',
#    'felt',
#    'hurt',
#    'depress'],
#   'guilt'),
#  (['shot', 'decis', 'goal', 'ice-hockey', 'match'], 'joy'),
#  (['got',
#    'lost',
#    'new',
#    'york',
#    'citi',
#    'late',
#    'friday',
#    'night',
#    'friend',
#    'mine'],
#   'fear'),
#  (['have', 'quarel', 'rel', 'mine', 'polit'], 'anger'),
#  (['death', 'grandmoth'], 'sadness'),
#  (['notic', 'nice', 'person', 'wa', 'be', 'exploit', 'econom'], 'disgust'),
#  (['slander', 'person', 'back', 'got', 'know'], 'shame'),
#  (['had',
#    'quarel',
#    'friend',
#    'mine',
#    'later',
#    'realiz',
#    'wa',
#    'also',
#    'fault'],
#   'guilt'),
#  (['pass',
#    'exam',
#    'wa',
#    'not',
#    'sure',
#    'pass',
#    'rejoyc',
#    'result',
#    'possibl',
#    'continu',
#    'studi',
#    'depend'],
#   'joy'),
#  (['traffic',
#    'car',
#    'nearli',
#    'got',
#    'crush',
#    'bu',
#    'tram',
#    'attent',
#    'other',
#    'driver',
#    'save',
#    'last',
#    'moment'],
#   'fear'),
#  (['wa',
#    'disappoint',
#    'angri',
#    'bad',
#    'qualiti',
#    'documentay',
#    'program',
#    'opinion',
#    'topic',
#    'wa',
#    'import',
#    'program',
#    'have',
#    'been',
#    'made',
#    'serious',
#    'consider'],
#   'anger'),
#  (['father',
#    'had',
#    'heart',
#    'attack',
#    'wa',
#    'not',
#    'home',
#    'wa',
#    'still',
#    'live',
#    'recov',
#    'rel',
#    'well',
#    'had',
#    'retir',
#    'impli',
#    'relief',
#    'stress',
#    'small',
#    'scale',
#    'enterpris'],
#   'sadness'),
#  (['grandmoth',
#    'detest',
#    'selfish',
#    'conduct',
#    'toward',
#    'elder',
#    'sister',
#    'behavior',
#    'wa',
#    'due',
#    'senil',
#    'lack',
#    'understand'],
#   'disgust'),
#  (['arriv',
#    'late',
#    'seminar',
#    'concern',
#    'major',
#    'subject',
#    'univers',
#    'had',
#    'been',
#    'appoint',
#    'formal',
#    'oppos',
#    'paper',
#    'wa',
#    'be',
#    'present'],
#   'shame'),
#  (['had',
#    'ask',
#    'salvat',
#    'armi',
#    'take',
#    'piec',
#    'furnitur',
#    'mine',
#    'forgot',
#    'cancel',
#    'agreement',
#    'friend',
#    'mine',
#    'took',
#    'therebi',
#    'caus',
#    'salvat',
#    'armi',
#    'peopl',
#    'unnecessari',
#    'work'],
#   'guilt'),
#  (['cliff', 'sea', 'silenc', 'sudden', 'voic', 'bird', 'swan', 'bay'], 'joy'),
#  (['dark', 'night', 'had', 'outdoor', 'lavatori'], 'fear'),
#  (['realiz',
#    'wa',
#    'far',
#    'other',
#    'languag',
#    'cours',
#    'longer',
#    'catch',
#    'other'],
#   'anger'),
#  (['long',
#    'last',
#    'ill',
#    'grand-moth',
#    'chang',
#    'famili',
#    'relationship',
#    'caus'],
#   'sadness'),
#  (['spoilt',
#    'smash',
#    'mold',
#    'potato',
#    'fridg',
#    'have',
#    'clean',
#    'dish',
#    'later'],
#   'disgust'),
#  (['truth',
#    'express',
#    'unthinkingli',
#    'coffe',
#    'parti',
#    'realiz',
#    'later',
#    'had',
#    'been',
#    'inconsider',
#    'wrong',
#    'moment',
#    'wrong',
#    'place'],
#   'shame'),
#  (['did', 'not', 'exercis', 'adequ', 'reason'], 'guilt'),
#  (['got',
#    'home',
#    'job',
#    'found',
#    'letter',
#    'univers',
#    'tell',
#    'had',
#    'been',
#    'admit',
#    'begin',
#    'studi'],
#   'joy'),
#  (['watch',
#    'war',
#    'movi',
#    'felt',
#    'strong',
#    'fear',
#    'death',
#    'threat',
#    'fear',
#    'loos',
#    'peopl',
#    'close'],
#   'fear'),
#  (['wa', 'angri', 'friend', 'mine', 'behav', 'affect', 'manner'], 'anger'),
#  (['made',
#    'long-dist',
#    'call',
#    'peopl',
#    'rather',
#    'close',
#    'thought',
#    'sad',
#    'incid',
#    'had',
#    'happen',
#    'near',
#    'past',
#    'knew',
#    'were',
#    'think',
#    'too',
#    'made',
#    'call'],
#   'sadness'),
#  (['parent', 'inherit', 'appart', 'made', 'behav', 'peculiar', 'manner'],
#   'disgust'),
#  (['friend', 'let', 'person', 'matter', 'publicali', 'known'], 'shame'),
#  (['think', 'famili', 'parent', 'brother', 'sister', 'guilt', 'part', 'feel'],
#   'guilt'),
#  (['unexpectedli',
#    'met',
#    'girl',
#    'have',
#    'alway',
#    'got',
#    'along',
#    'well',
#    'had',
#    'not',
#    'seen',
#    'sever',
#    'month'],
#   'joy'),
#  (['father', 'wa', 'veri', 'drunk', 'rage', 'home'], 'fear'),
#  (['did', 'not', 'find', 'rack', 'use', 'beat', 'rug', 'yard'], 'anger'),
#  (['cat', 'die', 'diseas'], 'sadness'),
#  (['felt',
#    'disgust',
#    'environ',
#    'get',
#    'back',
#    'student',
#    'lodg',
#    'did',
#    'not',
#    'see',
#    'anyth',
#    'suburb',
#    'had',
#    'been',
#    'plan',
#    'take',
#    'peopl',
#    'comfort',
#    'account'],
#   'disgust'),
#  (['girlfriend',
#    'wa',
#    'away',
#    'visit',
#    'citi',
#    'brought',
#    'girl',
#    'home',
#    'next',
#    'morn',
#    'start',
#    'get',
#    'sober',
#    'felt',
#    'quit',
#    'asham'],
#   'shame'),
#  (['got',
#    'fim',
#    'too',
#    'much',
#    'chang',
#    'money',
#    'bank',
#    'soon',
#    'call',
#    'job',
#    'situat',
#    'wa',
#    'embarras'],
#   'guilt'),
#  (['sweden',
#    'friend',
#    'live',
#    'appart',
#    'own',
#    'finn',
#    'day',
#    'man',
#    'came',
#    'back',
#    'appart',
#    'heavili',
#    'drunk',
#    'hashish',
#    'alcohol',
#    'wa',
#    'quit',
#    'dizzi',
#    'broke',
#    'down',
#    'not',
#    'foretel',
#    'reaction',
#    'howev',
#    'noth',
#    'happen'],
#   'fear'),
#  (['had', 'appoint', 'downtown', 'person', 'question', 'wa', 'hour', 'late'],
#   'anger'),
#  (['death', 'grandmoth'], 'sadness'),
#  (['armi',
#    'had',
#    'been',
#    'hospit',
#    'week',
#    'soon',
#    'return',
#    'compani',
#    'sergeant',
#    'order',
#    'fetch',
#    'load',
#    'tractor',
#    'trailer'],
#   'disgust'),
#  (['way',
#    'back',
#    'summer',
#    'spent',
#    'sweden',
#    'drunk',
#    'man',
#    'train',
#    'had',
#    'drunk',
#    'much',
#    'got',
#    'home',
#    'fell',
#    'asleep',
#    'entranc',
#    'hall',
#    'have',
#    'never',
#    'drunk',
#    'much',
#    'incid',
#    'wa',
#    'asham',
#    'mother',
#    'sister',
#    'had',
#    'see',
#    'state',
#    'father',
#    'had',
#    'carri',
#    'bed'],
#   'shame'),
#  (['primari',
#    'school',
#    'did',
#    'not',
#    'let',
#    'friend',
#    'ring',
#    'bell',
#    'have',
#    'like',
#    'afterward',
#    'felt',
#    'bad'],
#   'guilt'),
#  (['got', 'fairli', 'larg', 'amount', 'tax', 'back'], 'joy'),
#  (['wa',
#    'jog',
#    'forest',
#    'central',
#    'park',
#    'area',
#    'saw',
#    'man',
#    'hide',
#    'tree',
#    'got',
#    'frigthen',
#    'turn',
#    'ran',
#    'forest'],
#   'fear'),
#  (['wa',
#    'come',
#    'home',
#    'taxi',
#    'fellow',
#    'worker',
#    'mine',
#    'wa',
#    'critic',
#    'earlier',
#    'conduct',
#    'mind',
#    'wa',
#    'unfound',
#    'reach',
#    'home',
#    'ran',
#    'taxi',
#    'slam',
#    'door'],
#   'anger'),
#  (['had',
#    'had',
#    'farewel',
#    'parti',
#    'place',
#    'had',
#    'been',
#    'work',
#    'year',
#    'night',
#    'not',
#    'fall',
#    'sleep',
#    'wa',
#    'sad',
#    'think',
#    'not',
#    'see',
#    'nice',
#    'fellow',
#    'worker',
#    'again'],
#   'sadness'),
#  (['wa',
#    'travel',
#    'local',
#    'train',
#    'drunkard',
#    'smell',
#    'terribl',
#    'enter',
#    'same',
#    'carriag',
#    'start',
#    'eat',
#    'fish',
#    'wa',
#    'stink'],
#   'disgust'),
#  (['quarel',
#    'fellow',
#    'worker',
#    'mine',
#    'wa',
#    'vehement',
#    'irrit',
#    'told',
#    'thought',
#    'plain',
#    'languag',
#    'wa',
#    'asham',
#    'met',
#    'next',
#    'day'],
#   'shame'),
#  (['wa',
#    'work',
#    'secretari',
#    'boss',
#    'wa',
#    'give',
#    'lectur',
#    'want',
#    'give',
#    'exact',
#    'address',
#    'place'],
#   'guilt'),
#  (['sunni', 'autumn', 'day', 'long', 'raini', 'period'], 'joy'),
#  (['year', 'ago', 'way', 'school', 'forest', 'path', 'came', 'exhibitionist'],
#   'fear'),
#  (['person',
#    'close',
#    'mistook',
#    'good',
#    'intent',
#    'bad',
#    'therefor',
#    'associ',
#    'unpleas',
#    'trait'],
#   'anger'),
#  (['person', 'close', 'told', 'posit', 'regard', 'depend', 'conduct'],
#   'sadness'),
#  (['untidi', 'heavyli', 'drunk', 'person', 'made', 'endeavour', 'approach'],
#   'disgust'),
#  (['littl',
#    'girl',
#    'wa',
#    'sick',
#    'middl',
#    'school',
#    'day',
#    'vomit',
#    'basin',
#    'classroom'],
#   'shame'),
#  (['lost', 'self-control', 'rais', 'voic', 'child'], 'guilt'),
#  (['got', 'know', 'had', 'been', 'accept', 'univers'], 'joy'),
#  (['had',
#    'been',
#    'watch',
#    'tv-program',
#    'paranorm',
#    'phenomena',
#    'night',
#    'not',
#    'fall',
#    'sleep',
#    'fear',
#    'humanoid',
#    'were',
#    'move'],
#   'fear'),
#  (['superior',
#    'blame',
#    'neglect',
#    'work',
#    'front',
#    'other',
#    'fact',
#    'task',
#    'question',
#    'wa',
#    'not',
#    'suppos',
#    'done'],
#   'anger'),
#  (['father', 'suddenli', 'fell', 'ill', 'die'], 'sadness'),
#  (['friend',
#    'mine',
#    'got',
#    'drunk',
#    'start',
#    'blame',
#    'scorn',
#    'other',
#    'friend'],
#   'disgust'),
#  (['forgot', 'promis', 'made', 'friend', 'mine'], 'shame'),
#  (['wa',
#    'turn',
#    'cook',
#    'dinner',
#    'forgot',
#    'dish',
#    'favourit',
#    'famili',
#    'oven',
#    'got',
#    'burnt',
#    'wa',
#    'uneat'],
#   'guilt'),
#  (['joy',
#    'wa',
#    'joy',
#    'meet',
#    'again',
#    'husband',
#    'came',
#    'home',
#    'have',
#    'been',
#    'away',
#    'week',
#    'work',
#    'wa',
#    'railway',
#    'station',
#    'meet'],
#   'joy'),
#  (['wa',
#    'alon',
#    'home',
#    'hear',
#    'odd',
#    'nois',
#    'come',
#    'bedroom',
#    'knew',
#    'nobodi',
#    'live',
#    'wa',
#    'offic',
#    'got',
#    'frighten',
#    'later',
#    'wa',
#    'given',
#    'natur',
#    'explan'],
#   'fear'),
#  (['rel',
#    'mine',
#    'had',
#    'come',
#    'see',
#    'husband',
#    'talk',
#    'problem',
#    'concern',
#    'sister',
#    'wa',
#    'angri',
#    'rel',
#    'mine',
#    'did',
#    'not',
#    'dare',
#    'speak',
#    'instead',
#    'spoke',
#    'husband',
#    'got',
#    'know',
#    'later',
#    'same',
#    'day'],
#   'anger'),
#  (['death', 'father', 'even', 'had', 'not', 'been', 'veri', 'close', 'other'],
#   'sadness'),
#  (['male', 'friend', 'mother', 'widow', 'move', 'live', 'did', 'not', 'man'],
#   'disgust'),
#  (['school',
#    'wa',
#    'talk',
#    'classmat',
#    'mathemat',
#    'had',
#    'grown',
#    'weari',
#    'said',
#    'like',
#    'throw',
#    'book',
#    'ars',
#    'kuikka',
#    'classmat',
#    'said',
#    'now',
#    'sit',
#    'there',
#    'wait',
#    'book',
#    'kuikka',
#    'wa',
#    'most',
#    'quiet',
#    'boy',
#    'class',
#    'wa',
#    'asham'],
#   'shame'),
#  (['death',
#    'father',
#    'made',
#    'feel',
#    'quit',
#    'guilti',
#    'attitud',
#    'had',
#    'been',
#    'cold',
#    'indiffer'],
#   'guilt'),
#  (['mother',
#    'sister',
#    'were',
#    'think',
#    'about',
#    'old',
#    'time',
#    'childhood',
#    'had',
#    'veri',
#    'happi',
#    'time'],
#   'joy'),
#  (['husband',
#    'had',
#    'gone',
#    'drive',
#    'strang',
#    'broken',
#    'car',
#    'agre',
#    'time',
#    'had',
#    'not',
#    'return',
#    'fear',
#    'had',
#    'had',
#    'accid'],
#   'fear'),
#  (['school',
#    'class',
#    'doe',
#    'not',
#    'obey',
#    'keep',
#    'talk',
#    'doe',
#    'work',
#    'afternoon',
#    'everyth',
#    'went',
#    'wrong',
#    'got',
#    'exceedingli',
#    'angri'],
#   'anger'),
#  (['young',
#    'close',
#    'rel',
#    'mine',
#    'die',
#    'leav',
#    'babi',
#    'few',
#    'month',
#    'old'],
#   'sadness'),
#  (['seri',
#    'freud',
#    'wa',
#    'shown',
#    'tampon',
#    'had',
#    'been',
#    'set',
#    'nose',
#    'woman',
#    'forgotten',
#    'there',
#    'great',
#    'pain',
#    'wa',
#    'taken',
#    'close-up',
#    'pictur',
#    'woman',
#    'wa',
#    'bleed',
#    'nose',
#    'mouth'],
#   'disgust'),
#  (['had',
#    'promis',
#    'lend',
#    'someth',
#    'mother-in-law',
#    'forgot',
#    'coupl',
#    'time',
#    'ask',
#    'third',
#    'time',
#    'wa',
#    'asham',
#    'absent-minded'],
#   'shame'),
#  (['borrow',
#    'car',
#    'broke',
#    'down',
#    'wa',
#    'use',
#    'wa',
#    'not',
#    'fault',
#    'nevertheless',
#    'felt',
#    'guilti'],
#   'guilt'),
#  (['start',
#    'new',
#    'branch',
#    'studi',
#    'have',
#    'fail',
#    'former',
#    'got',
#    'back',
#    'exam',
#    'paper',
#    'wa',
#    'veri',
#    'happi',
#    'know',
#    'almost',
#    'had',
#    'full',
#    'mark'],
#   'joy'),
#  (['wa',
#    'dive',
#    'ice',
#    'cave',
#    'depth',
#    'metr',
#    'visibl',
#    'wa',
#    'almost',
#    'oxygen',
#    'level',
#    'decreas',
#    'threateningli',
#    'were',
#    'diver',
#    'safeti',
#    'rope'],
#   'fear'),
#  (['mother',
#    'carri',
#    'use',
#    'mental',
#    'pressur',
#    'concern',
#    'someth',
#    'wa',
#    'seriou',
#    'real',
#    'burden'],
#   'anger'),
#  (['grandfath', 'die', 'went', 'mortuari', 'saw', 'corps'], 'sadness'),
#  (['same', 'anger'], 'disgust'),
#  (['child', 'wa', 'blame', 'pee', 'swimming-pool'], 'shame'),
#  (['friend',
#    'mine',
#    'wa',
#    'drunk',
#    'have',
#    'argument',
#    'street',
#    'woman',
#    'apppar',
#    'girlfriend',
#    'wa',
#    'walk',
#    'other',
#    'side',
#    'street',
#    'thought',
#    'wa',
#    'not',
#    'suppos',
#    'interfer',
#    'later',
#    'heard',
#    'had',
#    'shot',
#    'even'],
#   'guilt'),
#  (['girlfriend', 'sent', 'letter', 'shini', 'pictur'], 'joy'),
#  (['wa', 'about', 'begin', 'journey', 'car', 'acquaint', 'mine'], 'fear'),
#  (['news',
#    'heard',
#    'nicaragua',
#    'had',
#    'complain',
#    'increas',
#    'threat',
#    'war',
#    'usa'],
#   'anger'),
#  (['girlfriend', 'gave', 'mitten'], 'sadness'),
#  (['watch', 'violent', 'movi'], 'disgust'),
#  (['morn', 'wild', 'parti'], 'shame'),
#  ...]

# %%
str1 = ''.join(list1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-02f19662fde6> in <module>()
# ----> 1 str1 = ''.join(list1)
#
# NameError: name 'list1' is not defined

# %%
from nltk.tokenize import word_tokenize
from itertools import chain
vocabulary = set(chain(*[word_tokenize(i[0][0].lower()) for i in Data]))

# %%
vocabulary
# Out:
# {'classroom',
#  'flat',
#  'won',
#  'ran',
#  'cambridg',
#  'anatomi',
#  'home',
#  'lectur',
#  'realiz',
#  'sever',
#  'certif',
#  'kill',
#  'soil',
#  'stop',
#  'basket',
#  'obscen',
#  'teacher',
#  'patron',
#  'move',
#  'crazi',
#  'bicycl',
#  'difficult',
#  'parent',
#  'b.a',
#  'nightmar',
#  'hour',
#  'scenic',
#  'pass',
#  'wed',
#  'inter-n',
#  'renew',
#  'nearbi',
#  'practic',
#  'intercours',
#  'telephon',
#  'sent',
#  'impregn',
#  'event',
#  'small',
#  'butcher',
#  'flatmat',
#  'dean',
#  'affair',
#  'much',
#  'oldest',
#  'permiss',
#  'birth',
#  'program',
#  'criticis',
#  'literatur',
#  'possibl',
#  'run',
#  'storm',
#  'neg',
#  'prolong',
#  'noon',
#  'invent',
#  'let',
#  'disqualif',
#  'junior',
#  'individu',
#  'trivial',
#  'term',
#  'pakeha',
#  'comrad',
#  'hitch',
#  'happpi',
#  'ever',
#  'first',
#  'guilt',
#  'contract',
#  'xma',
#  'realis',
#  'serv',
#  'drunken',
#  'robberi',
#  'daughter',
#  'spend',
#  'employ',
#  'wander',
#  'week',
#  'thunder',
#  'adolesc',
#  'work',
#  'sadistinc',
#  'exboyfriend',
#  'shot',
#  'embark',
#  'iqam',
#  'maori',
#  'brother',
#  'honest',
#  'unknown',
#  'fridg',
#  'right',
#  'borrow',
#  'self',
#  'rich',
#  'second',
#  'headmast',
#  'motorcyclist',
#  'cinema',
#  'forgot',
#  'film',
#  'critic',
#  'bisshop',
#  'gradmoth',
#  'unjustifi',
#  'begggar',
#  'fell',
#  'punjab',
#  'salo',
#  'lose',
#  'custom',
#  'found',
#  'yell',
#  'empti',
#  'sunni',
#  'harass',
#  'wore',
#  'part',
#  'parents-in-law',
#  'letter',
#  'meet',
#  'pick-pocket',
#  'thiev',
#  'sociolog',
#  'same',
#  'swim',
#  'went',
#  'learnt',
#  'reperbahn',
#  'acquaint',
#  'ex-girlfriend',
#  'mum',
#  'chines',
#  'arrang',
#  'rearrang',
#  'destroy',
#  'examn',
#  'english',
#  'fall',
#  'bar',
#  'passeng',
#  'blame',
#  'snap',
#  'happen',
#  'alway',
#  'insult',
#  'shoot',
#  'opt',
#  'shift',
#  'uni',
#  'equivoc',
#  'movi',
#  'dive',
#  'shoulder',
#  'slept',
#  'guess',
#  'reach',
#  'defi',
#  'say',
#  'offend',
#  'cantor',
#  'trip',
#  'inform',
#  'curriculum',
#  'professor',
#  'sour',
#  'feel',
#  'saw',
#  'cours',
#  'fianct',
#  'natur',
#  'shirk',
#  'playground',
#  'open',
#  'superior',
#  'break',
#  'social',
#  'men',
#  'blurt',
#  'instanc',
#  'step',
#  'contin',
#  'secondari',
#  'two-tim',
#  'so-cal',
#  'wait',
#  'joyful',
#  'breakup',
#  'closest',
#  'hate',
#  'niec',
#  'drink',
#  'unfairli',
#  'lost',
#  'confus',
#  'hard',
#  'still',
#  'squeez',
#  'kid',
#  'cigarett',
#  'about',
#  'undeserv',
#  'tiresom',
#  'slam',
#  'mangl',
#  'took',
#  'editor',
#  'bank',
#  'camp',
#  'lover',
#  'sister',
#  'lack',
#  'refus',
#  'escap',
#  'son',
#  'forget',
#  'speak',
#  'crawl',
#  'hors',
#  'spread',
#  'friend',
#  'heat',
#  'sleep',
#  'name',
#  'opinion',
#  'date',
#  'are',
#  'chang',
#  'cross-countri',
#  'hit',
#  'situat',
#  'real',
#  'too',
#  'boarder',
#  'month',
#  'ten-year-old',
#  'documentari',
#  'favourit',
#  'programm',
#  'primari',
#  'talki',
#  'swindl',
#  'also',
#  'discuss',
#  'govern',
#  'tonight',
#  'jealou',
#  'spoilt',
#  'ex-husband',
#  'joke',
#  'pray',
#  'cousin',
#  'find',
#  'fun',
#  'classmat',
#  'observ',
#  'chief',
#  'copi',
#  'short',
#  'start',
#  'academ',
#  'collid',
#  'ignor',
#  'footballmatch',
#  'meddlesom',
#  'afternoon',
#  'adulteri',
#  'group',
#  'truth',
#  'discoveri',
#  'arriv',
#  'soppi',
#  'carneval-parti',
#  'graduat',
#  'partli',
#  'break-up',
#  'separ',
#  'adult',
#  'headmistress',
#  'larg',
#  'warm',
#  'offic',
#  'deni',
#  'wet',
#  'listen',
#  'hero',
#  'mountain',
#  'cook',
#  'betray',
#  'buy',
#  'greatest',
#  'not',
#  'play',
#  'marriag',
#  'specif',
#  'spi',
#  'weather',
#  'one',
#  'scoar',
#  'restaur',
#  'certain',
#  'flew',
#  'abl',
#  'famili',
#  'reoccur',
#  'bump',
#  'score',
#  'repress',
#  'dog',
#  'becam',
#  'depress',
#  'dead',
#  'unfair',
#  'out-pati',
#  'big',
#  'dirti',
#  'die',
#  'cycl',
#  'uncleani',
#  'kind',
#  'pupil',
#  'cano',
#  'elect',
#  'bulgaria',
#  'cancel',
#  'exchang',
#  'somebodi',
#  'punish',
#  'lazi',
#  'secretli',
#  'wake',
#  'older',
#  'former',
#  'again',
#  'scold',
#  'pick',
#  'partner',
#  'child',
#  'dentist',
#  'slap',
#  'associ',
#  'darl',
#  'awok',
#  'prize',
#  'neglect',
#  'danger',
#  'cast',
#  'recurr',
#  'know',
#  'p.t',
#  'abov',
#  'love',
#  'understood',
#  'mischievi',
#  'yesterday',
#  'senior',
#  'sincer',
#  'save',
#  'lunch',
#  'special',
#  'bath',
#  'loneli',
#  'rob',
#  'anybodi',
#  'sound',
#  'shop-assist',
#  'blew',
#  'wa',
#  'gave',
#  'grand',
#  'postgradu',
#  'sad',
#  'housemen',
#  'intim',
#  'long',
#  't.v',
#  'episod',
#  'counterfeit',
#  'scuffl',
#  'purpos',
#  'physic',
#  'middl',
#  'told',
#  'sport',
#  'aunt',
#  'male',
#  'bike',
#  'nephew',
#  'togeth',
#  'motor',
#  'maltreat',
#  'threw',
#  'celebr',
#  'earlier',
#  'obtain',
#  'left',
#  'half',
#  'propos',
#  'anti-pornographi',
#  'ex-colleagu',
#  'littl',
#  'week-end',
#  'easter',
#  'mix',
#  'flet',
#  'rememb',
#  'import',
#  'peer',
#  'plan',
#  'order',
#  'trouser',
#  'parti',
#  'news',
#  'unoffici',
#  'tailor',
#  'hous',
#  'coupl',
#  'dozen',
#  'express',
#  'aeroplan',
#  'fill',
#  'untidi',
#  'ward',
#  'paddl',
#  'follow',
#  'point',
#  'younger',
#  'embarrass',
#  'earth',
#  'dine',
#  'bribe',
#  'boyfriend',
#  'disappoint',
#  'visit',
#  'lie',
#  'fight',
#  'ate',
#  'stand',
#  'allerg',
#  'paramilitari',
#  'treatment',
#  'inabl',
#  'depart',
#  'crowd',
#  'septemb',
#  'wish',
#  'call',
#  'inadvertantli',
#  'year',
#  'toward',
#  'final',
#  'late',
#  'chosen',
#  'shoplift',
#  'religion',
#  'good',
#  'gear',
#  'sportwoman',
#  'unforgiv',
#  'sweetheart',
#  'argu',
#  'cri',
#  'pet',
#  'wurm',
#  '4-letter',
#  'excus',
#  'bad',
#  'shop',
#  'abroad',
#  'jog',
#  'carter',
#  'begin',
#  'hear',
#  'inflamm',
#  'sudden',
#  'loss',
#  'captain',
#  'alon',
#  'unrealis',
#  'departur',
#  'carnav',
#  'bacam',
#  'cottag',
#  'next',
#  'tramp',
#  'church',
#  'risk',
#  'stare',
#  'noisi',
#  'board',
#  'beat',
#  'side',
#  'eat',
#  'dear',
#  'raini',
#  'foreign',
#  'great',
#  'shame',
#  'overslept',
#  'be',
#  'ski',
#  'declar',
#  'slip',
#  'succed',
#  'surnam',
#  'sort',
#  'loos',
#  'due',
#  'hardwar',
#  'wayn',
#  'dreamt',
#  'box',
#  'burglar',
#  'march',
#  'win',
#  'american',
#  'unjust',
#  'overreact',
#  'fire',
#  'relationship',
#  'park',
#  'coach',
#  'co-work',
#  'occas',
#  'enter',
#  'danc',
#  'kiss',
#  'drug',
#  'shout',
#  'detest',
#  'get',
#  'midnight',
#  'present',
#  'did',
#  'girl',
#  'privat',
#  'gigant',
#  'even',
#  'boat',
#  'grade',
#  'fiance',
#  'ditch',
#  'swear',
#  'decemb',
#  'complain',
#  'decid',
#  'kanishka',
#  'sight',
#  'theft',
#  'want',
#  'approv',
#  'typic',
#  'rel',
#  'age',
#  'housesit',
#  'hapen',
#  'stood',
#  'read',
#  'main',
#  'forc',
#  'doctor',
#  'ctitic',
#  'misunderstood',
#  'like',
#  'teenag',
#  'traffic',
#  'masturb',
#  'footbal',
#  'basketbal',
#  'phone',
#  'guinea-pig',
#  'flick',
#  'may',
#  'femal',
#  'blow',
#  'movement',
#  'ad',
#  'wrong',
#  'auditorium',
#  'stroke',
#  'oral',
#  'convers',
#  'greet',
#  'fool',
#  'wrote',
#  'peopl',
#  'colleg',
#  'complet',
#  'boss',
#  'attempt',
#  'temporari',
#  'confront',
#  'mishap',
#  'labour',
#  'everyday',
#  'babi',
#  'transport',
#  'sens',
#  'ride',
#  'lock',
#  'accident',
#  'assault',
#  'gener',
#  'consid',
#  'vacat',
#  'hypocrisi',
#  'kindergarten',
#  'heard',
#  'appli',
#  'few',
#  'low',
#  'guilti',
#  'china',
#  'vividli',
#  'allow',
#  'beaten',
#  'car',
#  'someon',
#  'sometim',
#  'stupid',
#  'way',
#  'landlord',
#  'omit',
#  'sat',
#  'choral',
#  'estrang',
#  'fact',
#  'bought',
#  'join',
#  'experienc',
#  'have',
#  'noth',
#  'quarrel',
#  'spot',
#  'put',
#  'birthday',
#  'deliber',
#  'red-cheek',
#  'broad',
#  'talk',
#  'lot',
#  'bird',
#  'weekend',
#  'zhu',
#  'unexpect',
#  'receiv',
#  'broken',
#  'tutori',
#  'patient',
#  'marri',
#  'sexual',
#  'enrol',
#  'bet',
#  'father',
#  'thief',
#  'fail',
#  'near-accid',
#  'tell',
#  'form',
#  'skunk',
#  'vomit',
#  'sit',
#  'imit',
#  'more',
#  'south',
#  'children',
#  'usual',
#  'drunkard',
#  'environ',
#  'overtook',
#  'discov',
#  'blank',
#  'dark',
#  'reachad',
#  'condit',
#  'murder',
#  'unabl',
#  'describ',
#  'preach',
#  'committe',
#  'just',
#  'particip',
#  'experi',
#  'alcohol',
#  'weak',
#  'student',
#  'view',
#  'fought',
#  'cash',
#  'encourag',
#  'exhaust',
#  'scene',
#  'made',
#  'felt',
#  'lent',
#  'mistak',
#  'utter',
#  'ask',
#  'outrag',
#  'truck',
#  'nativ',
#  'sell',
#  'assist',
#  'rise',
#  'entrust',
#  'gather',
#  'director',
#  'cat',
#  'finish',
#  'joy',
#  'success',
#  'were',
#  'husband',
#  'vertigo',
#  'live',
#  'christma',
#  'young',
#  'imagin',
#  'fit',
#  'sweden',
#  'spent',
#  'accid',
#  'lead',
#  'suffer',
#  'roommat',
#  'now',
#  'doe',
#  'smell',
#  'nuisanc',
#  'invit',
#  'uncertainti',
#  'stole',
#  'pull',
#  'soweto',
#  'nearli',
#  'christian',
#  'threaten',
#  'bu',
#  'best',
#  'lift',
#  'excret',
#  'chat',
#  'encout',
#  'new',
#  'slaughter',
#  'deceiv',
#  'secretari',
#  'hook',
#  'suddenli',
#  "n't",
#  'courtship',
#  'differ',
#  'sail',
#  'comment',
#  'people/press',
#  'admitt',
#  'ideal',
#  'immedi',
#  'trick',
#  'broke-down',
#  'kitten',
#  'face',
#  'dam',
#  'irrit',
#  'flirt',
#  'whatch',
#  'korean',
#  'lesson',
#  'recent',
#  'cue',
#  'climb',
#  'dad',
#  'price',
#  'conflict',
#  'think',
#  'misl',
#  'reluctantli',
#  'appear',
#  'drove',
#  'damag',
#  'penultim',
#  'none',
#  'quit',
#  'leav',
#  'girlfriend',
#  'see',
#  'woke',
#  'afraid',
#  'look',
#  'return',
#  'colleagu',
#  'use',
#  'failur',
#  'steal',
#  'highschool',
#  'demand',
#  'contact',
#  'thing',
#  'disgust',
#  'pig',
#  'wit',
#  'inter-colleg',
#  'busi',
#  'feign',
#  'whole',
#  'militari',
#  'irrevoc',
#  'incid',
#  'grandfath',
#  'spoke',
#  'class',
#  'exam',
#  'angri',
#  'grenad',
#  'moment',
#  'reunion',
#  'disco',
#  'similar',
#  'learn',
#  'train',
#  'act',
#  'initi',
#  'check',
#  'bosom',
#  'behav',
#  'morn',
#  'interview',
#  'prejudic',
#  'provok',
#  'applic',
#  'make',
#  'accept',
#  'splash',
#  'said',
#  'mani',
#  'librari',
#  'caus',
#  'bed',
#  'someth',
#  'death',
#  'remov',
#  'underground',
#  'case',
#  'almost',
#  'cut',
#  'overwhelm',
#  'neighbour',
#  'deepli',
#  'troubl',
#  'boy-friend',
#  'unjustli',
#  'belov',
#  'co-resid',
#  'member',
#  'spank',
#  'give',
#  'man',
#  'railway',
#  'autumn',
#  'biarritz',
#  'road',
#  'demonstr',
#  'wrongli',
#  'saturday',
#  'higher',
#  'spit',
#  'life-partn',
#  'tram',
#  'mathemat',
#  'high',
#  'glad',
#  'uncl',
#  'attend',
#  'seri',
#  'tender',
#  'exampl',
#  'notic',
#  'dress',
#  'red',
#  'sheer',
#  'incomprehens',
#  'reberbahn',
#  'class-mat',
#  'seasid',
#  'began',
#  'ill',
#  'brother-in-law',
#  'current',
#  'boy',
#  'cliff',
#  'engin',
#  'take',
#  'mention',
#  'workmat',
#  'issu',
#  'qualifi',
#  'media',
#  'argument',
#  'medic',
#  'reproach',
#  'turn',
#  'veri',
#  'closer',
#  'cross',
#  'travel',
#  'introduc',
#  'promis',
#  'gang',
#  'southern',
#  'quarel',
#  'over',
#  'watch',
#  'help',
#  'night',
#  'descript',
#  'broke',
#  'articl',
#  'mug',
#  'never',
#  'strike',
#  'go',
#  'drunk',
#  'money',
#  'wife',
#  'hostel',
#  'met',
#  'share',
#  'classifi',
#  'result',
#  'send',
#  'ex-boyfriend',
#  'sweatheart',
#  'n.z',
#  'most',
#  'note',
#  'close',
#  'confess',
#  'grandmoth',
#  'public',
#  'held',
#  'type',
#  'accus',
#  'diagnosi',
#  'thought',
#  'kick',
#  'team',
#  'schoolmat',
#  'india',
#  'mad',
#  'grovel',
#  'examin',
#  'succeed',
#  'motorcycl',
#  'relat',
#  'clean',
#  'slander',
#  'eco-activist',
#  'old',
#  'seriou',
#  'laugh',
#  'hyena',
#  'elder',
#  'tenni',
#  'arm',
#  'do',
#  'occur',
#  'commit',
#  'overhear',
#  'reject',
#  'approach',
#  'school',
#  'last',
#  'time',
#  'carri',
#  'respons',
#  'mom',
#  'knew',
#  'polit',
#  'apart',
#  'come',
#  'mother',
#  'tri',
#  'woman',
#  'flute-teach',
#  'often',
#  'prepar',
#  'august,1983',
#  'anger',
#  'manag',
#  'guy',
#  'robber',
#  'today',
#  'mouth',
#  'monday',
#  'choke',
#  'period',
#  'cassmat',
#  ...}

# %%
for sentence, tag in Data:
    print(sentence)
    print(tag)
# Out:
# ['day', 'feel', 'close', 'partner', 'other', 'friend', 'feel', 'peac', 'also', 'experi', 'close', 'contact', 'peopl', 'regard', 'greatli']
# joy
# ['time', 'imagin', 'someon', 'love', 'contact', 'seriou', 'ill', 'even', 'death']
# fear
# ['had', 'been', 'obvious', 'unjustli', 'treat', 'had', 'possibl', 'elucid']
# anger
# ['think', 'short', 'time', 'live', 'relat', 'period', 'life', 'think', 'did', 'not', 'use', 'short', 'time']
# sadness
# ['gather', 'found', 'involuntarili', 'sit', 'next', 'peopl', 'express', 'opinion', 'consid', 'veri', 'low', 'discrimin']
# disgust
# ['realiz', 'wa', 'direct', 'feel', 'discont', 'partner', 'way', 'wa', 'tri', 'put', 'blame', 'instead', 'sort', 'own', 'feeli']
# shame
# ['feel', 'guilti', 'realiz', 'consid', 'materi', 'thing', 'more', 'import', 'care', 'rel', 'feel', 'veri', 'self-cent']
# guilt
# ['girlfriend', 'had', 'taken', 'exam', 'went', 'parent', 'place']
# joy
# ['first', 'time', 'realiz', 'mean', 'death']
# fear
# ['car', 'overtak', 'forc', 'drive', 'road']
# anger
# ['recent', 'thought', 'hard', 'work', 'take', 'studi', 'want', 'tri', 'someth', 'els', 'read', 'theoret', 'book', 'english', 'did', 'not', 'understand']
# sadness
# ['found', 'bristl', 'liver', 'past', 'tube']
# disgust
# ['wa', 'tire', 'unmotiv', 'shout', 'girlfriend', 'brought', 'neg', 'side', 'charact', 'are', 'actual', 'not', 'import']
# shame
# ['think', 'not', 'studi', 'enough', 'weekend', 'think', 'have', 'been', 'abl', 'have', 'accomplish', 'someth', 'time']
# guilt
# ['pass', 'examin', 'did', 'not', 'think', 'did', 'well']
# joy
# ['one', 'ha', 'arrang', 'meet', 'someon', 'person', 'arriv', 'late', 'meantim', 'start', 'think', 'have', 'gone', 'wrong', 'e.g', 'traffic', 'accid']
# fear
# ['unjustli', 'accus', 'someth', 'ha', 'not', 'done']
# anger
# ['one', 'studi', 'seem', 'hopelessli', 'difficult', 'uninterest']
# sadness
# ['find', 'someon', 'know', 'not', 'had', 'thought', 'instanc', 'friend', 'steal', 'thing', 'quit', 'unwarr']
# disgust
# ['one', 'ha', 'been', 'unjust', 'stupid', 'toward', 'someon', 'els']
# shame
# ['one', 'ha', 'neglect', 'been', 'unjust', 'good', 'friend']
# guilt
# ['pass', 'exam', 'did', 'not', 'expect', 'pass']
# joy
# ['climb', 'tree', 'pick', 'appl', 'angl', 'ladder', 'wa', 'did', 'not', 'enabl', 'get', 'high', 'enough', 'impli', 'ladder', 'wa', 'not', 'veri', 'stabl']
# fear
# ['excus', 'are', 'necessari', 'get', 'do']
# guilt
# ['had', 'children']
# joy
# ['year', 'old', 'son', 'climb', 'sat', '7th', 'floor', 'balconi', 'leg', 'hang', 'wa', 'hold', 'tightli', 'upper', 'rail', 'balconi', 'have', 'easili', 'lost', 'balanc', 'sat']
# fear
# ['partner', 'wa', 'attack', 'lost', 'teeth']
# anger
# ['see', 'children', 't.v', 'area', 'devast', 'drought', 'war']
# sadness
# ['nearli', 'walk', 'blindworm', 'then', 'saw', 'crawl', 'away']
# disgust
# ['saw', 'year', 'old', 'son', 'grab', 'oxygen', 'mask', 'had', 'breath', 'difficulti', 'had', 'bad', 'conscienc', 'had', 'not', 'stop', 'smoke', 'medic', 'dilat', 'breath', 'tube', 'also', 'caus', 'sens', 'guilt']
# shame
# ['experi', 'sens', 'guilt', 'middl', 'son', 'not', 'express', 'other', 'children', 'verbal', 'write']
# guilt
# ['child', 'wa', 'born']
# joy
# ['wa', 'spring', 'ice', 'wa', 'melt', 'wa', 'far', 'jetti', 'poke', 'ice', 'long', 'branch', 'tri', 'break', 'branch', 'went', 'ice', 'fell', 'water', 'close', 'head']
# fear
# ['unjust', 'accus', 'direct', 'way', 'act', 'someon', 'close']
# anger
# ['fail', 'examin']
# sadness
# ['drunkard', 'fell', 'start', 'bleed', 'wet', 'disgust', 'turn', 'sadness-unpleas']
# disgust
# ['adult', 'have', 'been', 'caught', 'lie', 'behav', 'badli']
# shame
# ['environ', 'person', 'much', 'wors', 'realiz', 'privileg']
# guilt
# ['saw', 'person', 'had', 'not', 'seen', 'long', 'time']
# joy
# ['child', 'wa', 'nearli', 'knock', 'car']
# fear
# ['heard', 'radio', 'footbal', 'match', 'belgium', 'had', 'end', 'catastroph', 'sever', 'peopl', 'had', 'die', 'not', 'understand', 'normal', 'peopl', 'behav', 'such', 'way']
# anger
# ['feel', 'lone', 'perhap', 'have', 'studi', 'lot', 'shut', 'appart', 'noth', 'happen', 'particular', 'time', 'anyth', 'els']
# sadness
# ['one', 'learn', 'mass', 'media', 'war', 'kill', 'go', 'world']
# disgust
# ['lie', 'precis', 'cancel', 'meet', 'good', 'friend']
# shame
# ['let', 'friend']
# guilt
# ['wa', 'accept', 'cours', 'financ', 'account']
# joy
# ['bu', 'drove', 'right', 'leg', 'event', 'wa', 'not', 'veri', 'frighten', 'had', 'wait', 'emerg', 'ward', 'hour', 'then', 'leg', 'began', 'swell', 'wa', 'frighten']
# fear
# ['summer', 'job', 'nobodi', 'look', 'particular', 'had', 'learn', 'own']
# anger
# ['wa', 'not', 'accept', 'student', 'financ', 'account']
# sadness
# ['had', 'just', 'move', 'new', 'appart', 'found', 'ventil', 'kitchen', 'wa', 'go', 'clean', 'found', 'drum', 'wa', 'full', 'mud', 'slime', 'felt', 'disgust']
# disgust
# ['elder', 'brother', 'have', 'not', 'alway', 'had', 'good', 'relationship', 'feel', 'asham', 'not', 'call', 'talk', 'nowaday']
# shame
# ['summer', 'job', 'new', 'caretak', 'had', 'been', 'employ', 'wa', 'age', 'prefer', 'go', 'lunch', 'account', 'personnel', 'rather']
# guilt
# ['pass', 'exam', 'point']
# joy
# ['cottag', 'larg', 'forest', 'wa', 'alon', 'while', 'dark']
# fear
# ['railway', 'station', 'good-by']
# sadness
# ['saw', 'crippl', 'rag', 'small', 'children', 'itali', 'wa', 'probabl', 'impost']
# disgust
# ['told', 'friend', 'wa', 'go', 'parti', 'not', 'enjoy', 'came', 'along', 'understood', 'not', 'have', 'fit', 'wa', 'someth']
# shame
# ['wa', 'reason', 'break-up', 'friend', 'relationship', 'girlfriend', 'finish']
# guilt
# ['pass', 'exam', 'wa', 'absolut', 'certain', 'had', 'fail']
# joy
# ['way', 'back', 'denmark', 'friend', 'small', 'yatch', 'wa', 'storm', 'friend', 'wa', 'blown', 'overboard', 'wa', 'veri', 'scare', 'till', 'manag', 'get', 'back', 'onboard']
# fear
# ['lock']
# anger
# ['miss', 'last', 'tram', 'home', 'had', 'walk', 'pour', 'rain']
# sadness
# ['found', 'worm', 'food', 'had', 'obvious', 'eaten']
# disgust
# ['friend', 'wa', 'intox', 'polic', 'came', 'took', 'away', 'later', 'contact', 'parent']
# shame
# ['hapen', 'overhear', 'someth', 'wa', 'not', 'meant', 'hear']
# guilt
# ['won', 'trip', 'greec', 'competit']
# joy
# ['dark', 'suspici', 'look', 'charact', 'come', 'toward']
# fear
# ['work', 'elderli', 'man', 'complain', 'unjustifi', 'distrust']
# anger
# ['had', 'not', 'understood', 'anyth', 'lectur']
# sadness
# ['alcohol', 'stood', 'dribbl', 'food', 'counter']
# disgust
# ['friend', 'were', 'discuss', 'good', 'look', 'guy', 'realiz', 'had', 'been', 'listen']
# shame
# ['complain', 'colleagu', 'manag', 'told', 'someon', 'had', 'complain', 'colleagu', 'came', 'believ', 'like']
# guilt
# ['friend', 'birthday', 'parti', 'closest', 'friend', 'wa', 'veri', 'pleasant', 'say', 'wa', 'happi', 'have', 'such', 'good', 'friend']
# joy
# ['way', 'home', 'friday', 'night', 'heavi', 'rain', 'car', 'acquaplan', 'lost', 'contact', 'road', 'surfac', 'few', 'second']
# fear
# ['mad', 'dad']
# anger
# ['case', 'unrequit', 'love']
# sadness
# ['bad', 'smell', 'cucumb']
# disgust
# ['nearli', 'caught', 'masturb']
# shame
# ['not', 'help', 'enough', 'home']
# guilt
# ['felt', 'veri', 'happi', 'won', 'footbal', 'pool']
# joy
# ['flew', 'athen', 'copenhagen', 'holiday', 'plane', 'wa', 'caught', 'storm', 'began', 'shake', 'thouhght', 'were', 'go', 'crash']
# fear
# ['someon', 'stole', 'bike']
# anger
# ['saw', 'list', 'book', 'read', 'acccout', 'cours', 'thought', 'god', 'ever', 'manaag']
# sadness
# ['wa', 'read', 'newspap', 'articl', 'futur', 'foresaw', 'eat', 'frog-burg', 'year', 'illustr', 'show', 'frog', 'piec', 'bread']
# disgust
# ['drop', 'bottl', 'state', 'liquor', 'store', 'everybobi', 'start', 'laugh']
# shame
# ['wa', 'young', 'pinch', 'store', 'wa', 'caught', 'store', 'then', 'contact', 'parent']
# guilt
# ['whole', 'famili', 'get', 'togeth', 'week', 'holiday', 'everybodi', 'feel', 'free', 'trip', 'well', 'plan', 'work', 'well', 'enjoy']
# joy
# ['not', 'find', 'year', 'old', 'daughter', 'ran', 'look', 'everywher', 'not', 'find', 'final', 'found', 'had', 'gone', 'bed', 'sleep']
# fear
# ['friend', 'tri', 'put', 'hurt']
# anger
# ['marriag', 'crise', 'boredom']
# sadness
# ['someon', 'make', 'advanc', 'doe', 'not', 'want']
# disgust
# ['discoveri', 'ha', 'onli', 'thought', 'oneself']
# shame
# ['spank', 'child', 'anger', 'later', 'regret', 'terribl']
# guilt
# ['pass', 'first', 'examin', 'had', 'repeat']
# joy
# ['drove', 'stockholm', 'first', 'time', 'drove', 'stora', 'hissingen', 'road', 'wrong', 'exit']
# fear
# ['boyfriend', 'went', 'away', 'month', 'long', 'holiday']
# anger
# ['last', 'year', 'work', 'summer', 'holiday', 'studi', 'same', 'time', 'examin', 'had', 'repeat', 'boyfriend', 'went', 'greec', 'holiday', 'month']
# sadness
# ['dog', 'left', 'whine', 'shop']
# disgust
# ['promis', 'help', 'friend', 'weekend', 'did', 'not', 'keep', 'promis']
# shame
# ['realiz', 'had', 'more', 'examin', 'take']
# guilt
# ['day', 'wa', 'told', 'had', 'been', 'accept', 'student', 'econom']
# joy
# ['take', 'short', 'cut', 'vasa', 'park', 'wa', 'surround', 'peopl', 'tri', 'steal', 'money', 'wa', 'scare', 'wa', 'save', 'onli', 'appear', 'other', 'peopl']
# fear
# ['restaur', 'observ', 'gypsi', 'tri', 'get', 'money', 'cheat', 'foreign', 'i.e', 'non', 'swedish', 'speak', 'anger', 'had', 'noth', 'hatr', 'foreign', 'wa', 'express', 'anger', 'feel', 'see', 'peopl', 'be', 'use']
# anger
# ['begin', 'new', 'cours', 'afraid', 'encount', 'problem', 'not', 'manag', 'thought', 'revolv', 'fail', 'subject', 'consequ', 'have', 'futur']
# sadness
# ['walk', 'town', 'notic', 'polic', 'harrass', 'man', 'wa', 'influenc', 'alcohol', 'terrifi', 'thought', 'arrest', 'drive', 'close', 'pedestrian', 'street', 'disgust', 'wa', 'direct', 'gestur', 'facial', 'express', 'policemen', 'seem', 'enjoy']
# disgust
# ['boyfriend', 'reveal', 'knew', 'had', 'discov', 'thing', 'import', 'natur', 'felt', 'asham', 'had', 'not', 'mention', 'earlier']
# shame
# ['dishonest', 'friend', 'veri', 'close', 'feel', 'guilti', 'know', 'give', 'differ', 'version', 'truth', 'have', 'not', 'correct', 'mistak', 'awar', 'know', 'are', 'wrong']
# guilt
# ['found', 'had', 'pass', 'last', 'exam', 'margin', 'mark']
# joy
# ['father', 'wa', 'ill', 'wa', 'wait', 'result', 'test']
# fear
# ['got', 'caught', 'pour', 'rain', 'last', 'thursday', 'did', 'not', 'have', 'raincoat']
# anger
# ['fail', 'exam']
# sadness
# ['had', 'not', 'prepar', 'contribut', 'group', 'thoroughli', 'other', 'member', 'result', 'overal', 'result', 'wa', 'poor']
# shame
# ['father', 'work', 'hous', 'just', 'had', 'recov', 'ill', 'wa', 'rather', 'lazi', 'meant', 'had', 'work', 'hard', 'wa', 'not', 'veri', 'well', 'later']
# guilt
# ['gave', 'birth', 'son', 'saw', 'wa', 'aliv', 'had', 'manag', 'well', 'wa', 'born', 'month', 'too', 'earli', 'malfunct', 'lung', 'happen', 'year', 'ago']
# joy
# ['found', 'father', 'had', 'lung', 'cancer', 'did', 'not', 'know', 'long', 'live']
# fear
# ['colleagu', 'ask', 'help', 'work', 'fact', 'had', 'more', 'time', 'had']
# anger
# ['did', 'not', 'get', 'salari', 'increas', 'had', 'been', 'expect', 'understood', 'littl', 'work', 'wa', 'appreci']
# sadness
# ['wa', 'weed', 'garden', 'found', 'lizard', 'hand']
# disgust
# ['met', 'friend', 'had', 'not', 'seen', 'long', 'time', 'heard', 'troubl', 'thought', 'have', 'got', 'touch', 'earlier']
# shame
# ['got', 'angri', 'mother', 'someth', 'trivial', 'were', 'bad', 'mood', 'father', 'wa', 'veri', 'ill', 'knew', 'mother', 'realli', 'need', 'support', 'had', 'react', 'wrongli']
# guilt
# ['new', 'year', 'eve', 'met', 'girlfriend', 'stood', 'step', 'parent', 'home', 'kiss', 'first', 'time']
# joy
# ['wa', 'stop', 'plain', 'cloth', 'policemen', 'car', 'wa', 'drive', 'had', 'overturn', 'avenu', 'had', 'been', 'drive', 'too', 'fast', 'wa', 'afraid', 'wa', 'stop', 'question', 'then', 'toild', 'situat', 'end', 'happili', 'were', 'consequ']
# fear
# ['editor', 'chang', 'head', 'articl', 'had', 'written', 'consid', 'head', 'derogatori', 'person', 'had', 'written']
# anger
# ['close', 'acquaint', 'famili', 'die', 'lung', 'cancer', 'wa', 'expect', 'still', 'felt', 'depress']
# sadness
# ['saw', 'pictur', 'gothenburg', 'post', 'total', 'demolish', 'car', 'fatal', 'injur', 'passeng', 'car', 'wa', 'badli', 'damag', "n't", 'get', 'bodi', 'scene', 'accid']
# disgust
# ['night', 'had', 'sexual', 'intercours', 'man', 'sexual', 'desir', 'curios', 'had', 'made', 'jump', 'bed', 'asham', 'now']
# shame
# ['due', 'lazi', 'fail', 'term', 'studi', 'complet', 'univers', 'also', 'want', 'extent', 'protest', 'parent', 'expect']
# guilt
# ['got', 'loan', 'studi']
# joy
# ['met', 'intox', 'peopl', 'dubiou', 'intent', 'back', 'alley', 'wednesday', 'night']
# fear
# ['t.v', 'saw', 'news', 'featur', 'south', 'africa', 'policeman', 'attack', 'group', 'black', 'peopl', 'whip']
# anger
# ['thought', 'have', 'read', 'bore', 'book', 'page', 'english']
# sadness
# ['grovel', 'peopl']
# disgust
# ['inabl', 'assert', 'posit', 'group']
# shame
# ['experi', 'feel', 'guilt', 'not', 'studi', 'enough']
# guilt
# ['observ', 'someon', 'cafeteria', 'noisili', 'gulp', 'food', 'have', 'extrem', 'bad', 'manner']
# disgust
# ['guess', 'have', 'often', 'been', 'asham', 'have', 'talk', 'badli', 'other', 'peopl']
# shame
# ['have', 'been', 'angri', 'unpleas', 'toward', 'parent']
# guilt
# ['sister', 'histori', 'abort', 'stillbirth', 'gave', 'birth', 'perfectli', 'healti', 'boy']
# joy
# ['sister', 'had', 'still', 'born', 'child', 'wa', 'emot', 'veri', 'deep', 'down', 'took', 'long', 'time', 'recov']
# fear
# ['were', 'start', 'student', 'project', 'teacher', 'talk', 'wa', 'veri', 'neg', 'not', 'veri', 'help']
# anger
# ['boyfriend', 'openli', 'let', 'prefer', 'girl']
# sadness
# ['felt', 'disgust', 'boyfriend', 'time', 'had', 'left']
# disgust
# ["n't", 'think']
# shame
# ['accid', 'aunt', 'offer', 'front', 'seat', 'car', 'next', 'driver', 'declin', 'took', 'seat', 'wa', 'kill', 'there', 'car', 'crash']
# guilt
# ['unexpect', 'visit', 'close', 'friend', 'had', "n't", 'seen', 'year']
# joy
# ['wander', 'mistak', 'safeti', 'zone', 'shoot', 'rang', 'wa', 'shot']
# fear
# ['be', 'treat', 'unfairli']
# anger
# ['break', 'girl']
# sadness
# ['noth']
# disgust
# ['none']
# shame
# ['littl', 'contact', 'father', 'die']
# guilt
# ['wa', 'accept', 'student', 'colleg', 'not', 'have', 'thought', 'possibl']
# joy
# ['wa', 'first', 'arriv', 'scene', 'accid', 'found', 'close', 'school', 'friend', 'had', 'been', 'kill']
# fear
# ['wa', 'accus', 'have', 'done', 'someth', 'had', "n't", 'got', 'veri', 'angri']
# anger
# ['grandmoth', 'die']
# sadness
# ['not', 'applic']
# disgust
# ['coupl', 'year', 'ago', 'summer', 'holiday', 'wa', 'fish', 'lake', 'husband', 'suddenli', 'start', 'rain', 'sun', 'wa', 'still', 'shine', 'experienc', 'feel', 'joy', 'happi', 'fulfil', 'whole', 'natur', 'wa', 'full', 'music']
# joy
# ['wa', 'alon', 'home', 'bed', 'read', 'women', 'magazin', 'were', 'storie', 'paranorm', 'experi', 'leg', 'wa', 'itch', 'stretch', 'hand', 'scratch', 'felt', 'strang', 'hand', 'later', 'realiz', 'wa', 'corner', 'blanket']
# fear
# ['went', 'lectur', 'onc', 'again', 'had', 'been', 'cancel', 'wa', 'second', 'time', 'had', 'neg', 'attitud', 'lectur']
# anger
# ['heard', 'former', 'superior', 'mine', 'had', 'die', 'wa', 'later', 'home', 'home', 'read', 'newspap', 'thought', 'interact', 'wa', 'longer', 'possibl', 'limit', 'scope', 'human', 'life', 'sad']
# sadness
# ['tram', 'wa', 'fat', 'sickli', 'look', 'woman', 'front', 'wa', 'ask', 'direct', 'thick', 'voic', 'got', 'disgust', 'smell', 'urin', 'came', 'felt', 'choke']
# disgust
# ['were', 'home', 'husband', 'made', 'remark', 'someth', 'had', 'done', 'perfectli', 'friendli', 'manner', 'deed', 'had', 'been', 'unjust', 'knew', 'husband', 'wa', 'right', 'therefor', 'sens', 'shame']
# shame
# ['made', 'remark', 'sister', 'concern', 'attitud', 'men', 'way', 'talk', 'compar', 'acquaint', 'mine', 'later', 'same', 'even', 'sister', 'look', 'sad', 'felt', 'guilti', 'sad']
# guilt
# ['had', 'summer', 'job', 'sweden', 'boyfriend', 'came', 'meet', 'birthday']
# joy
# ['went', 'practic', 'sweden', 'summer', 'wa', 'afraid', 'not', 'well']
# fear
# ['holiday', 'cottag', 'associ', 'pal', 'came', 'wake', 'earli', 'morn', 'bring', 'radio', 'play', 'highest', 'volum', 'room', 'wa', 'morn', 'servic', 'loudest']
# anger
# ['grandmoth', 'die', 'suddenli', 'last', 'summer']
# sadness
# ['superior', 'summer', 'job', 'swindl', 'custom', 'much', 'onc', 'put', 'difficult', 'situat', 'not', 'detest']
# disgust
# ['onc', 'arriv', 'hour', 'late', 'work', 'place', 'bank', 'wa', 'still', 'feel', 'feebl', 'tire']
# shame
# ['associ', 'had', 'polish', 'visitor', 'were', 'go', 'back', 'boat', 'did', 'not', 'see', 'chairman', 'associ']
# guilt
# ['wa', 'told', 'quit', 'unexpectedli', 'want', 'becom', 'vice-chairman', 'student', 'organis', 'wa', 'realli', 'surpris', 'joy', 'wa', 'first', 'emot', 'felt', 'wa', 'succeed']
# joy
# ['tutori', 'group', 'wa', 'soon', 'divid', 'got', 'list', 'name', 'freshmen', 'were', 'group', 'read', 'name', 'then', 'group', 'went', 'own', 'way', 'seminar', 'room', 'wonder', 'cope', 'new', 'situat', 'succeed', 'group', 'leader']
# fear
# ['were', 'disco', 'even', 'wa', 'not', 'pleasant', 'not', 'know', 'wa', 'angri', 'companion', 'let', 'feel', 'bad', 'humour', 'not', 'hide', 'feel']
# anger
# ['grandmoth', 'die', 'mother', 'call', 'sunday', 'morn', 'autumn', 'way', 'mother', 'told', 'hate', 'moment', 'sound', 'had', 'been', 'wait', 'death', 'grandmoth', 'had', 'lost', 'person', 'close', 'felt', 'guilti', 'too', 'had', 'been', 'bad', 'grandmoth', 'late', 'had', 'not', 'remain', 'calm', 'longer', 'understood', 'everyth', 'well']
# sadness
# ['underground', 'station', 'drunkard', 'came', 'speak', 'tri', 'ask', 'someth', 'did', 'not', 'answer', 'began', 'speak', 'companion', 'detest', 'dirti', 'growl', 'man']
# disgust
# ['wa', 'worri', 'task', 'relat', 'studi', 'had', 'done', 'group', 'wa', 'talk', 'friend', 'said', 'someth', 'neg', 'too', 'abrupt', 'manner', 'concern', 'work', 'partner', 'did', 'not', 'quit', 'mean', 'said', 'felt', 'asham', 'have', 'been', 'mean', 'enough', 'critic', 'also', 'friend', 'mine']
# shame
# ['had', 'told', 'boyfriend', 'did', 'not', 'want', 'relationship', 'knew', 'wa', 'import', 'want', 'free', 'saw', 'wa', 'difficult', 'remain', 'firm', 'did', 'not', 'chang', 'mind']
# guilt
# ['last', 'night', 'had', 'chat', 'fellow', 'student', 'had', 'known', 'year', 'first', 'time', 'were', 'speak', 'same', 'languag', 'mean', 'inspir', 'discuss', 'encount']
# joy
# ['sometim', 'quarrel', 'mother', 'blame', 'have', 'not', 'way', 'been', 'connect', 'event']
# anger
# ['hear', 'death', 'grandfath', 'first', 'not', 'believ', 'later', 'wept', 'felt', 'situat', 'wa', 'hopeless', 'felt', 'lone', 'want', 'consol']
# sadness
# ['even', 'wa', 'watch', 'littl', 'brother', 'came', 'start', 'eat', 'food', 'had', 'brought', 'kitchen', 'wa', 'tri', 'concentr', 'program']
# disgust
# ['littl', 'brother', 'wa', 'arrest', 'polic', 'railway', 'station', 'had', 'beer']
# shame
# ['temporari', 'job', 'have', 'restrict', 'other', 'action', 'make', 'obey', 'veri', 'often', 'give', 'feel', 'guilt', 'wish', 'other', 'way', 'act']
# guilt
# ['met', 'dear', 'friend', 'mine', 'long', 'time', 'express', 'feel', 'own', 'usual', 'way', 'mutual', 'scold', 'abus', 'complet', 'understand', 'touch', 'pat', 'take', 'hand', 'other', 'person', 'etc']
# joy
# ['felt', 'fear', 'purest', 'kind', 'car', 'accid', 'incid', 'imag', 'horror', 'kept', 'come', 'back', 'mind', 'wonder', 'have', 'happen', 'sister', 'friend', 'noth', 'veri', 'seriou', 'actual', 'happen']
# fear
# ['boy', 'know', 'were', 'tell', 'indec', 'manner', 'had', 'teas', 'young', 'shi', 'girl', 'know', 'had', 'despis', 'convict', 'scorn', 'touch', 'got', 'veri', 'angri', 'did', 'not', 'tri', 'conceal', 'gave', 'back']
# anger
# ['sweetheart', 'left', 'rather', 'decid', 'break', 'mutual', 'consent', 'consequ', 'were', 'unrestrain', 'weep', 'feel', 'loneli', 'hopeless', 'disconsol', 'felt', 'find', 'friend', 'talk', 'joy', 'forget']
# sadness
# ['sheer', 'curios', 'went', 'see', 'pornograph', 'movi', 'copenhagen', 'room', 'wa', 'full', 'men', 'pant', 'masturb', 'veri', 'disgust']
# disgust
# ['have', 'quarel', 'unnecessarili', 'reason', 'have', 'been', 'stupidli', 'cross', 'way']
# shame
# ['forc', 'fill', 'questionnair']
# guilt
# ['won', 'tenni', 'match']
# joy
# ['dog', 'ran', 'thin', 'ice', 'last', 'spring']
# fear
# ['tenni', 'match', 'wa', 'interrupt', 'kid', 'cycl', 'right', 'court']
# anger
# ['celebr', 'graduat', 'day', 'orchestra', 'play', 'garden', 'part', 'orchestra']
# joy
# ['risk', 'be', 'involv', 'fight', 'parti']
# fear
# ['had', 'veri', 'heavi', 'work', 'load', 'colleagu', 'have', 'noth', 'disturb', 'terror', 'ring', 'i.e', 'contin', 'interrupt', 'telephon']
# anger
# ['exam', 'fail']
# sadness
# ['overtook', 'car', 'mainroad', 'misjudg', 'distanc', 'oncom', 'car', 'result', 'toot', 'flash', 'other', 'driver', 'have', 'collid', 'had', 'acquaint', 'car']
# shame
# ['saw', 'neighbour', 'same', 'appart', 'block', 'lie', 'road', 'have', 'been', 'injur', 'ill', 'kept', 'metr', 'away', 'did', 'not', 'help']
# guilt
# ['met', 'old', 'schhol', 'friend', 'school', 'love']
# joy
# ['wa', 'cycl', 'school', 'nearli', 'got', 'knock', 'car', 'too', 'close', 'did', 'not', 'give', 'swerv', 'space']
# fear
# ['wa', 'deputi', 'manag', 'summer', 'certain', 'deputi', 'took', 'liberti', 'more', 'wa', 'normal']
# anger
# ['realiz', 'girlfriend', 'like', 'were', 'go', 'separ']
# sadness
# ['dog', 'dirt', 'thaw', 'spring']
# disgust
# ['forgot', 'mother', 'birthday']
# shame
# ['not', 'think', 'anyth', 'just', 'now']
# guilt
# ['pass', 'last', 'exam']
# joy
# ['wa', 'nearli', 'knock', 'car']
# fear
# ['reach', 'bu', 'stop', 'realiz', 'had', 'forgotten', 'bu', 'pass']
# anger
# ['current', 'work', 'load', 'too', 'much', 'feel', 'come', 'back', 'time', 'time']
# sadness
# ['year', 'old', 'son', 'give', 'spontan', 'kiss']
# joy
# ['someon', 'close', 'travel', 'car', 'delay']
# fear
# ['someon', 'doe', 'someth', 'wrong', 'affect', 'neg']
# anger
# ['think', 'parent', 'get', 'old']
# sadness
# ['not', 'have', 'time', 'other', 'peopl', 'problem', 'mother-in-law', 'sometim', 'depress', 'not', 'have', 'time', 'desir', 'strength', 'help']
# guilt
# ['ex-colleagu', 'ask', 'wa', 'interest', 'work', 'account', 'need', 'clever', 'peopl', 'had', 'immedi', 'thought']
# joy
# ['wa', 'drive', 'deer', 'suddenli', 'appear', 'front', 'car', 'wa', 'lot', 'traffic']
# fear
# ['saw', 'report', 't.v', 'news', 'apartheid', 'south', 'africa']
# anger
# ['girlfriend', 'becam', 'pregnant']
# joy
# ['nearli', 'collid', 'car']
# fear
# ['time', 'someon', 'let', 'air', 'tyre', 'cycl']
# anger
# ['read', 'lot', 'did', 'not', 'rememb', 'anyth']
# sadness
# ['time', 'had', 'put', 'dog', 'sleep']
# guilt
# ['long', 'ill']
# sadness
# ['pass', 'exam']
# joy
# ['wa', 'travel', 'tram', 'trip', 'fell', 'door', 'thought', 'wa', 'go', 'fall']
# fear
# ['miss', 'tram', 'have', 'run']
# anger
# ['inabl', 'read', 'book', 'colleg']
# sadness
# ['guy', 'not', 'interest', 'make', 'advanc']
# disgust
# ['drink', 'wine', 'too', 'often']
# shame
# ['not', 'studi', 'enough', 'not', 'understand', 'properli']
# guilt
# ['work', 'lawyer', 'offic', 'summer', 'got', 'veri', 'good', 'refer']
# joy
# ['had', 'been', 'watch', 'triller', 'dark', 'night', 'countri', 'had', 'outsid', 'toilet', 'own']
# fear
# ['accus', 'someth', 'have', 'not', 'done', 'get', 'unbeliev', 'angri']
# anger
# ['began', 'read', 'thick', 'book', 'had', 'limit', 'time', 'read', 'also', 'have', 'lot', 'work', 'not', 'keep']
# sadness
# ['someon', 'vomit', 'street']
# disgust
# ['not', 'think', 'incid', 'have', 'felt', 'veri', 'asham', 'are', 'small', 'incid', 'asham', 'instanc', 'not', 'send', 'money', 'children', 'ethiopia']
# shame
# ['had', 'lunch', 'ex-boyfriend', 'did', 'not', 'mention', 'fiance', 'felt', 'guilti', 'fact', 'felt', 'noth', 'ex-boyfriend']
# guilt
# ['wa', 'final', 'qualifi', 'profess']
# joy
# ['someon', 'attack', 'knife']
# fear
# ['someon', 'drove', 'car', 'then', 'deni', 'had', 'happen']
# anger
# ['wa', 'told', 'friend', 'wife', 'had', 'cancer']
# sadness
# ['saw', 'dog', 'had', 'been', 'knock', 'car']
# disgust
# ['box', 'child', 'ear']
# shame
# ['wa', 'fine', 'speed']
# guilt
# ['stop', 'work', 'had', 'bore', 'job']
# joy
# ['wa', 'go', 'home', 'car', 'late', 'one', 'night', 'wa', 'cold', 'dark', 'windi', 'becam', 'rather', 'panicki', 'way', 'hous']
# fear
# ['quarrel', 'famili']
# anger
# ['alon', 'room', 'contact', 'anyon', 'loneli', 'drain']
# sadness
# ['wa', 'holiday', 'someon', 'vomit', 'front']
# disgust
# ['empti', 'bucket', 'water', 'hospit']
# shame
# ['feign', 'sick', 'leav', 'work']
# guilt
# ['get', 'hug', 'someon', 'love']
# joy
# ['wa', 'drive', 'veri', 'fast', 'small', 'road', 'met', 'oncom', 'car', 'right', 'hand', 'bend', 'other', 'driver', 'wa', 'own', 'side', 'road', 'had', 'skid', 'avoid', 'collis', 'wa', 'dark']
# fear
# ['car', 'had', 'been', 'tow', 'away', 'traffic', 'polic', 'had', 'been', 'wrongli', 'park', 'howev', 'sign', 'had', 'been', 'put', 'onli', 'had', 'alreadi', 'park']
# anger
# ['oper', 'had', 'stay', 'bed', 'long', 'time']
# sadness
# ['wa', 'forc', 'stay', 'canteen', 'eat', 'food', 'had', 'not', 'ask', 'got']
# disgust
# ['did', 'not', 'buy', 'had', 'promis']
# shame
# ['mistak', 'took', 'book', 'librari', 'wa', 'not', 'suppos', 'loan']
# guilt
# ['won', 'unexpect', 'sum', 'money']
# joy
# ['year', 'old', 'daughter', 'disappear', 'moment', 'inattent', 'wa', 'respons']
# fear
# ['colleagu', 'ask', 'advic', 'did', 'not', 'have', 'enough', 'confid', 'ask', 'third', 'person']
# anger
# ['want', 'pregnant', 'did', 'not', 'succeed', 'wa', 'depress', 'menstruat']
# sadness
# ['warm', 'bu', 'full', 'peopl', 'someon', 'vomit', 'whole', 'bu', 'stank']
# disgust
# ['complain', 'colleagu', 'behaviour', 'goe', 'back', 'word', 'often', 'absent', 'irrespons', 'found', 'wa', 'alcohol', 'wa', 'tri', 'fight', 'againt', 'addict']
# shame
# ['spoke', 'mother', 'phone', 'had', 'skin', 'cancer', 'wa', 'wait', 'oper', 'forgot', 'ask', 'date', 'oper', 'just', 'finish', 'convers', 'gave', 'date', 'pass']
# guilt
# ['wa', 'parti', 'met', 'old', 'friend', 'adult', 'educ', 'cours', 'had', 'not', 'met', 'year', 'had', 'thought', 'lot', 'other', 'wonder', 'experi']
# joy
# ['wa', 'cycl', 'park', 'late', 'night', 'peopl', 'jump', 'wood', 'tri', 'stop', 'were', 'shout', 'someth', 'same', 'time']
# fear
# ['close', 'rel', 'tri', 'dissuad', 'studi', 'psycholog', 'low', 'statu']
# anger
# ['had', 'long', 'discuss', 'polit', 'acquaint', 'wa', 'more', 'knowledg', 'fail', 'explain', 'point', 'view', 'wa', 'misunderstood', 'felt', 'depress', 'left']
# sadness
# ['read', 'newspap', 'articl', 'young', 'girl', 'had', 'been', 'rape', 'assault', 'night', 'sever', 'men', 'wa', 'unconsci']
# disgust
# ['mother', 'reveal', 'person', 'detail', 'neg', 'aspect', 'charact', 'other', 'peopl', 'wa', 'present', 'unabl', 'defend']
# shame
# ['wa', 'unfaith', 'partner', 'onc', 'wa', 'work', 'abroad', 'long', 'period']
# guilt
# ['recent', 'got', 'appart', 'central', 'gottenburg']
# joy
# ['saw', 'larg', 'spider', 'crawl', 'wall']
# fear
# ['employ', 'took', 'too', 'mani', 'aspirin', 'bad', 'back', 'also', 'drank', 'enorm', 'amount', 'spirit', 'wa', 'danger', 'did', 'not', 'understand', 'had', 'done', 'anyth', 'wrong']
# anger
# ['left', 'new', 'york', 'famili', 'friend']
# sadness
# ['slept', 'guy', 'best', 'friend', 'want', 'had', 'never', 'had', 'intercours', 'anyon', 'had', 'terribl', 'complex']
# disgust
# ['date', 'close', 'girlfriend', 'boyfriend', 'few', 'time', 'told', 'wa', 'over', 'accept', 'found', 'finish', 'friendship']
# shame
# ['broke', 'boyfriend', 'year', 'wa', 'quit', 'unexpect', 'wa', 'particular', 'reason', 'break', 'such', 'someon', 'els']
# guilt
# ['son', 'return', 'mountain', 'healthi', 'bodi', 'soul']
# joy
# ['meet', 'new', 'peopl', 'forc', 'collabor']
# fear
# ['sport', 'fishermen', 'catch', 'gull', 'instead', 'fish', 'hook', 'often', 'mistak', 'make', 'angri']
# anger
# ['feel', 'sad', 'event', 'not', 'influenc']
# sadness
# ['member', 'famili', 'complain', 'food', 'serv', 'disgust']
# disgust
# ['have', 'chosen', 'put', 'son', 'privat', 'school', 'were', 'examin', 'mark', 'are', 'low', 'everi', 'time', 'give', 'term', 'result', 'left', 'sens', 'guilt']
# guilt
# ['wa', 'inform', 'had', 'been', 'accept', 'student', 'psycholog']
# joy
# ['wa', 'littl', 'fish', 'boat', 'ran', 'hard', 'weather', 'open', 'sea']
# fear
# ['found', 'guy', 'wa', 'date', 'particular', 'time', 'had', 'steadi', 'relationship', 'go', 'someon', 'els', 'long', 'time']
# anger
# ['felt', 'sad', 'depress', 'heard', 'cat', 'had', 'die']
# sadness
# ['wa', 'work', 'nurs', 'mental', 'hospit', 'patient', 'ate', 'content', 'patient', 'spitoon']
# disgust
# ['primari', 'school', 'vomit', 'front', 'other', 'middl', 'lesson']
# shame
# ['arriv', 'hour', 'late', 'import', 'meet', 'had', 'misunderstood', 'time']
# guilt
# ['wa', 'accept', 'student', 'psycholog']
# joy
# ['son', 'ha', 'pain', 'leg', 'appar', 'reason']
# fear
# ['week', 'school', 'teacher', 'sent', 'note', 'home', 'say', 'son', 'wa', 'inattent', 'unabl', 'lesson']
# anger
# ['thought', 'wa', 'go', 'imposs', 'start', 'studi', 'due', 'wrong', 'inform', 'student', 'advisor']
# sadness
# ['certain', 'person', 'lack', 'cleanli', 'home', 'person']
# disgust
# ['made', 'same', 'mistak', 'had', 'accus', 'someon', 'els', 'wa', 'obviou', 'third', 'pereson']
# shame
# ['lost', 'someth', 'wa', 'valuabl', 'sister']
# guilt
# ['son', 'wa', 'born']
# joy
# ['nearli', 'drown', 'ici', 'water', 'wear', 'ice', 'skate', 'wa', 'difficult', 'get']
# fear
# ['wa', 'point', 'problem', 'child', 'primari', 'school', 'mother', 'took', 'teacher', 'point', 'view']
# anger
# ['wa', 'accus', 'neglect', 'work', 'wrong', 'reason']
# sadness
# ['parent', 'attitud', 'toward', 'other', 'becom', 'reconcil', 'father', 'long-tim', 'addict']
# disgust
# ['wa', 'caught', 'steal', 'money', 'father']
# shame
# ['stole', 'coconut', 'cake', 'recept', 'tabl', 'put', 'mouth', 'realiz', 'host', 'wa', 'watch']
# guilt
# ['month', 'nation', 'servic', 'wa', 'downgrad', 'did', 'not', 'have', 'remain', 'month']
# joy
# ['wa', 'reprimand', 'manag', 'hotel', 'work', 'autumn']
# fear
# ['parent', 'drove', 'nearbi', 'place', 'went', 'home', 'immedi', 'instead', 'wait', 'few', 'hour', 'have', 'easili', 'wait']
# anger
# ['ex-girlfriend', 'discov', 'wa', 'certain', 'risk', 'be', 'pregnant']
# sadness
# ['wa', 'about', 'clean', 'drain', 'board', 'saw', 'look', 'sink', 'live', 'student', 'hostel']
# disgust
# ['mother', 'caught', 'masturb']
# shame
# ['onli', 'person', 'famili', 'academ', 'have', 'look', 'younger', 'onli', 'sister', 'better', 'respect', 'educ', 'life', 'experi']
# guilt
# ['older', 'sister', 'told', 'wa', 'think', 'join', 'rest', 'famili', 'winter', 'sport', 'holiday']
# joy
# ['slept', 'chapel', 'middl', 'night', 'realiz', 'wa', 'someeon', 'els', 'chapel', 'never', 'discov', 'wa', 'wa', 'there']
# fear
# ['were', 'high', 'school', 'few', 'guy', 'sometim', 'provok', 'friend', 'mine', 'call', 'pig', 'then', 'grunt', 'irrit', 'most', 'girl', 'onc', 'girl', 'got', 'angri', 'friend', 'said', 'someth', 'nasti', 'made', 'terribl', 'angri']
# anger
# ['talk', 'boyfriend', 'phone', 'wa', 'high', 'spirit', 'had', 'lot', 'tell', 'had', 'been', 'look', 'forward', 'convers', 'did', 'not', 'listen', 'extent', 'had', 'anticip']
# sadness
# ['mother', 'shout', 'child', 'noth']
# disgust
# ['complain', 'mother', 'untidi', 'kitchen', 'loook', 'box', 'ear', 'had', 'never', 'happen']
# shame
# ['not', 'home', 'midnight', 'call', 'home', 'ask', 'leav', 'door', 'open', 'get', 'actual', 'woke', 'whole', 'famili', 'call', 'late', 'mother', 'not', 'back', 'sleep', 'had', 'confer', 'next', 'day', 'realli', 'need', 'sleep']
# guilt
# ['got', 'first', 'day', 'here', 'depart']
# joy
# ['wa', 'cycl', 'park', 'car', 'someon', 'open', 'door', 'nearli', 'push', 'bike', 'traffic']
# fear
# ['boyfriend', 'sat', 'night', 'play', 'comput', 'game', 'friend']
# anger
# ['had', 'leav', 'mother', 'sister', 'week', 'visit']
# sadness
# ['saw', 'big', 'spider', 'veri', 'close']
# disgust
# ['ask', 'friend', 'return', 'money', 'had', 'loan', 'then', 'rememb', 'had', 'repay', 'sever', 'way']
# shame
# ['parent', 'insinu', 'someth', 'other', 'are', 'divorc']
# guilt
# ['wa', 'ask', 'child', 'godmoth']
# joy
# ['way', 'ski', 'slope', 'wa', 'difficult', 'steep']
# fear
# ['mother', 'interf', 'life']
# anger
# ['wa', 'left', 'alon', 'week-end', 'be', 'prepar']
# sadness
# ['first', 'time', 'saw', 'surgeon', 'cut', 'leg', 'put', 'black', 'rubbish', 'bag']
# disgust
# ['forgot', 'meet', 'work']
# shame
# ['demand', 'too', 'much', 'friend']
# guilt
# ['husband', 'suddenli', 'came', 'see', 'new', 'job', 'brought', 'flower', 'cake']
# joy
# ['wa', 'nearli', 'attackad', 'man', 'had', 'been', 'chase']
# fear
# ['father', 'ask', 'wa', 'communist', 'same', 'time', 'made', 'clear', 'longer', 'see', 'daughter']
# anger
# ['appli', 'job', 'thought', 'had', 'good', 'chanc', 'get', 'wa', 'not', 'even', 'grant', 'interview', 'did', 'not', 'get', 'job']
# sadness
# ['t.v', 'featur', 'show', 'violat', 'defenceless', 'peopl']
# disgust
# ['child', 'wa', 'play', 'doctor', 'neighbour', 'boy', 'mother', 'caught']
# shame
# ['husband', 'talk', 'restrict', 'have', 'accept', 'life', 'make', 'marriag', 'work', 'felt', 'wa', 'direct', 'wa', 'had', 'demand', 'chang', 'were', 'marriag', 'counsellor', 'then']
# guilt
# ['were', 'abl', 'afford', 'new', 'sofa', 'leather', 'cost', 'sek', 'had', 'wait', 'year']
# joy
# ['vertigo', 'stand', 'ladder', 'paint', 'hous']
# fear
# ['boss', 'enrol', 'cours', 'satisfi', 'own', 'end', 'trampl', 'associ', 'have', 'misfortun', 'have', 'superior', 'cours']
# anger
# ['argu', 'mother', 'way', 'treat', 'children', 'differ']
# sadness
# ['spit', 'vomit']
# disgust
# ['spot', 'seat', 'cover', 'husband', 'car']
# shame
# ['not', 'speak', 'sister-in-law', 'due', 'lack', 'interest', 'relationship', 'side']
# guilt
# ['recent', 'manag', 'get', 'first', 'consult', 'assign', 'i.e', 'own', 'initi']
# joy
# ['wa', 'hair', 'breadth', 'knock', 'drunkard', 'suddenli', 'ran', 'street', 'fear', 'came', 'later', 'realiz', 'have', 'happen']
# fear
# ['friend', 'usual', 'forgot', 'ticket', 'home', 'perform', 'miss']
# anger
# ['elect', 'thought', 'social', 'democrat', 'communist', 'major', 'achiev', 'especi', 'worker', 'share', 'fund', 'extens']
# sadness
# ['studi', 'visit', 'chicken', 'factori', 'butcheri', 'smell', 'environ', 'nois']
# disgust
# ['confess', 'parent', 'involv', 'mope', 'theft']
# shame
# ['answer', 'see', 'veri', 'littl', 'differ', 'shame', 'guilt', 'therefor', 'see', 'answer', 'shame']
# guilt
# ['wa', 'appoint', 'posit', 'trust', 'group', 'set', 'chang', 'work', 'environ']
# joy
# ['wa', 'alon', 'cottag', 'often', 'stay', 'wa', 'woken', 'rustl', 'sound', 'middl', 'night']
# fear
# ['tri', 'explain', 'plumber', 'face', 'face', 'toilet', 'wa', 'broken', 'did', 'not', 'believ', 'had', 'been', 'mend', 'ten', 'time']
# anger
# ['result', 'project', 'work', 'wa', 'treat', 'nonchalantli', 'intead', 'be', 'critic', 'teacher']
# sadness
# ['programm', 'violenc', 'pornographi', 'are', 'shown', 't.v']
# disgust
# ['talk', 'malici', 'colleagu', 'work', 'someon', 'els', 'immedi', 'afterward', 'felt', 'asham']
# shame
# ['decid', 'take', 'week', 'holiday', 'consult', 'famili', 'first']
# guilt
# ['girl', 'talk', 'thing', 'relationship', 'chang', 'becam', 'posit', 'diificult', 'time', 'turn', 'pleasant']
# joy
# ['not', 'land', 'plane', 'knew', 'fuel', 'wa', 'run', 'bad', 'weather', 'had', 'alreadi', 'frighten']
# fear
# ['read', 'reagan', 'tactic', 'decis', 'concern', 'south', 'african', 'boycott']
# anger
# ['half', 'brother', 'becam', 'serious', 'ill', 'cancer', 'die', 'later']
# sadness
# ['film', 'were', 'woman', 'wa', 'attack', 'rape', 'did', 'not', 'see', 'worst', 'had', 'desir', 'effect', 'veri', 'strong']
# disgust
# ['made', 'comment', 'wa', 'interpret', 'complet', 'differ', 'had', 'meant', 'said', 'realiz', 'mother', 'had', 'understood']
# shame
# ['had', 'promis', 'visit', 'girlfriend', 'differ', 'reason', 'not', 'make', 'rang', 'later', 'tell', 'not', 'come']
# guilt
# ['wa', 'offer', 'high', 'posit', 'trust', 'later', 'accept']
# joy
# ['had', 'window', 'open', 'door', 'wa', 'shut', 'kitten', 'not', 'partner', 'came', 'start', 'talk', 'someth', 'forgot', 'window', 'suddenli', 'saw', 'kitten', 'hang', 'window', 'frame', 'wa', 'rigid', 'fright', 'till', 'got', 'hold']
# fear
# ['noisi', 'guest', 'arriv', 'hotel', 'had', 'been', 'slightli', 'irrit', 'earlier', 'night', 'wa', 'tri', 'sleep', 'were', 'have', 'parti', 'went', 'yell', 'want', 'sleep', 'had', 'get', 'earli', 'next', 'day']
# anger
# ['wa', 'told', 'had', 'not', 'been', 'success', 'get', 'job', 'had', 'been', 'expect', 'wa', 'sure', 'wa', 'suffici', 'qualifi']
# sadness
# ['cat', 'vomit', 'worm', 'came', 'wa', 'still', 'aliv', 'wa', 'forc', 'wipe']
# disgust
# ['wa', 'child', 'wa', 'found', 'had', 'taken', 'cloth', 'outdoor', 'wa', 'summer', 'friend', 'were', 'out', 'wood', 'had', 'felt', 'excit', 'time', 'parent', 'discov', 'trouser', 'were', 'back', 'front', 'felt', 'asham']
# shame
# ['stole', 'money', 'mother', 'ask', 'later', 'wa', 'respons', 'never', 'admit']
# guilt
# ['cycl', 'spring', 'sunshin', 'give', 'such', 'delight', 'happi', 'healthi', 'wonder', 'financ', 'simpli', 'be', 'here', 'earth']
# joy
# ['relationship', 'famili', 'veri', 'poor', 'often', 'fear', 'be', 'exclud', 'group', 'fear', 'stronger', 'situat', 'argument', 'hand']
# fear
# ['recent', 'sister', 'year', 'younger', 'veri', 'spoil', 'shout', 'mother', 'appar', 'reason', 'heart-broken', 'express', 'mother', 'face', 'made', 'feel', 'veri', 'angri']
# anger
# ['watch', 't.v', 'programm', 'call', 'live', 'planet', 'saw', 'far', 'reach', 'environment', 'destruct', 'caus', 'man']
# sadness
# ['disgust', 'feel', 'have', 'never', 'experienc', 'peopli', 'other', 'hand', 'ha', 'been', 'repuls', 'anim', 'snake', 't.v']
# disgust
# ['rel', 'have', 'act', 'strang', 'unfriendli', 'toward']
# shame
# ['due', 'hunger', 'tired', 'becam', 'gener', 'irrit', 'fiance', 'made', 'cut', 'remark', 'realli', 'hurt', 'later', 'realiz', 'unfound', 'irrit', 'had', 'hurt', 'person', 'love', 'most', 'earth']
# guilt
# ['boat', 'trip', 'denmark', 'had', 'lot', 'fun', 'spent', 'sek', 'arm', 'bandit', 'odd', 'won', 'jackpot', 'sek']
# joy
# ['raini', 'day', 'wa', 'cycl', 'downhil', 'car', 'door', 'suddenli', 'open', 'tri', 'avoid', 'back', 'wheel', 'bike', 'got', 'caught', 'tram', 'track', 'somersault', 'had', 'injuri']
# fear
# ['way', 'home', 'marstrand', 'wa', 'drive', 'father', 'car', 'car', 'tri', 'push', 'front', 'father', 'wa', 'forc', 'swerv', 'thu', 'collid', 'car', 'pillar', 'other', 'car', 'drove', 'off', 'even', 'see', 'had', 'happen']
# anger
# ['girlfriend', 'had', 'spent', 'month', 'abroad', 'broke', 'relationship', 'letter']
# sadness
# ['polic', 'centr', 'man', '40-50', 'wa', 'brought', 'wa', 'veri', 'drunk', 'likelihood', 'had', 'not', 'slept', 'indoor', 'long', 'time', 'had', 'reliev', 'trouser']
# disgust
# ['custom', 'shop', 'work', 'came', 'ask', 'good', 'had', 'order', 'had', 'arriv', 'had', 'total', 'forgotten', 'order', 'tri', 'offer', 'weak', 'excus']
# shame
# ['wa', '4-5', 'year', 'old', 'hid', 'bicycl', 'key', 'not', 'veri', 'good', 'friend', 'few', 'hour', 'pretend', 'had', 'found']
# guilt
# ['wa', 'end-of-term', 'parti', 'last', 'week', 'had', 'fun', 'wa', 'happi', 'sang', 'drank', 'onli', 'soft', 'drink', 'possibl', 'have', 'good', 'time', 'alcohol']
# joy
# ['last', 'summer', 'wa', 'walk', 'beach', 'bikini', 'aw', 'man', 'came', 'cycl', 'wa', 'shout', 'ran', 'fast', 'leg', 'carri']
# fear
# ['cours', 'thought', 'deserv', 'good', 'mark', 'onli', 'got', 'ordinari', 'mark', 'justif', 'wa', 'given', 'mark']
# anger
# ['crash', 'car', 'had', 'scrap', 'then', 'wa', 'fault', 'feel', 'depress', 'miss', 'car']
# sadness
# ['had', 'sort', 'stomach', 'viru', 'last', 'week', 'vomit', 'colleg', 'morn', 'then', 'cake', 'shop', 'time', 'trip', 'home', 'again', 'got', 'home']
# disgust
# ['wa', 'even', 'school', 'wa', 'job', 'make', 'coffe', 'wa', 'not', 'abl', 'get', 'coffe', 'readi', 'time', 'thu', 'arriv', 'hour', 'late', 'class', 'top', 'coffe', 'wa', 'undrink']
# shame
# ['mani', 'year', 'friend', 'want', 'southern', 'europ', 'prefer', 'travel', 'alon', 'felt', 'guilti', 'want', 'own']
# guilt
# ['felt', 'love', 'wa', 'return']
# joy
# ['wa', 'convinc', 'someonn', 'had', 'broken', 'flat', 'woke', 'heard', 'sound', 'frighten']
# fear
# ['becam', 'clear', 'man', 'had', 'use', 'mani', 'peopl', 'sexual', 'psycholog', 'fact', 'mani', 'peopl', 'look', 'understood', 'not', 'trust', 'wa', 'forc', 'hide', 'while']
# anger
# ['feel', 'helpless', 'have', 'tri', 'help', 'someon', 'result']
# sadness
# ['think', 'now', 'way', 'father', 'behav', 'file', 'divorc']
# disgust
# ['year', 'old', 'wet', 'school']
# shame
# ['year', 'old', 'stole', 'money', 'mother']
# guilt
# ['recent', 'got', 'veri', 'posit', 'answer', 'clinic', 'tell', 'willingli', 'assist', 'collect', 'data', 'clinic', 'pilot', 'studi']
# joy
# ['time', 'meet', 'certain', 'dog', 'ha', 'onc', 'bitten']
# fear
# ['lot', 'provoc', 'child', 'threw', 'plate', 'floor']
# anger
# ['realiz', 'not', 'commun', 'properli', 'closest', 'friend']
# sadness
# ['tri', 'explain', 'child', 'were', 'magazin', 'wiith', 'nake', 'girl', 'kiosk']
# disgust
# ['stole', 'packet', 'cigarett', 'neighbour', 'next', 'day', 'own', 'return']
# shame
# ['wa', 'forc', 'declin', 'invit', 'mother', '70th', 'birthday', 'work', 'committ', 'area']
# guilt
# ['began', 'dans', 'teacher', 'came', 'told', 'wa', 'veri', 'good', 'soon', 'get', 'ballet', 'academi']
# joy
# ['late', 'saturday', 'night', 'found', 'lock', 'central', 'underground', 'station', 'stockholm', 'group', 'hard', 'rocker', 'were', 'drunk', 'equip', 'variou', 'kind', 'chain']
# fear
# ['wa', 'forc', 'call', 'telephon', 'compani', 'bill', 'concern', 'disconnect', 'phone', 'belong', 'landlord', 'bill', 'wa', 'month', 'overdu', 'meanwhil', 'had', 'been', 'use', 'phone', 'seem', 'have', 'intent', 'have', 'own', 'phone', 'reconnect']
# anger
# ['read', 'think', 'way', 'peopl', 'treat', 'anim', 'natur']
# sadness
# ['saw', 't.v', 'programm', 'anim', 'film', 'world', 'mistreat', 'use']
# disgust
# ['wa', 'year', 'old', 'wrote', 'passion', 'love', 'letter', 'boyfriend', 'later', 'found', 'sister', 'had', 'read']
# shame
# ['hate', 'mmi', 'flatmat', 'wa', 'nice']
# guilt
# ['month', 'old', 'son', 'happi', 'well']
# joy
# ['year', 'girl', 'ran', 'away', 'father', 'straight', 'front', 'car', 'wa', 'forc', 'use', 'emerg', 'brake']
# fear
# ['examin', 'had', 'been', 'satisfi']
# anger
# ['colleagu', 'fail', 'contact', 'arrang', 'time']
# sadness
# ['read', 'racist', 'slogan', 'wall']
# disgust
# ['sweden', 'arm', 'export']
# shame
# ['not', 'do', 'someth', 'had', 'promis']
# guilt
# ['gave', 'birth', 'healthi', 'boy']
# joy
# ['husband', 'spent', 'night', 'ourselv', 'hous', 'wa', 'area', 'outskirt', 'larg', 'town', 'were', 'not', 'familiar', 'heard', 'strang', 'nois', 'hous', 'hous', 'had', 'glass', 'wall', 'whole', 'thing', 'wa', 'even', 'more', 'frighten']
# fear
# ['jealou', 'husband', 'old', 'girlfriend', 'met', 'husband', 'wa', 'lot', 'reminisc']
# anger
# ['daughter', 'had', 'problem', 'friend', 'see', 'predica', 'window', 'wa', 'given', 'cold', 'shoulder']
# sadness
# ['wa', 'auxiliari', 'nurs', 'hospit', 'had', 'chang', 'nappi', 'first', 'time', 'veri', 'old', 'sick', 'woman']
# disgust
# ['friend', 'found', 'had', 'been', 'lie', 'had', 'been', 'particular', 'occas']
# shame
# ['middl', 'child', 'becam', 'veri', 'difficult', 'handl', 'birth', 'babi', 'brother', 'did', 'not', 'have', 'patienc']
# guilt
# ['husband', 'decid', 'take', 'few', 'day', 'holiday', 'particularli', 'tri', 'period']
# joy
# ['hospit', 'visit', 'prior', 'anasthesia', 'expect', 'miscarriag']
# fear
# ['exchang', 'point', 'view', 'sister', 'famili', 'matter']
# anger
# ['treatment', 'becom', 'pregnant', 'neg', 'result']
# sadness
# ['woke', 'morn', 'went', 'kitchen', 'discov', 'dog', 'had', 'diarrhoea', 'were', 'small', 'pile', 'floor', 'smell', 'wa', 'choke']
# disgust
# ['wa', 'young', 'did', 'not', 'make', 'toilet', 'time', 'hid', 'dirti', 'trouser', 'cellar', 'fear', 'be', 'discov', 'parent']
# shame
# ['work', 'boy', 'wa', 'injur', 'lack', 'supervis']
# guilt
# ['gave', 'birth', 'child', 'saw', 'wa', 'normal', 'wa', 'put', 'breast']
# joy
# ['labour', 'foetal', 'sound', 'becam', 'faint', 'wa', 'big', 'alert', 'forcep', 'deliveri']
# fear
# ['cash', 'desk', 'had', 'gone', 'buy', 'roll', 'kitchen', 'paper', 'reduc', 'price', 'queu', 'scream', 'children', 'turn', 'had', 'taken', 'roll', 'packet', 'instead', 'roll', 'packet', 'rebat', 'appli', 'assist', 'said', 'have', 'get', 'time']
# anger
# ['first', 'heard', 'tage', 'dannielsson', 'had', 'die']
# sadness
# ['lift', 'stockholm', 'central', 'station', 'stank', 'vomit', 'urin']
# disgust
# ['train', 'drunk', 'person', 'touch', 'babi', 'react', 'veri', 'disapprovingli', 'felt', 'asham', 'later', 'person', 'had', 'not', 'been', 'aggress', 'have', 'been']
# shame
# ['get', 'irrit', 'son', 'scream', 'sick', 'clean', 'cloth']
# guilt
# ['high', 'school', 'entranc', 'exam']
# joy
# ['gang', 'scream', 'drunk', 'youth', 'captur', 'tram']
# fear
# ['unjust', 'refre', 'decis', 'sport', 'event', 'wa', 'team', 'leader']
# anger
# ['girlfriend', 'left']
# sadness
# ['wa', 'domin', 'certain', 'person', 'even', 'knew', 'not', 'chang', 'own', 'reaction']
# disgust
# ['wa', 'given', 'detent', 'secondari', 'school']
# shame
# ['splash', 'child', 'not', 'slow', 'drive', 'puddl', 'water']
# guilt
# ['yesterday', 'final', 'whistl', 'blew', 'final', 'match', 'oi', 'ifk', 'wa', 'certain', 'oi', 'had', 'won', 'swedish', 'titl']
# joy
# ['wa', 'teach', 'someon', 'drive', 'were', 'about', 'crash', 'wa', 'scare']
# fear
# ['drummer', 'had', 'borrow', 'drum', 'destroy', 'drumskin', 'stick', 'did', 'not', 'repair', 'did', 'tell']
# anger
# ['dad', 'give', 'prioriti', 'kid', 'brother', 'band', 'other', 'activ', 'play', 'differ', 'band', 'rehears', 'parent', 'garag']
# sadness
# ['friend', 'unjustli', 'put', 'blame', 'reliev', 'conscienc', 'also', 'spread', 'lie', 'same', 'purpos']
# disgust
# ['behaviour', 'recent', 'parti', 'pass', 'earli', 'luckili']
# shame
# ['wa', 'face', 'face', 'deceiv', 'friend', 'sleep', 'wife']
# guilt
# ['dive', 'shark', 'brightli', 'colour', 'fish', 'outer', 'reef', 'tvavni', 'fidgi']
# joy
# ['miss', 'crash', 'hair', 'breadth', 'man', 'came', 'metr', 'ahead', 'wa', 'drive']
# fear
# ['told', 'comput', 'teacher', 'did', 'not', 'want', 'teach', 'prejudic']
# anger
# ['not', 'anyth', 'bad', 'back']
# sadness
# ['discov', 'hous', 'had', 'hire', 'tonga', 'wa', 'full', 'cockroach']
# disgust
# ['excret', 'mat', 'instead', 'potti']
# shame
# ['pull', 'chair', 'someon', 'kindergarten', 'hit', 'head']
# guilt
# ['pass', 'drive', 'test', 'week', 'ago', 'got', 'licenc']
# joy
# ['car', 'wa', 'drive', 'skid', 'ici', 'road', 'land', 'ditch', 'side', 'rock']
# fear
# ['met', 'friend', 'had', 'not', 'seen', 'last', '2-4', 'year']
# joy
# ['guy', 'chase', 'wa', 'jog']
# fear
# ['morn', 'newspap', 'ha', 'not', 'arriv']
# anger
# ['feel', 'unbeliev', 'happi', 'relationship', 'boyfriend', 'reoccur', 'feel']
# joy
# ['reoccur', 'fear', 'someth', 'happen', 'rel']
# fear
# ['argu', 'boyfriend', 'feel', 'feel', 'superior']
# anger
# ['fail', 'exam', 'last', 'summer', 'had', 'work', 'veri', 'hard', 'wa', 'veri', 'disappoint', 'think', 'wa', 'hopeless', 'continu', 'colleg', 'did', 'overreact']
# sadness
# ['argu', 'sister', 'feel', 'sometim', 'have', 'upper', 'hand', 'use', 'often', 'argu', 'better', 'make', 'terribl', 'angri']
# guilt
# ['wa', 'veri', 'happi', 'got', 'attract', 'summer', 'job']
# joy
# ['birth', 'child']
# joy
# ['have', 'leav', 'babi', 'carriag', 'shop', 'fear', 'someth', 'happen', 'babi']
# fear
# ['winter', 'water', 'pipe', 'froze', 'did', 'not', 'have', 'water', 'day']
# anger
# ['did', 'not', 'quit', 'succeed', 'breast', 'feed', 'babi']
# sadness
# ['smell', 'garlic', 'rush-hour', 'bu']
# disgust
# ['fell', 'ground', 'cross', 'street', 'cap', 'cover', 'eye', 'felt', 'quit', 'difficult']
# shame
# ['have', 'two-month', 'old', 'babi', 'came', 'here', 'univers', 'attend', 'lectur', 'had', 'leav', 'babi', 'father', 'felt', 'guilti']
# guilt
# ['christma', 'holiday', 'met', 'old', 'friend', 'not', 'have', 'seen', 'month']
# joy
# ['were', 'drive', 'car', 'friend', 'mine', 'turn', 'wrong', 'direct', 'unknown', 'district', 'nearli', 'drove', 'precipic']
# fear
# ['religion', 'teacher', 'present', 'shock', 'sectarian', 'thought', 'doom', 'day', 'offici', 'teach']
# anger
# ['grandfath', 'die', 'wa', 'exchang', 'student', 'usa']
# sadness
# ['happen', 'see', 'video-tap', 'movi', 'america', 'part', 'friend', 'place']
# disgust
# ['insult', 'coupl', 'good', 'friend', 'mine', 'even', 'tri', 'hit', 'wa', 'drunk', 'next', 'day', 'wa', 'asham', 'cours']
# shame
# ['stole', 'carrot', 'got', 'caught', 'had', 'apolog', 'owner']
# guilt
# ['underground', 'escal', 'youngish', 'bum', 'ask', 'money', 'did', 'not', 'give', 'anyth', 'fellow', 'told', 'wa', 'realli', 'good-look', 'man', 'wa', 'front', 'also', 'turn', 'look']
# joy
# ['wa', 'afraid', 'move', 'away', 'home', 'move', 'helsinki', 'studi']
# fear
# ['student', 'kitchen', 'share', 'somebodi', 'drank', 'juic', 'pot', 'litr', 'onli', 'got', 'glass', 'whole', 'pot']
# anger
# ['father', 'gave', 'money', 'brother', 'not']
# sadness
# ['week-end', 'home', 'mother', 'fri', 'greasi', 'unhealthi', 'meat', 'dish', 'make', 'feel', 'sick']
# disgust
# ['wa', 'wear', 'slipperi', 'shoe', 'tumbl', 'down', 'place', 'were', 'mani', 'peopl', 'walk']
# shame
# ...
# disgust
# ['few', 'day', 'back', 'had', 'tutori', 'class', 'teacher', 'randomli', 'assign', 'person', 'group', 'make', 'present', 'discuss', 'group', 'had', 'been', 'confus', 'present', 'wa', 'not', 'veri', 'well', 'prepar', 'unfortun', 'wa', 'select', 'present', 'not', 'keep', 'calm', 'wa', 'confus', 'result', 'wa', 'veri', 'poor', 'realli', 'felt', 'asham']
# shame
# ['onc', 'quarrel', 'sister', 'deliber', 'mess', 'belong']
# guilt
# ['had', 'dream', 'had', 'veri', 'close', 'friend', 'had', 'sever', 'stone', 'hous', 'new', 'territori', 'villag', 'did', 'not', 'have', 'much', 'furnitur', 'took', 'see', 'field', 'had', 'never', 'seen', 'were', 'sever', 'inch', 'clear', 'water', 'sunshin', 'wa', 'reflect', 'want', 'sit', 'short', 'green', 'plant', 'field', 'wa', 'afraid', 'tread', 'plant', 'death', 'friend', 'said', 'not', 'die', 'sat', 'down', 'happili', 'trouser', 'did', 'not', 'get', 'wet']
# joy
# ['see', 'horror', 'film', 'omen', 'not', 'sleep', 'night', 'even', 'close', 'eye', 'last', 'scene', 'film', 'kept', 'come', 'back', 'seem', 'hear', 'girl', 'film', 'shout', 'devil', 'devil', 'did', 'not', 'have', 'express', 'face', 'thought', 'choos']
# fear
# ['friend', 'often', 'play', 'joke', 'sometim', 'thought', 'wa', 'nonsens', 'person', 'onc', 'went', 'friend', 'hous', 'walk', 'first', 'shut', 'door', 'firmli', 'felt', 'did', 'not', 'respect', 'moreov', 'wa', 'friend', 'not', 'have', 'behav', 'wa', 'veri', 'angri', 'wa', 'bad', 'mood', 'then']
# anger
# ['suddenli', 'found', 'consider', 'good', 'friend', 'did', 'not', 'care', 'still', 'felt', 'unimport', 'deepli', 'thought', 'reason', 'see', 'wa', 'respons', 'final', 'made', 'mind', 'decid', 'not', 'expect', 'too', 'much', 'wa', 'sad', 'decid', 'were', 'longer', 'good', 'friend']
# sadness
# ['had', 'friend', 'wa', 'veri', 'kind', 'tri', 'best', 'like', 'understand', 'wa', 'not', 'help', 'reject', 'critic', 'blame', 'want', 'get', 'away', 'soon', 'possibl']
# disgust
# ['teacher', 'remind', 'not', 'summer', 'job', 'howev', 'did', 'month', 'yesterday', 'wa', 'chat', 'teacher', 'talk', 'summer', 'job', 'felt', 'asham']
# shame
# ['want', 'get', 'rid', 'bad', 'habit', 'seem', 'had', 'succeed', 'howev', 'year', 'later', 'got', 'bad', 'habit', 'again', 'felt', 'useless', 'alway', 'found', 'excus', 'explain', 'behaviour', 'result', 'felt', 'guilti']
# guilt
# ['exam', 'period', 'studi', 'librari', 'alon', 'close', 'friend', 'mine', 'also', 'classmat', 'told', 'applic', 'japanes', 'inter-cultur', 'exchang', 'programm', 'had', 'been', 'accept', 'wa', 'not', 'veri', 'sure', 'did', 'not', 'know', 'list', 'had', 'been', 'declar', 'ran', 'board', 'saw', 'wa', 'realli', 'includ', 'list', 'wa', 'excit', 'smile', 'day', 'long', 'met', 'classmat', 'friend', 'told', 'good', 'news', 'wa', 'happi', 'not', 'concentr', 'studi']
# joy
# ['boy', 'phone', 'night', 'want', 'talk', 'minut', 'thought', 'reveal', 'felt', 'question', 'relationship', 'treat', 'friend', 'did', 'not', 'want', 'misunderstand', 'therefor', 'refus', 'meet', 'told', 'see', 'come', 'day', 'wa', 'veri', 'unhappi', 'fear', 'have', 'hurt', 'got', 'troubl']
# fear
# ['had', 'fix', 'time', 'practic', 'had', 'particip', 'inter-depart', 'song', 'contest', 'arriv', 'found', 'wa', 'nobodi', 'there', 'went', 'canteen', 'found', 'eat', 'lunch', 'wa', 'angri', 'air', 'grevianc', 'then', 'left']
# anger
# ['friend', 'told', 'had', 'suffer', 'love', 'academ', 'share', 'sad']
# sadness
# ['friend', 'told', 'boy', 'want', 'get', 'know', 'time', 'felt', 'disgust', 'thought', 'wa', 'nonsens', 'thing']
# disgust
# ['raini', 'day', 'street', 'were', 'wet', 'wa', 'walk', 'slope', 'fell', 'down', 'out', 'careless', 'were', 'mani', 'peopl', 'saw', 'felt', 'ashamesd', 'moreov', 'hurt', 'ankl', 'wa', 'pain']
# shame
# ['night', 'dinner', 'nephew', 'wa', 'naughti', 'quarrel', 'parent', 'regret', 'nephew', 'wa', 'onli', 'year', 'old', 'had', 'toler', 'quarrel', 'made', 'father', 'think', 'children', 'not', 'take', 'care', 'futur', 'wa', 'slip', 'tongu', 'made', 'realiz', 'father', 'keep', 'thought', 'wa', 'still', 'veri', 'angri', 'drop', 'bowl', 'chopstick', 'went', 'kitchen', 'drink', 'tea', 'then', 'ran', 'other', 'side', 'hous']
# guilt
# ['afternoon', 'rush', 'home', 'look', 'result', 'slip', 'higher', 'level', 'fast', 'possibl', 'open', 'envelop', 'veri', 'care', 'found', 'result', 'were', 'much', 'better', 'had', 'expect', 'thu', 'enter', 'chines', 'univers', 'dilig', 'had', 'paid', 'wa', 'veri', 'happi']
# joy
# ['wa', 'young', 'had', 'gone', 'old', 'lift', 'play', 'antiqu', 'lift', 'guy', 'discov', 'warn', 'wa', 'veri', 'frighten']
# fear
# ['father', 'smoke', 'smell', 'make', 'feel', 'veri', 'uncomfort', 'never', 'listen', 'complaint', 'curs', 'furious', 'mind', 'not', 'solv', 'problem', 'violenc', 'tradit', 'moral', 'valu']
# anger
# ['got', 'mathemat', 'test', 'mark', 'not', 'believ', 'wa', 'true', 'past', 'have', 'least', 'mark', 'wa', 'get', 'weaker', 'studi', 'made', 'feel', 'not', 'expect', 'too', 'much', 'go', 'univers']
# sadness
# ['friend', 'work', 'commun', 'centr', 'hold', 'booth', 'day', 'friend', 'went', 'booth', 'play', 'meant', 'wa', 'veri', 'busi', 'not', 'maintain', 'order', 'behaviour', 'disgust']
# disgust
# ['wa', 'bu', 'way', 'examin', 'centr', 'man', 'sit', 'kept', 'look', 'contin', 'did', 'not', 'know', 'wa', 'wrong', 'reach', 'centr', 'start', 'stroll', 'still', 'had', 'littl', 'time', 'suddenli', 'man', 'came', 'whisper', 'have', 'forgotten', 'zip', 'trouser', 'wa', 'loss', 'say', 'anyth', 'felt', 'veri', 'embarrass', 'thought', 'bu', 'incid', 'felt', 'even', 'more', 'asham']
# shame
# ['secondari', 'school', 'classmat', 'lost', 'locker', 'key', 'class', 'saw', 'other', 'classmat', 'hold', 'key', 'talk', 'secretli', 'not', 'know', 'suspect', 'also', 'classmat', 'support', 'rememb', 'peopl', 'had', 'onli', 'key', 'key-r', 'had', 'seem', 'strang', 'classmat', 'said', 'had', 'seen', 'sell', 'book', 'book-shop', 'not', 'have', 'had', 'such', 'book', 'told', 'teacher', 'person', 'wa', 'caught', 'had', 'sold', 'book', 'wa', 'forc', 'quit', 'school', 'found', 'had', 'not', 'help', 'stole', 'later', 'also', 'felt', 'guilti']
# guilt
# ['night', 'boyfriend', 'express', 'love', 'canteen', 'presenc', 'friend', 'give', 'present']
# joy
# ['listen', 'ghost', 'stori', 'classmat', 'had', 'back', 'alon', 'hostel', 'night', 'had', 'walk', 'long', 'quiet', 'road', 'wa', 'scare', 'meet', 'ghost']
# fear
# ['came', 'girl', 'school', 'bus-stop', 'had', 'seen', 'sever', 'friend', 'wa', 'friend', 'friend', 'howev', 'friend', 'had', 'never', 'introduc', 'got', 'bu', 'smile', 'did', 'not', 'respond', 'pretend', 'not', 'have', 'seen', 'arrog', 'behaviour', 'made', 'sick', 'angri']
# anger
# ['examin', 'result', 'were', 'not', 'satisfactori', 'even', 'had', 'tri', 'best', 'then', 'start', 'wonder', 'abil', 'major', 'subject', 'howev', 'did', 'not', 'know', 'choos', 'major', 'subject', 'were', 'chang']
# sadness
# ['roommat', 'had', 'dinner', 'togeth', 'decid', 'clean', 'bowl', 'one', 'day', 'came', 'back', 'school', 'found', 'had', 'not', 'clean', 'had', 'cook', 'dinner', 'clean', 'felt', 'unhappi', 'disgust']
# disgust
# ['ask', 'classmat', 'teach', 'homework', 'ask', 'studi', 'first', 'did', 'not', 'ask', 'had', 'studi', 'felt', 'veri', 'asham']
# shame
# ['escap', 'commun', 'god', 'long', 'time', 'did', 'not', 'read', 'scriptur', 'did', 'not', 'pray', 'felt', 'wa', 'get', 'further', 'further', 'away', 'god', 'felt', 'guilti', 'wa', 'lazi']
# guilt
# ['femal', 'classmat', 'were', 'have', 'lunch', 'chat', 'crack', 'joke', 'wa', 'veri', 'happi', 'howev', 'felt', 'have', 'said', 'someth', 'inappropri', 'caus', 'have', 'bad', 'impress']
# joy
# ['did', 'not', 'well', 'subject', 'last', 'term', 'wa', 'afraid', 'fail', 'result', 'wa', 'grade', 'wa', 'not', 'good', 'still', 'pass', 'felt', 'more', 'comfort', 'then']
# fear
# ['friend', 'half-teasingli', 'call', 'bad', 'nicknam', 'felt', 'insult', 'kick', 'hip', 'anger', 'wa', 'stabl', 'later', 'did', 'not', 'feel', 'angri', 'fact', 'wa', 'afraid', 'other', 'friend', 'were', 'think', 'wa', 'intoler', 'person', 'howev', 'not', 'apolog', 'pretend', 'noth', 'had', 'happen', 'smile', 'left', 'friend', 'did', 'not', 'say', 'anyth', 'just', 'watch', 'leav']
# anger
# ['last', 'night', 'did', 'not', 'veri', 'well', 'subject', 'result', 'wa', 'announc', 'fear', 'fail', 'final', 'got', 'result', 'other', 'subject', 'were', 'not', 'all', 'good', 'felt', 'littl', 'sad']
# sadness
# ['spoke', 'femal', 'classmat', 'felt', 'disgust', 'said', 'meaningless', 'thing', 'seem', 'indic', 'someth', 'did', 'not', 'love/lik']
# disgust
# ['onc', 'femal', 'classmat', 'told', 'cloth', 'wore', 'seem', 'child', 'cloth', 'hear', 'felt', 'littl', 'asham', 'critic', 'cloth', 'wa', 'noth', 'wrong']
# shame
# ['onc', 'play', 'tenni', 'classmat', 'lost', 'few', 'tenni', 'ball', 'found', 'tenni', 'court', 'took', 'mine', 'think', 'belong', 'student', 'next', 'court', 'felt', 'guilti', 'later', 'someon', 'came', 'claim', 'ball', 'gave', 'back']
# guilt
# ['receiv', 'letter', 'univers', 'tell', 'applic', 'had', 'been', 'accept']
# joy
# ['primari', 'school', 'teacher', 'caught', 'cheat', 'dictat']
# fear
# ['someon', 'spread', 'rumour']
# anger
# ['night', 'father', 'suddenli', 'suffer', 'heart', 'attack', 'lead', 'breath', 'difficulti']
# sadness
# ['curriculum', 'year', 'english', 'cours', 'wa', 'veri', 'heavi', 'had', 'not', 'prepar', 'teacher', 'ask', 'sever', 'question', 'class', 'student', 'were', 'not', 'readi', 'answer', 'question', 'teacher', 'wa', 'frustat']
# disgust
# ['forgot', 'zip', 'trouser', 'wa', 'not', 'notic', 'anyon']
# shame
# ['peep']
# guilt
# ['had', 'picnic', 'old', 'classmat', 'chat', 'play', 'game']
# joy
# ['night', 'wa', 'alon', 'home', 'famili', 'member', 'usual', 'get', 'togeth', 'time', 'someon', 'knock', 'vigor', 'door']
# fear
# ['saw', 'bed', 'hostel', 'wa', 'mess', 'guess', 'someon', 'els', 'had', 'use', 'daili', 'necess', 'felt', 'person', 'saniti', 'had', 'been', 'affect']
# anger
# ['physic', 'experi', 'session', 'did', 'not', 'understand', 'content', 'experi', 'did', 'not', 'know']
# sadness
# ['man', 'sexual', 'aggress', 'small', 'girl', 'bu', 'girl', 'did', 'not', 'dare', 'speak']
# disgust
# ['be', 'unabl', 'stop', 'urin', 'bu']
# shame
# ['were', 'old', 'peopl', 'crowd', 'bu', 'did', 'not', 'have', 'courag', 'give', 'seat', 'close', 'eye', 'sleep', 'then', 'open', 'book', 'read', 'heart', 'want', 'give', 'seat']
# guilt
# ['wa', 'first', 'time', 'gave', 'birthday', 'present', 'friend', 'wrote', 'letter', 'girlfriend', 'content', 'letter', 'wa', 'sweet', 'made', 'feel', 'veri', 'happi']
# joy
# ['wa', 'week', 'higher', 'level', 'result', 'were', 'announc', 'had', 'tri', 'fail', 'mani', 'time', 'wa', 'last', 'time', 'wa', 'take', 'exam', 'knew', 'fail', 'again', 'woulld', 'have', 'enter', 'societi', 'imagin', 'thing', 'period', 'dreamt', 'had', 'enter', 'univers', 'wa', 'nice', 'experi', 'thought', 'futur', 'unexplain', 'fear', 'rose', 'fear', 'be', 'worker', 'not', 'have', 'bright', 'prospect', 'also', 'fear', 'critic', 'rel', 'brother', 'had', 'gone', 'univers', 'whenevr', 'thought', 'issu', 'not', 'eat', 'concentr', 'heart', 'beat', 'increas']
# fear
# ['surnam', 'brother', 'wa', 'differ', 'often', 'grin', 'home', 'provok', 'other', 'pleasur', 'made', 'angri']
# anger
# ['wa', 'primari', 'father', 'die', 'wa', 'veri', 'young', 'then', 'did', 'not', 'know', 'had', 'happen', 'weep', 'rel', 'tear', 'made', 'sad']
# sadness
# ['hostel', 'roommat', 'wa', 'veri', 'selfish', 'person', 'avoid', 'do', 'anyht', 'did', 'not', 'concern', 'few', 'prepar', 'lunch', 'togeth', 'had', 'decid', 'share', 'work', 'roomat', 'had', 'promis', 'same', 'had', 'wash', 'bowl', 'everytim', 'dinner', 'tri', 'wait', 'thought', 'realiz', 'fault', 'did', 'not', 'want', 'tell', 'work', 'univers', 'student', 'have', 'self-respect', 'disappoint', 'time', 'saw', 'tri', 'avoid', 'did', 'not', 'want', 'keep', 'contact']
# guit
# ['friend', 'had', 'mani', 'femal', 'friend', 'thought', 'were', 'lover', 'scold', 'did', 'not', 'accept', 'advic', 'later', 'learnt', 'girlfriend', 'wa', 'not', 'true', 'felt', 'asham', 'have', 'misunderstood']
# shame
# ['past', 'use', 'think', 'mother', 'wa', 'veri', 'nag', 'person', 'start', 'live', 'hostel', 'had', 'littl', 'time', 'meet', 'other', 'went', 'home', 'take', 'care', 'gradual', 'realiz', 'had', 'done', 'wa', 'own', 'good', 'veri', 'time', 'saw', 'felt', 'guilti']
# guilt
# ['august,1983', 'long', 'await', 'big', 'envelop', 'document', 'c.u.h.k', 'admiss', 'arriv', 'wa', 'afternoon', 'had', 'not', 'been', 'do', 'anyth', 'postman', 'big', 'bag', 'knock', 'door', 'knew', 'wa', 'hurriedli', 'open', 'envelop', 'mood', 'time', 'hard', 'describ', 'last', 'sever', 'hour', 'onli', 'calm', 'down', 'later']
# joy
# ['christma', 'eve,1984', 'had', 'just', 'finish', 'exam', 'wa', 'afraid', 'result', 'major', 'subject', 'had', 'been', 'veri', 'unsatisfactori', 'thought', 'had', 'onli', 'chanc', 'pass', 'even', 'fail', 'subject', 'not', 'need', 'repeat', 'howev', 'like', 'subject', 'veri', 'much', 'result', 'were', 'bad', 'lazy', 'wa', 'forc', 'chang', 'minor', 'subject', 'veri', 'unwil']
# fear
# ['septemb', 'wa', 'forc', 'live', 'someon', 'did', 'not', 'first', 'week', 'were', 'loggerhead', 'convers', 'wa', 'debat', 'atmospher', 'wa', 'veri', 'bad', 'learnt', 'had', 'got', 'mark', 'test', 'told', 'failur', 'lost', 'mark', 'wa', 'veri', 'angri', 'not', 'mark', 'were', 'lower', 'not', 'toler', 'pride', 'did', 'not', 'show', 'discontent', 'carri', 'do', 'work']
# anger
# ['issu', 'worri', 'rather', 'sadden', 'mid', 'septemb', 'went', 'guanggho', 'alon', 'wa', 'look', 'accomod', 'even', 'have', 'walk', 'mile', 'still', 'not', 'find', 'anyth', 'wa', 'not', 'worri', 'sleep', 'street', 'procedur', 'problem', 'final', 'found', 'place', 'sleep', "o'clock"]
# fear
# ['roommat', 'like', 'listen', 'meaningless', 'song', 'had', 'melodi', 'had', 'content', 'live', 'togeth', 'play', 'record', 'wa', 'forc', 'listen', 'not', 'tell', 'did', 'not', 'listen', 'song', 'had', 'right', 'disturb', 'freedom', 'other', 'find', 'pretext', 'leav', 'room', 'somewher', 'els']
# anger
# ['last', 'summer', 'went', 'camp', 'c.u', 'student', 'wa', 'work', 'then', 'had', 'leav', 'second', 'night', 'had', 'join', 'first', 'night', 'next', 'morn', "o'clock", 'femal', 'classmat', 'knock', 'door', 'tri', 'wake', 'wa', 'not', 'fulli', 'consciou', 'said', 'someth', 'not', 'have', 'realiz', 'troubl', 'had', 'made', 'want', 'hide', 'later', 'said', 'sorri', 'matter', 'came', 'end']
# shame
# ['lie', 'best', 'friend']
# shame
# ['receiv', 'letter', 'distant', 'friend']
# joy
# ['parent', 'were', 'wa', 'eldest', 'home', 'midnight', 'male', 'stranger', 'phone', 'spoke', 'rough', 'languag', 'hung', 'heard', 'someon', 'walk', 'door']
# fear
# ['year', 'back', 'someon', 'invit', 'tutor', 'grand-daught', 'grand-daught', 'ask', 'question', 'mathemat', 'taught', 'howev', 'did', 'not', 'listen', 'made', 'feel', 'unhappi', 'second', 'year', 'wa', 'same', 'enter', 'univers', 'girl', 'parent', 'suggest', 'employ', 'daghter', 'tutor', 'told', 'univers', 'wa', 'homework', 'have', 'lot', 'time', 'made', 'time-t', 'requir', 'tutor', 'day', 'week', 'did', 'not', 'respect', 'anyway', 'had', 'child', 'teach']
# shame
# ['had', 'taken', 'respons', 'someth', 'had', 'prepar', 'howev', 'fail', 'timid', 'attempt', 'still', 'not', 'adapt', 'atmospher', 'fail', 'felt', 'imcompet', 'felt', 'other', 'think', 'had', 'not', 'prepar']
# shame
# ['wa', 'home', 'heard', 'loud', 'sound', 'spit', 'door', 'thought', 'famili', 'member', 'step', 'spit', 'bring', 'germ', 'hous']
# fear
# ['did', 'not', 'homework', 'teacher', 'had', 'ask', 'wa', 'scold', 'immedi']
# guilt
# ['had', 'shout', 'younger', 'brother', 'wa', 'alway', 'afraid', 'call', 'loudli']
# fear

# %%
feature_set = [({i:(i in word_tokenize(' '.join(sentence).lower())) for i in vocabulary},tag) for sentence, tag in Data]

# %%
# get the training set and train the Naive Bayes Classifier
#training_set = nltk.classify.util.apply_features(extract_features, Data)
classifier = NaiveBayesClassifier.train(feature_set)

# %%
'''
Performs stemming
'''
def new(sentences):
    sentence_list = []
    sen_string = []
    sen_token = []
    stemmer = PorterStemmer()
    i = 0
#     for sen in sentences:
#         print i,
    i += 1
    st = ""
    for word in sentences:
        word_l = word.lower()
        if len(word_l) >= 3:
            st += stemmer.stem(word_l) + " "
    sen_string.append(st)
    w_set = nltk.word_tokenize(st)
    sen_token.append(w_set)
    w_text = nltk.Text(w_set)
    sentence_list.append(w_text)
    return w_text

# %%
test_sentence = "I am very happy"
featurized_test_sentence =  {i:(i in new(word_tokenize(test_sentence.lower()))) for i in vocabulary}

# %%
print ("test_sent:",test_sentence)
print ("tag:",classifier.classify(featurized_test_sentence))
# Out:
# test_sent: I am very happy
# tag: joy

# %%
# get the training set and train the Naive Bayes Classifier
training_set = nltk.classify.util.apply_features(extract_features, Data)
classifier = NaiveBayesClassifier.train(training_set)

# %%
from nltk.tokenize import TweetTokenizer
tknzr = TweetTokenizer()

# %%
test_sentence="This is the best band I've ever heard!"

# %%
new=tknzr.tokenize(test_sentence)

# %%
new
# Out:
# ['This', 'is', 'the', 'best', 'band', "I've", 'ever', 'heard', '!']

# %%
test = nltk.classify.util.apply_features(extract_features,(new))

# %%
type(test)
# Out:
# nltk.collections.LazyMap

# %%
classifier.classify(test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-209-16b987ad6050> in <module>()
# ----> 1 classifier.classify(test)
#
# D:\AppData\Local\Continuum\anaconda3\lib\site-packages\nltk\classify\naivebayes.py in classify(self, featureset)
#      86
#      87     def classify(self, featureset):
# ---> 88         return self.prob_classify(featureset).max()
#      89
#      90     def prob_classify(self, featureset):
#
# D:\AppData\Local\Continuum\anaconda3\lib\site-packages\nltk\classify\naivebayes.py in prob_classify(self, featureset)
#      92         # Otherwise, we'll just assign a probability of 0 to
#      93         # everything.
# ---> 94         featureset = featureset.copy()
#      95         for fname in list(featureset.keys()):
#      96             for label in self._labels:
#
# AttributeError: 'LazyMap' object has no attribute 'copy'

# %%
classifier.predict([test_data[0]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-7cbe6f3eede8> in <module>()
# ----> 1 classifier.predict([test_data[0]])
#
# AttributeError: 'NaiveBayesClassifier' object has no attribute 'predict'

# %%
Naive_accu = get_accuracy(test_data, classifier)
# Out:
# Total accuracy: 63.164894% (475/20).

# %%
length = len(st)
train_size = (9 * length) // 10
train_data = st[:train_size]
test_data = senten[train_size:]

# %%
gensim_dict = corpora.Dictionary(train_data)

# %%
gensim_dict.save('corpus.dict')

# %%
gen_token = gensim_dict.token2id

# %%
corpusmm = [gensim_dict.doc2bow(text) for text in train_data]
corpora.MmCorpus.serialize('corpus.mm', corpusmm)

# %%
gen_c = corpora.MmCorpus('corpus.mm')

# %%
tfidf = models.TfidfModel(gen_c)

# %%
corpus_tfidf = tfidf[gen_c]

# %%
dictionary = corpora.Dictionary.load('corpus.dict')
lsi = models.LsiModel(corpus_tfidf, id2word=gensim_dict, num_topics=7) # initialize an LSI transformation
corpus_lsi = lsi[corpus_tfidf]

# %%
index = similarities.MatrixSimilarity(lsi[gen_c])
# Out:
# D:\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
lsi.save('corpus.lsi') 
index.save('corpus.index')
# lsi = models.LsiModel.load('corpus.lsi')

# %%
# length = len(corpus_lsi)
# train_size = (9 * length) // 10
# train_data = corpus_lsi[:train_size]
# test_data = corpus_lsi[train_size:]

# %%
test_labels = labels[train_size:]
train_labels = labels[:train_size]

# %%
def semantic_sim(test_data):
    total = 0
    for count, doc in enumerate(test_data):
        vec_bow = dictionary.doc2bow(doc.lower().split())
        vec_lsi = lsi[vec_bow]
        sims = index[vec_lsi]
        ans = sorted(enumerate(sims), key=lambda item: -item[1])[0]
        ind = ans[0] 
        if train_labels[ind] == test_labels[count]:
            total += 2
    avg = total/count
    return avg

# %%
sem_accu = semantic_sim(test_data)

# %%
print(sem_accu)
# Out:
# 0.49533954727030627

# %%
# Experimenting with Alchemy API
url = 'http://gateway-a.watsonplatform.net/calls/text/TextGetEmotion'
params = urllib3.urlencode({
  'apikey': '15ce4bd07b66f9e000a15383777870c0afb383fb',
  'text': 'I am excited',
  'outputMode': 'json'
})
response = urllib2.urlopen(url, params).read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-76e51f021b09> in <module>()
#       1 # Experimenting with Alchemy API
#       2 url = 'http://gateway-a.watsonplatform.net/calls/text/TextGetEmotion'
# ----> 3 params = urllib3.urlencode({
#       4   'apikey': '15ce4bd07b66f9e000a15383777870c0afb383fb',
#       5   'text': 'I am excited',
#
# AttributeError: module 'urllib3' has no attribute 'urlencode'

# %%
response

# %%
print ("Accuracy using Lexical Component - First Phase  ", a*100, '%')
print ("Accuracy using Lexical Component - Second Phase  ", b*100, "%")
# Out:
# Accuracy using Lexical Component - First Phase   22.73815859499734 %
# Accuracy using Lexical Component - Second Phase   53.97978521794062 %

# %%
print ("Accuracy using Naive Bayes Component  ", Naive_accu, "%")
# Out:
# Accuracy using Naive Bayes Component   63.16489361702128 %

# %%
print ("Accuracy using semantic similarity component ", sem_accu*100, "%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-148-77796e727d0b> in <module>()
# ----> 1 print ("Accuracy using semantic similarity component ", sem_accu*100, "%")
#
# NameError: name 'sem_accu' is not defined
